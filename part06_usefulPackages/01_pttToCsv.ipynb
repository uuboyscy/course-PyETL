# %% [markdown]
# # 製作 DataFrame

# %%
# 引入必要套件
import pandas as pd
import os

# 列出所有文檔
source_file_path = r'./res_gossiping'
file_list = os.listdir(source_file_path)
file_list
# Out:
# ['[問卦] 兩個候選人選前一個月同時陣亡的可能性.txt',
#  '[新聞]江啟臣：兩岸是不對稱的戰爭 從募兵改徵兵.txt',
#  'Re: [新聞] 高加索血戰破百死：亞美尼亞禁止役齡男.txt',
#  '[問卦] 如果川普老婆死於武漢肺炎會怎麼樣？.txt',
#  '[問卦] 為什麼古代生物體型可以長到這麼大？.txt',
#  '[問卦] 支那女生是不是都沒錢修補衣服.txt',
#  'Re: [問卦] 今天為什麼要降半旗.txt',
#  '[問卦] 八卦板的問卦484都毫無意義?.txt',
#  '[新聞] 川普夫婦確診了！網友卻認為「案情不單.txt',
#  '[問卦] 習大大現在在想什麼.txt',
#  '[問卦] 正妹讀大學時  大概會吃幾根香腸?.txt',
#  '[問卦] 美帝統領中瘟疫了 現在是解放台灣時候?.txt',
#  '[問卦] 美軍、參聯會現在想什麼?.txt',
#  '[新聞] 國際藝文人士來台可申請專案縮短隔離 國.txt',
#  '[問卦] 隨便說三個你會的做愛技巧！.txt',
#  '[問卦] 亡國之君在想什麼？.txt',
#  '[問卦] 現在新聞都喜歡用什麼字眼啊.txt',
#  'Re: [新聞] 酒店公關爽吃人夫...還跩嗆正宮「鬆姐黑.txt',
#  '[問卦] 你第一眼直覺這個能防螞蟻嗎.txt',
#  '[問卦] (更新肉包) 大安區的便當這樣多少？.txt',
#  '[問卦] 泌尿科找女醫師，最後向台女露鳥的機會？.txt',
#  '[新聞] 新莊、樹林周邊電桿全面地下化 耗資9億54.txt',
#  'Re: [問卦] 憂鬱症不吃藥的治療方法.txt',
#  '[新聞] 印度邊境布防巡航導彈目標鎖解放軍西藏.txt',
#  '[問卦] 華堡是不是屌打大麥克.txt',
#  '[新聞] 扯！台中發獎狀竟印中國民國\u3000師：原來.txt',
#  '[問卦] 台灣的印度人多嗎.txt',
#  'Re: [問卦] 喂 為什麼教召要改成一年一訓而不徵兵啦.txt',
#  '[問卦] 川普遺書會寫什麼？.txt',
#  '[問卦] 阿福一字馬484很香啊？.txt',
#  'Re: [問卦] 有沒有『洪蘭式煩惱』的八卦？.txt',
#  '[問卦] 有沒有國慶煙火超屌的八卦？.txt',
#  '[問卦] 那些質疑魏如萱的是否沒看到這段才質疑.txt',
#  '[問卦] 如果川普在選前掛掉會怎樣？.txt',
#  '[問卦] 為什麼中國不保留皇室傳統 ??.txt',
#  '[問卦] 65歲老人可以湊到一個輕裝師嗎？.txt',
#  '[新聞] 最新Chromecast搭載Google TV與遙控器\u3000.txt',
#  '[問卦] 如果川普跟拜登都在選前病逝？.txt',
#  '[問卦] 洗頭妹 幫我洗頭帶手套？？？？.txt',
#  'Re: [問卦] 夜よ 僕に歌わせるなよ.txt',
#  '[問卦] 知道招式機01~08的都是什麼樣的人啊?.txt',
#  '[問卦] 機車吵爸媽出錢買的在想什麼？.txt',
#  '[問卦] 湖口一堆流氓8+9？.txt',
#  'Re: [問卦] 核彈投中國哪，台灣才不會被波及？.txt',
#  'Re: [問卦] 被UBER EAT嗆不要送上樓怎麼辦.txt',
#  '[問卦] 林俊傑音樂功力怎麼樣.txt',
#  '[新聞]《惡靈古堡》電影再啟卡司曝光！Netfix影 .txt',
#  'Re: [新聞] 國民黨提案台美復交「促美協防抵抗中共.txt',
#  '[問卦] 質疑口罩防疫效果的人是不是都遭到報應?.txt',
#  '[新聞] 萊豬文宣竟進入北市7國小 北市教育局：確.txt',
#  '[問卦] 今天美股會熔斷嗎？.txt',
#  '[問卦] 靠觀光旅遊賺錢的歐豬現在經濟如何?.txt',
#  '[問卦] 台北車站真的算迷宮嗎？.txt',
#  '[問卦] 排骨酥湯+湯圓 這樣吃會很客家嗎.txt',
#  '[問卦] 住在陽明山上有什麼優點？.txt',
#  '[問卦] 活過2020年484能嘴一輩子？.txt',
#  '[問卦] 川普確診是不是八奇的思考領域.txt',
#  '[問卦] 有人只能靠年終存錢的ㄇ.txt',
#  '[問卦] 請問女同事問我要不要去同事婚禮的八卦.txt',
#  '[問卦] 坑殺四十萬趙國降卒？.txt',
#  '[問卦] 4不4該把川普爸爸接來台灣的時候到了??.txt',
#  '[問卦]低碳飲食的狀態下有辦法不容易肚子餓？.txt',
#  '[問卦] 亂倫的黑數484很高？.txt',
#  '[問卦] 騎到新竹宇老 再來要幹嗎？.txt',
#  '[爆卦] 拜登領先擴大至21%！.txt',
#  '[問卦] 武漢病毒現在在想什麼？.txt',
#  '[問卦] 有沒有新竹火車站的八卦.txt',
#  '[新聞] 變態直排輪教練！帶7男童拍裸照打飛機 \u3000.txt',
#  '[新聞] 戰爭時誰收屍？PTT鄉民揭神秘內幕：大賺.txt',
#  '[問卦] 我哥也是勞工為何不嫌退休金少？.txt',
#  '[新聞] 延攬柯文哲人馬 林右昌證實前北市府發言人林昆鋒接綜合發展.txt',
#  '[問卦] 海陸全餐加蔥蛋林志玲吃的完嗎？.txt',
#  '[問卦] 川普對上羅禮士，誰會贏？.txt',
#  '[問卦] 基隆以後適合長住嗎？.txt',
#  '[問卦] FB上面放BMW跟放MBL哪個可以吸引到女森？.txt',
#  '[問卦] 上帝連我的隊友都救不了，如何救世人.txt',
#  'Re: [問卦]台妹:大陸健保比台灣健保公平太多啦！.txt',
#  '[問卦] 機車上高速到底有沒有合法？.txt',
#  '[問卦] 有沒有像「北榮」這種簡稱的簡稱.txt',
#  '[問卦] 買惹many發現路上妹子都在看我怎麼辦？.txt',
#  '[問卦] 學妹穿女僕裝說 主人 晚餐要吃什麼?(有圖).txt',
#  'Fw: [新聞] 獄警強迫囚犯連聽Baby Shark兩小時遭起訴.txt',
#  '[問卦] 怎麼勸告阿北不要吃(美)牛肉麵?!.txt',
#  '[問卦] 川普如果癒後颯爽復出會發生什麼事？.txt',
#  '[問卦] 爐渣市要辦國慶煙火有推薦好玩好吃的嗎.txt',
#  '[爆卦] 恭喜警察被記申誡喔！.txt',
#  '[問卦] 有匿蹤戰機，怎麼匿蹤飛彈還沒做出來？.txt',
#  '[問卦] 雙北的8＋9都藏在哪？.txt',
#  '[問卦] 放假前進十張2330是不是躺著數錢？.txt',
#  'Re: [新聞] 防疫獎章頒獎 陳時中：台灣人氣質好可以.txt',
#  '[問卦] 甘草粉是不是屌打梅粉？.txt',
#  '[問卦] 灑狗血 打悲情牌 這招在美國選舉有用嗎?.txt',
#  '[新聞] Subway潛艇堡的麵包不是麵包？愛爾蘭法院.txt',
#  '[問卦] 有沒有hspice的八卦.txt',
#  '[問卦] 看到教召要加薪教召仔有多爽？？.txt',
#  '[問卦] 乃木坂"夏のFree&Easy"ＭＶ的觀看重點?.txt',
#  '[新聞] 放寬除役年限？年齡擬提高到50歲\u3000.txt',
#  '[爆卦] 最新防疫成功國家排名 中國第一 台灣榜外 .txt',
#  '[問卦] 川普中標會讓美國選舉產生變數嗎.txt',
#  '[問卦] 大家幾天沒洗頭會變條碼頭？.txt',
#  '[問卦] 年薪40萬  可以買台北哪裡？.txt',
#  '[問卦] 蘋果的safari為啥這麼多人愛用.txt',
#  '[問卦] 台中火車站那麼多家太陽餅都誰在買的？.txt',
#  '[問卦] 有沒有蓋牌的八卦？.txt',
#  '[問卦] 台灣跟中國一樣虛坪制不丟臉嗎？.txt',
#  'Re: [問卦] 演化後為什麼要一公一母才可以繁衍.txt',
#  'Re: [新聞] 台灣豬標章標示不實「吹哨者條款」出爐.txt',
#  '[新聞] 救豬農「百億基金」首曝光 陳吉仲：4年共.txt',
#  '[問卦] 如果普丁生在台灣 有辦法成功台獨嗎?.txt',
#  '[問卦] 美國總統中毒，最爽的是誰？.txt',
#  '[問卦] 咖啡因洗髮精真的有用嗎？.txt',
#  '[問卦] 阿薩斯會淨化白宮嗎.txt',
#  '[問卦] 有沒有黃安又要拍戲的八卦？.txt',
#  'Re: [爆卦] 中國新的實驗性疫苗證實安全有效.txt',
#  '[新聞] 慕尼黑房市 泡沫風險冠全球.txt',
#  '[問卦] 明天要挑戰一人頂三工好緊張？.txt',
#  '[問卦] 外國人唱中文歌的例子多嗎？.txt',
#  '[問卦] 汪建民和丸子的Junior要怎麼分？.txt',
#  '[問卦] 想見你為啥沒入圍金曲獎？.txt',
#  'Re: [問卦] 流氓能買的起c300？賺錢能力超強？.txt',
#  '[爆卦] 學甲爐渣案 林易瑩:一直有耳聞市府壓新聞.txt',
#  '[爆卦] 2020年諾貝爾化學獎.txt',
#  '[問卦] 該怎麼用北京話求饒.txt',
#  '[新聞] 大安警衛伴李登輝36年今解散歸建 \u3000李坤.txt',
#  '[問卦] 台灣有厲害的科普YT嗎？.txt',
#  '[問卦] 在美國生病只能自身自滅嗎？.txt',
#  '[問卦] 覺青是不是嚇得屁滾尿流了wwwwwww.txt',
#  '[問卦] 美豬進口台灣，誰會去代理經銷啊？.txt',
#  '[問卦] 萬一美國總統選到一半候選人死了會怎樣?.txt',
#  '[新聞]「退黨證書」可線上辦 中國人紛退黨自保.txt',
#  '[問卦] 象棋是不是不懂戰爭的人發明的.txt',
#  '[問卦] 欸! 教召爭議其實是因為不公平吧!.txt',
#  '[問卦] 2020的高潮要來了嗎?.txt',
#  'Re: [問卦] 退伍超過八年到底會不會被教召？.txt',
#  '[爆卦] 日本藝人結婚對東京股市的衝擊.txt',
#  'Re: [問卦] 為何共匪軍機擾台 我們要出動驅逐？.txt',
#  '[問卦] 為什麼日本AKB會突然力捧大盛真步？.txt',
#  '[新聞] 礦業63歲老闆再婚娶38歲妻 新娘：嫁給愛.txt',
#  '[新聞] 獨／國道又見機車趴趴走…連過2交流道不.txt',
#  '[問卦] 大學私立前段是哪幾間阿？.txt',
#  '[問卦] 當兵最幹的是甚麼??.txt',
#  '[問卦] 中秋節大家會做愛吧.txt',
#  '[問卦] 為什麼兔田佩可拉一直在用小畫家？.txt',
#  'Re: [問卦] 以後下基地會全部都是教召老兵嗎?.txt',
#  'Re: [問卦] 家裡跑出野生螃蟹怎麼辦.txt',
#  '[新聞] 「不管你說什麼，我反戰！」龍應台怒批.txt',
#  '[新聞] 超愛吃肉乾！28歲女罹大腸癌\u3000醫曝研究.txt',
#  'Re: [問卦] 一天到晚嗆買房是傻子的都哪種人？.txt',
#  '[問卦] 年收50萬在鄉下地方是什麼等級.txt',
#  '[問卦] 台女滯留愛爾蘭在做啥阿??U沒U卦??.txt',
#  '[新聞] 網購3盒壯陽藥 男子差點被關10年.txt',
#  '[新聞] 19歲男大生多次與15歲女孩上床\u3000品行優良.txt',
#  '[問卦] 市容差距.txt',
#  '[問卦] 承認怕死是一種罪???.txt',
#  '[問卦] 隔壁住吸毒犯怎麼辦?.txt',
#  '[問卦] 李永樂老師屌打台灣多數的Youtuber吧?.txt',
#  '[新聞] 辦好市多會員卡值得？過來人曝「真實經驗.txt',
#  '[問卦] 娶到銀行員是什麼感覺？.txt',
#  '[問卦] 所以推背圖有推到川普陽性嗎.txt',
#  '[新聞] 夫妻冷戰10年互罵畜生、惡毒的嘴 法院認2人已恩斷義絕.txt',
#  '[問卦] 撿到鴿子怎麼辦？.txt',
#  '[問卦] 愛莉莎莎算是PTT反串的巔峰嗎？.txt',
#  '[問卦] 有沒有四級地震的卦？.txt',
#  '[新聞] 開放美豬｜農委會疑濫用政策行銷費用\u3000.txt',
#  '[問卦] 閩南民系漢族的特徵是什麼？.txt',
#  'Re: [問卦] 如果戰爭的話，你（個人）會投降嗎？.txt',
#  '[問卦] 為什麼我還沒被教召過？？？.txt',
#  '[問卦] 美國之子捨身對抗邪惡這劇本怎麼樣.txt',
#  'Re: [新聞] 妻打麻將輸了沒錢還…竟趴桌讓3牌友蹂躪.txt',
#  '[問卦] 拜登如果輸了會提起選舉無效之訴嗎.txt',
#  'Re: [爆卦] 花敬群:有人把我沒說過的渾話栽贓給我.txt',
#  '[問卦] 除役年齡 可能要延長14年了.txt',
#  '[問卦] 台灣以外 其他國的中秋節 有人在烤肉嗎.txt',
#  '[問卦] 習近平怎摸都沒事啊.txt',
#  '[新聞] 機車族不是人！ 中央擬取消人行道機車格 .txt',
#  '[新聞] 駁陳廷寵 嚴德發：國軍現在最有戰力.txt',
#  '[問卦] 簡廷芮男友是不是很有錢？.txt',
#  '[問卦] 百度鎖臺灣ip是不是分裂國家？.txt',
#  'Re: [問卦] 簡體字為了掃盲是不是智障的作法?.txt',
#  '[問卦]  A date which will live in infamy.txt',
#  '[問卦] 有沒有給我tempo ready go 的掛.txt',
#  '[新聞] 3000違建工廠僅300納管\u3000桃園祭違建剋星.txt',
#  '[問卦] 辛普森家庭的製作人？.txt',
#  '[問卦] 有沒有智力測驗的八卦？.txt',
#  '[問卦] 朋友去買豪宅.txt',
#  '[問卦] 要世界大戰了嗎？.txt',
#  '[問卦] 川普確診的時間點.txt',
#  '[問卦] 開戰後要打多久才能讓共匪喪失戰意？.txt',
#  '[新聞] 爆哭！吳宗憲現場骰子擲到這一面「小鬼真.txt',
#  'Re: [新聞] 婚姻和姓氏：妻隨夫姓為何在西方社會更為普遍.txt',
#  '[問卦] 辯論會的辯論人位置是社交距離嗎？.txt',
#  '[問卦] 翻墮羅拳接班人.txt',
#  '[新聞] 習近平思想 納入中國重點大學必修課  .txt',
#  '[問卦] 有湯瑪士小火車真人版的卦ㄇ.txt',
#  'Re: [問卦] 認真問 好市多卡值得辦嗎？.txt',
#  '[問卦] 怎樣才可以叫中國或北韓趕快打阿??.txt',
#  '[問卦] 台北人連假會去哪裡玩的八卦.txt',
#  '[問卦] 台灣空軍升空驅離共機有必要嗎??.txt',
#  '[問卦] 中國484完了.txt',
#  'Re: [問卦] 台女寧可老了無人照顧也不願嫁普台男?.txt',
#  '[協尋] 桃園交通事故，請大家幫幫忙.txt',
#  'Re: [問卦] 台南的50嵐也太少了吧？？.txt',
#  'Re: [問卦] 瘋狂十月開始了嗎？.txt',
#  '[問卦] 大蛇丸是不是也得肺炎？.txt',
#  '[新聞] 何志偉提美豬總量管制 蔡英文不語、中常.txt',
#  '[問卦] 發現自己對別人的悲慘無感，怎麼釋懷？.txt',
#  '[新聞] 林智堅表態不選新北市長 侯友宜：好人才.txt',
#  '[問卦] 廢大學改科大會重返農藥嗎?.txt',
#  '[問卦] 周一上午要怎麼搶7?.txt',
#  '[新聞] 營養午餐文宣遭疑宣揚瘦肉精 教育部要求.txt',
#  '[問卦] 潘瑋柏 瘦子Ozi.txt',
#  '[問卦] 禮拜一台股開盤要馬上把股票賣掉嗎？.txt',
#  '[新聞] 台灣大道違停昨害死18歲女大生\u3000扯！貨車今又再犯.txt',
#  '[問卦] 欸幾年沒放過颱風假了？.txt',
#  '[爆卦] 解放軍:台灣地區不要干擾我正常行動！.txt',
#  '[新聞] 國民黨推台美復交…國台辦崩潰了 江啟臣.txt',
#  'Re: [新聞] ATM領2萬少8千...求助遭疑「妳動手腳」.txt',
#  '[新聞] 美50名參議員致函川普政府 敦促展開台美BTA談判.txt',
#  '[問卦] 是不是有重大事件就是ptt的價值發揮的時.txt',
#  '[問卦] 怎麼做選擇啊 ?.txt',
#  '[問卦] 有沒有川普都不戴口罩很沒水準的八卦.txt',
#  '[問卦] 為什麼有錢人愛打高爾夫.txt',
#  '[問卦] 台灣怎麼不全民當兵?.txt',
#  '[新聞] 內衣女模遭硬塞\u3000胸部驚見「異物」！闆娘.txt',
#  'Re: [問卦] 宮廟8+9會上ptt嗎？.txt',
#  'Re: [新聞] 康軒傳開除「吹哨者」未付66萬資遣費\u3000新北下午登總部勞.txt',
#  '[問卦] 有沒有一姆三分咪的八卦？.txt',
#  '[問卦] 台灣人為什麼排斥當兵上戰場呢？.txt',
#  'Re: [問卦] 川普第一次參加選舉就能當選美國總統？.txt',
#  '[問卦] 台灣真的很多積非成是的事嗎?.txt',
#  '[問卦] 商圈一堆女性品牌服飾到底誰在買的？.txt',
#  '[問卦] 美國總統死於武漢肺炎的話這仇多大.txt',
#  '[問卦] 為什麼白石麻衣的影片出現的是白石茉莉奈.txt',
#  '[問卦] 拜登現在宣布自己確診還有救嗎?.txt',
#  '[新聞] 獨家》教室冷氣跳電停機一個月 高市國小.txt',
#  '[新聞] 國小菜單驚見瘦肉精文宣挨轟\u3000北市教育.txt',
#  '[問卦] 慟！Fighter 6停產了.txt',
#  '[新聞] 確診者在身邊？ 新APP將發出警告.txt',
#  '[問卦] 現在沒人在說很台了嗎.txt',
#  '[新聞] 高雄全套店收三倍券 更自製「振興折200券.txt',
#  'Re: [問卦] 健身房教練好賺嗎？.txt',
#  '[新聞] 川普夫婦確診新冠肺炎 副總統潘斯：為他.txt',
#  '[新聞] 拍妻絲襪辣腿…遭轟死變態！尪1句反擊 冉.txt',
#  '[問卦] 拜登應該嚇死了吧.txt',
#  '[問卦] 川普推特宣布中標前會先操作股票嗎？.txt',
#  '[公告] 多篇無關推噓文 水桶.txt',
#  '[問卦] 有多少女生主動跟你說中秋節快了啊?.txt',
#  '[問卦] 有沒有Reddit都在慶祝川普確診的八卦.txt',
#  '[問卦] 欸 在麥當勞丟垃圾 不分類的都什麼人.txt',
#  'Re: [問卦] 認真問被比特犬攻擊如何自保或反擊.txt',
#  '[爆卦] 台彩刮刮樂的設計者的都不讀書嗎？.txt',
#  '[問卦] 碩士念什麼所最慘？.txt',
#  '[問卦] 為什麼冰淇淋紅茶是給粗吸管啊.txt',
#  '[公告] 中秋連假線上烤肉兼置底聯誼閒聊區.txt',
#  'Re: [問卦] 台灣就這麼小 為什麼這麼塞?.txt',
#  '[問卦] =.= 有沒有賣塊公務員油土伯阿神的八卦.txt',
#  'Re: [問卦] 民主黨派拜登是不是看美國人沒有.txt',
#  'Re: [新聞] 何博文95％得票當選新北黨部主委 叫陣2022綠.txt',
#  '[問卦] 看到俯衝轟炸機衝過來的士兵在想啥？.txt',
#  '[問卦] 台灣情趣用品店怎麼那麼多？.txt',
#  '[問卦] 學弟想面交.txt',
#  '[問卦] 唐綺陽預言很準的八卦.txt',
#  '[問卦] 有沒有什麼歌是台灣國慶應該必唱的？.txt',
#  '[問卦] 中共到底紀念孫中山幹嘛？.txt',
#  '[問卦] 私立大學分前後段是不是假議題？.txt',
#  '[問卦] 拿熟女穿一天的絲襪來尻槍是什麼感覺.txt',
#  '[問卦] 如果是普丁中標的話?.txt',
#  '[新聞] 35隻猴子打群架\u3000踩塌樓房壓死屋主和工人.txt',
#  '[新聞] 吃完牛肉麵稱「老闆送錯了」奧客只付陽春.txt',
#  'Re: [問卦] 有沒有健美是否真的很美的八卦.txt',
#  '[問卦] 老闆怎麼還不放蝦.txt',
#  '[問卦] 27歲 人生終於到盡頭了.txt',
#  'Re: [新聞] 陳廷寵「國軍戰力零」論 吳斯懷：憲法言.txt',
#  '[問卦] 一般人可以把hangten穿得很潮嗎.txt',
#  '[新聞] 傳柯文哲一度想出席！國慶日退將辦「反台.txt',
#  '[問卦] 烤懶較怎麼烤才好吃.txt',
#  '[問卦] 鄉民會眼皮跳嗎.txt',
#  '[問卦] 翻車魚484海裏的渡渡鳥牙?.txt',
#  '[問卦] 甚麼是快樂？.txt',
#  '[新聞] 反駁賣台\u3000周錫瑋：國民黨什麼時候對大.txt',
#  '[問卦] 「藝FUN券」算是免洗APP嗎?.txt',
#  '[新聞] 大象絕望嚼食垃圾!攝影師跟蹤骨瘦如柴的.txt',
#  '[問卦] 中秋禮金只有200怎辦.txt',
#  'Re: [問卦] 台灣空軍升空驅離共機有必要嗎??.txt',
#  '[問卦] 城市尋寶是個什麼樣的活動.txt',
#  'Re: [新聞] 預告十月還有「震撼死亡」事件！唐綺陽.txt',
#  '[問卦] 川普武漢肺炎確診對他美國總統連任有利?.txt',
#  '[問卦] 中秋連假第二天應該沒人會噓了吧？.txt',
#  'Re: [問卦] 台灣怎麼不全民當兵?.txt',
#  '[新聞] 揚言殺孩子、打斷親生女兒腿 法官准惡爸.txt',
#  '[新聞] 每月捐薪水1%\u3000永達保經8年捐64輛長照專車.txt',
#  'Re: [問卦] 台灣可以做出IC 卻做不出汽車？.txt',
#  '[問卦] 沒塞車是不是大家改雙十才出遊啊？.txt',
#  '[問卦] 你說自由就像一陣風.txt',
#  '[問卦] 拜登中標的機率？.txt',
#  '[問卦] 川普是高危險族群吧！.txt',
#  '[問卦] 羅志祥在微博慶賀雙節的八卦？.txt',
#  '[問卦] 簡體字為了掃盲是不是智障的作法?.txt',
#  '[問卦] 肥宅的嘔吐物能賣多少？.txt',
#  '[問卦] 約克羊會看綿羊料理嗎.txt',
#  '[問卦] 有沒有芭樂特的八卦？.txt',
#  '[問卦] 現在還有人固定14天買全家人的口罩嗎.txt',
#  'Re: [問卦] 哪個智障設計環狀線新埔彎板橋的?.txt',
#  '[問卦] 誰能接下川普的黃金精神?.txt',
#  '[問卦] 現在換成彭斯的話，中國會有多慘呢？.txt',
#  '[新聞] 局長遭爆料！軍情局駁斥醜聞不排除提告 .txt',
#  '[問卦] 為何雪隧昨天一路暢通？？.txt',
#  '[問卦] 小心「港版國安法」地雷.txt',
#  'Re: [問卦] ‘’和平‘’是不是根本不可能？.txt',
#  '[問卦] 為什麼禿頭會有大鬍子？.txt',
#  '[問卦] 肖戰為什麼沒有出現在中秋晚會上？.txt',
#  '[問卦] 川普選舉花招是不是一直學台灣？.txt',
#  '[問卦] 該請美國爸爸來臺灣治療了吧？.txt',
#  '[問卦] 隔壁女鄰居來借幾包麵？該借嗎.txt',
#  'Re: [問卦] 哈根達斯到底貴不貴阿??.txt',
#  '[問卦] 女生要的很簡單 到底多簡單？.txt',
#  '[新聞] 老翁開賓士撞上16輛汽機車 自稱「閃車才.txt',
#  '[問卦] 古代真的有可能把城門撞開嗎？.txt',
#  '[問卦] 第一次坐捷運要注意什麼.txt',
#  'Re: [問卦] 愛莉莎莎算是PTT反串的巔峰嗎？.txt',
#  'Re: [爆卦] 央行副行長：房地產不是台灣經濟火車頭！.txt',
#  '[問卦] 美國的華萊士有倒在地上哭嗎？.txt',
#  'Re: [新聞] 川普確診「躺棺材」曝光！美網友貼辛普森.txt',
#  '[新聞] 藍營提案「台美復交」 蔡英文疑問：國民.txt',
#  '[問卦] 川普體內病毒在想什麼？.txt',
#  '[問卦] 臺灣如果有顆核彈是不是中國就閉嘴了.txt',
#  '[問卦]中國軍機靠近台灣若被打下 他們敢開戰？.txt',
#  '[問卦] 美國總統有病被隔離時可射核彈嗎？.txt',
#  'Re: [新聞] 川普夫婦確診陸網嗨爆！直衝微博熱搜第一.txt',
#  '[問卦] 川普推特為什麼一堆阿姆哈拉文推文？.txt',
#  '[問卦] 隨便說三個玩過三年的遊戲.txt',
#  '[爆卦] 幕僚確診後 川普跑去參加餐會.txt',
#  'Re: [問卦] 台灣即將被中國統一.txt',
#  'Re: [問卦] 原來台灣仇女的這麼多，我好震驚.txt',
#  'Re: [新聞] 海邊漂來「怪香黑石」！送檢報告出爐「就.txt',
#  '[新聞] 勤洗手防疫台北市每人每日家庭用水量創10.txt',
#  '[問卦] 還有什麼新聞可看啊.txt',
#  '[問卦] 滿手台積電的還吃得下烤肉嗎？.txt',
#  '[新聞]解放軍何時會攻打台灣沈富雄預測：起碼還要30年.txt',
#  '[問卦] 美國人會怎麼跟中國算帳？.txt',
#  '[問卦] 今天為什麼要降半旗.txt',
#  'Re: [問卦] 現在舔共最成功的是誰.txt',
#  '[問卦] 為啥川普確診一堆人po限時動態？.txt',
#  '[問卦] 以後下基地會全部都是教召老兵嗎?.txt',
#  '[問卦] 五星旗現在哪裡可以買？.txt',
#  '[問卦] 有沒有後XX的八卦？.txt',
#  '[問卦] 慟！中秋連烤4天肉，到現在還沒拉屎！.txt',
#  'Re: [問卦] 可以一人一信到白宮建議我川嗎？.txt',
#  'Re: [新聞] 中共不是祖國？蔡正元歷史分析 「中國確.txt',
#  'Re: [新聞] 五星旗亂象》防中共藉言論自由統戰.txt',
#  '[問卦] 亞美尼亞女現在願意嫁給台男嗎.txt',
#  '[問卦] 中共小粉紅很想跟美國打戰啊？.txt',
#  '[問卦] 胡天蘭吃到美豬會說什麼？.txt',
#  '[問卦] 為什麼勁舞團當年會很多人玩.txt',
#  '[新聞] 美國總統川普與第一夫人梅蘭妮亞新冠肺.txt',
#  '[問卦] 地錯好看嗎?.txt',
#  '[問卦] 咱們817覺青不怕打仗.txt',
#  '[問卦] 30歲前年收300萬的人生活是什麼樣子.txt',
#  '[問卦] 等下班的垃圾時間可以幹嘛.txt',
#  '[問卦] 假設中共潛艦來投誠 要收嗎?.txt',
#  '[問卦] 如果立法院拍youtobe開頻道有搞頭嗎？.txt',
#  '[問卦] 有大腸鏡跟胃鏡都做過的鄉民嗎？.txt',
#  '[問卦] 為什麼不讓機車在內車道.txt',
#  'Re: [問卦] 有沒有手很小男生的八卦？.txt',
#  '[問卦] 川普跟拜登可能進入四人賭命賽？.txt',
#  '[問卦] 愛莉莎莎仙氣側臉，網驚呼：臺灣IU.txt',
#  '[新聞] 快訊／川普夫婦確診新冠肺炎 即刻開始隔.txt',
#  'Re: [問卦] 真的有人幹過羊嗎.txt',
#  '[問卦] iPhone的記憶體會不會少得可憐啊.txt',
#  '[問卦] 妳的網誌成了我秘密基地.txt',
#  '[問卦] 我的經歷是中國社會的縮影嗎？.txt',
#  'Re: [問卦] 認真問 人一天可以走幾公里呀？.txt',
#  '[新聞] 熱戀ing衝公廁纏綿！男大生慘挨告\u300012歲.txt',
#  '[問卦] 請問有沒有防貓貓搶飯的方法.txt',
#  'Re: [問卦] 美豬進口台灣，誰會去代理經銷啊？.txt',
#  '[問卦] 美式豬肋排要用美豬還是台豬啊？.txt',
#  '[問卦] 哪個地區的麻將最智障？哪個最講技術？.txt',
#  'Re: [問卦] 台灣牛為什麼大多不做牛排用？.txt',
#  'Re: [問卦] 陸客多久沒來了台灣也沒怎樣.txt',
#  'Re: [問卦] 基隆以後適合長住嗎？.txt',
#  '[問卦] 為什麼川普中標推特下 一堆奇怪圖片?.txt',
#  '[問卦] 融資是什麼意思阿.txt',
#  '[爆卦] 最新美國6大搖擺州民調 川普選情持續穩定.txt',
#  '[問卦] 四大科缺人 是哪四大？.txt',
#  '[問卦] 孤單的朋友看到烤肉動態要來參加 怎辦.txt',
#  '[問卦] 女生都怎麼玩肥宅的雞雞？☺☺☺.txt',
#  '[新聞] 機車路考沒過！他「誇張180度大擺頭」網.txt',
#  '[問卦] 所以匝道上國五大概要塞多久啊？.txt',
#  '[問卦] 中獎反而更賭爛？？？.txt',
#  '[問卦] 健身房教練好賺嗎？.txt',
#  '[問卦] 台灣的房子那麼醜，建築師要負一半責任吧.txt',
#  '[問卦] 對不起我騙了妳.txt',
#  '[問卦] 富堅有沒有考慮畫完獵人.txt',
#  '[問卦] 南港為什麼在北部.txt',
#  '[問卦] 演化後為什麼要一公一母才可以繁衍.txt',
#  '[問卦] 乾脆抓監獄重刑犯和8+9充軍不就好了？.txt',
#  '[問卦] 川普推特留言發生什麼事？.txt',
#  '[問卦] 連鎖拿鐵喝哪家?.txt',
#  '[問卦] 兒子藏老媽食物被發現 老媽要不爽多久??.txt',
#  'Re: [爆卦] 恭喜警察被記申誡喔！.txt',
#  '[協尋] 台北市內湖區樂群二路265巷路口 行車紀錄.txt',
#  'Re: [新聞] 蘇貞昌：自己國家自己守，自己國家自己.txt',
#  '[問卦] 如果我川跟拜登都中標美國要怎麼辦？.txt',
#  'Re: [問卦] 川普的票倉其實在台灣吧？.txt',
#  '[問卦] 高爾夫球跟賽車誰更無聊.txt',
#  'Re: [問卦] 愛莉莎莎文484廢文.txt',
#  'Re: [新聞] 教召不夠！陳玉珍提「金門民防自衛隊」.txt',
#  '[問卦] 川普防疫能力是不是蠻猛的啊？.txt',
#  '[問卦] 吳剛是不是隔壁老王.txt',
#  '[問卦] 我川不是有天天吃奎寧？.txt',
#  '[問卦] 哆啦a夢的道具有被報導過幾次??.txt',
#  '[問卦] 川普現在最想見誰?.txt',
#  'Re: [問卦] 黑嘉嘉2010 vs 黑嘉嘉2020 大家選哪個?.txt',
#  '[爆卦] [疫情] 全球死亡創紀錄 爆出巨量阿根廷.txt',
#  '[問卦] 梅子綠有推薦的嗎.txt',
#  '[問卦] 教授484不喜歡待在學校？.txt',
#  '[新聞] 蘇貞昌不容許陳同佳自由來台 港議員：投案.txt',
#  '[問卦] 有沒有台北火車站的八卦.txt',
#  '[新聞] 豬農百億基金規劃出爐！ 陳吉仲︰46億升.txt',
#  '[問卦] 教授問我主流文化的特點.txt',
#  '[問卦] 駕照結合ETC，區分駕照路權?.txt',
#  '[問卦] 大家住的地方多久一次會抽水肥.txt',
#  '[新聞] 聖約翰遭控欠薪 校方：教師不願商議.txt',
#  '[問卦] 年薪140萬  台北市買房可以買哪裡.txt',
#  '[問卦] 全面攻佔4 劇本流出?.txt',
#  '[問卦] 這波如果在台灣 候選人會怎麼操作.txt',
#  '[問卦] 不想打仗幹嘛不跟中國講= =?.txt',
#  '[問卦] 台灣還有哪些景點有救.txt',
#  '[問卦] 古墓奇兵2018有無拍續集的卦.txt',
#  '[問卦] 買雙螢幕還是寬曲面螢幕？.txt',
#  '[問卦] 這算中國暗殺成功嗎？.txt',
#  '[問卦] 拜登現在在想什麼.txt',
#  '[問卦] 幹！有白目機車騎在禁行機車上.txt',
#  '[問卦] 「八卦板五毛」會不會是空氣稻草人.txt',
#  '[問卦] 瘋狂十月開始了嗎？.txt',
#  '[新聞] 陳廷寵以中國人為傲 吳斯懷謢航:言論自由.txt',
#  '[問卦] 為啥電動車還不能自動充電？.txt',
#  'Re: [問卦] 台女脫口秀只能靠黃色出名嗎.txt',
#  '[問卦] 認真問，長痔瘡怎麼辦...txt',
#  '[新聞] 35隻猴子打群架 踩塌樓房壓死屋主和工人.txt',
#  '[問卦] 女友叫我在她公司兩百公尺處等???.txt',
#  '[問卦] 魚的台語.txt',
#  '[新聞] 陳其邁首備詢就遇陳抗 網嘆:韓國瑜可是勇.txt',
#  '[問卦] 川普超沒水準都不戴口罩PTT還挺川普？.txt',
#  '[問卦] 國家太空中心是不是騙錢用的？.txt',
#  '[問卦] 噁茫啊斯是不是超好玩超心機.txt',
#  '[新聞] 川普下令解密通俄門調查所有文檔.txt',
#  '[問卦] 核彈投中國哪，台灣才不會被波及？.txt',
#  '[問卦] 正妹香味從哪來的.txt',
#  'Re: [問卦] 如果台灣出現超級英雄可以對抗中共嗎?.txt',
#  '[新聞] WTO上修2020世界貿易量，回復至減少9%.txt',
#  '[問卦] 根本就是以前太多智障用路人吧？.txt',
#  '[新聞] 營養午餐文宣挨批宣傳美豬 教部：食農教.txt',
#  '[問卦] 支那的生化戰是不是成功了？.txt',
#  '[新聞] 蓬佩奧：若中共攻台 美軍不會袖手旁觀.txt',
#  '[問卦] 習近平會怎麼回應關於川普中標這件事.txt',
#  'Re: [問卦] 習近平怎摸都沒事啊.txt',
#  '[新聞] 8歲時遭性侵身心受創 15年後打開心結將狼.txt',
#  '[新聞] 「準備」選國民黨主席 周錫瑋：與韓國瑜.txt',
#  '[問卦] 相機可以退場了吧?.txt',
#  '[問卦] 支那維尼.txt',
#  '[問卦] 有些地方坐高鐵是不是沒有比較快啊.txt',
#  '[問卦] 為何寧願買房也不跟父母住?.txt',
#  'Re: [新聞] 川普確診新冠肺炎 感染科醫：拜登危險了.txt',
#  'Re: [新聞] 婦科名醫麻醉性侵15分鐘3次 妻揭惡行：他.txt',
#  '[問卦] 土地被註銷編訂  我是不是要發大財惹?.txt',
#  '[問卦] 如果臺灣有一個航母戰鬥群.txt',
#  '[問卦] 當時蜀國怎麼不南下取緬甸、泰國？.txt',
#  '[問卦] 跟網友見面是直銷的八卦.txt',
#  '[新聞] 藍委提修社維法 毒駕、酒駕致死傷拘留3.txt',
#  'Re: [問卦] 川普打悲情牌會有人買單嗎？.txt',
#  '[問卦] 肥宅會假裝自己有去烤肉嗎？.txt',
#  '[問卦] 梁社漢好吃在哪.txt',
#  '[問卦] 現在是進場美股的時機嗎.txt',
#  '[問卦] 我~與 各位共清歡  我~笑 眾人看不穿 .txt',
#  '[問卦] 每天都要聽一次守望傳說廣告？.txt',
#  '[問卦] 如果川普輸了台灣會怎麼說中國的好?.txt',
#  'Re: [新聞] 五星旗亂象》防中共藉言論自由統戰 綠委.txt',
#  '[問卦] 台灣人工時高於韓國但年均卻低於韓.txt',
#  '[問卦] 為何有些蚊子寧可被打死也要吸血.txt',
#  '[問卦] 布丁浮在奶茶上面的八卦?.txt',
#  '[新聞] 蝦腳抱一排「橘色顆粒」 內行驚曝：吃完秒睡醫院.txt',
#  '[問卦] 美股是不是要爆漲了？.txt',
#  '[問卦] 為什要吃保健食品？.txt',
#  '[問卦] 歐美人不認真封城是不是智障？.txt',
#  '[新聞] 美眾議員提案：指定中共為跨國犯罪組織.txt',
#  '[問卦] 在田裡撿到刺蝟，該怎麼處置.txt',
#  '[問卦]乃木坂有可能像AKB一樣 讓10世代接班嗎？.txt',
#  '[問卦] 彭斯要接手總統大位嗎?.txt',
#  '[問卦] 你各位啊，老實說被統一又如何.txt',
#  '[問卦] 星街彗星的老公都給我進來.txt',
#  '[問卦] 有沒有高雄冠軍哥的八卦？.txt',
#  'Re: [問卦] 有沒有工作出過最大的包是什麼的八卦.txt',
#  '[新聞] 民團盼比照短期商務客模式 讓跨國伴侶有.txt',
#  '[問卦] 川普中鏢 支那現在很爽嗎.txt',
#  'Re: [問卦] 反對教召的人 到底都在怕什麼???????????.txt',
#  '[問卦] 川普確診是不是斬首行動成功了?.txt',
#  '[問卦] 各位每天用最久的app是哪個？.txt',
#  '[問卦] 不買星巴克可以去星巴克裡面坐著嗎？.txt',
#  'Re: [新聞] 博士畢業打零工7年 月入11K吃剩食度日.txt',
#  '[問卦] 你覺得罰歐陽娜娜50萬合理嗎？.txt',
#  '[問卦] 美國人484很懂談判？.txt',
#  'Re: [問卦] 有沒有台北人都很有愛心的八卦.txt',
#  '[問卦] 日本的鐵路比台灣進步很多.txt',
#  '[問卦] 今天上班怎麼打發時間好呢?.txt',
#  '[新聞] 高加索血戰破百死：亞美尼亞禁止役齡男.txt',
#  '[問卦] 為何美國沒有過女總統?.txt',
#  '[問卦] 有喜歡吃大蒜泥的嬰幼兒嗎.txt',
#  '[問卦] 川普中標是中共幹的吧？.txt',
#  '[問卦] 川普和拜登都死於肺炎會怎樣.txt',
#  '[問卦] 寫個"純" 是什麼意思.txt',
#  'Re: [問卦] 女大生被貨車輾死  自己問題也很大吧.txt',
#  '[爆卦] 中國新的實驗性疫苗證實安全有效.txt',
#  '[問卦] 保健食品怎麼挑啊？.txt',
#  'Re: [問卦] 為什麼持修的最佳新人獎點閱率這麼高？.txt',
#  '[問卦] 會去打工換宿的人腦中都在想甚麼阿.txt',
#  '[問卦] 血溶性貧血到底要禁鐵還是補充鐵.txt',
#  '[問卦] 可以帶十八禁抱枕去宿舍嗎?.txt',
#  '[問卦] 南投有人聽過阿霞蛋捲ㄇ.txt',
#  '[問卦] 一堆台大法律系的 卻處理不了歐陽娜娜？.txt',
#  '[問卦] 你不是怪物 別害怕 誰來欺負.txt',
#  'Re: [新聞] 塞怕了／用路人變聰明 主動做分流.txt',
#  '[問卦] 下午茶這樣100塊？.txt',
#  '[問卦] 真的有人幹過羊嗎.txt',
#  'Re: [新聞] 超愛吃肉乾！28歲女罹大腸癌\u3000醫曝研究.txt',
#  '[問卦] 醬油為什麼要用碟子啊.txt',
#  '[問卦] 為啥總有人以為交通亂很重要？.txt',
#  '[問卦] 戰爭時期殘忍殺害統畜會犯法嗎？.txt',
#  'Re: [問卦] 川普這招是奧步嗎?.txt',
#  '[問卦] 女朋友邀我去她家吃飯該注意什麼 ?.txt',
#  '[問卦] 川普的票倉其實在台灣吧？.txt',
#  '[問卦] 朋友這盒太陽餅是什麼意思.txt',
#  '[問卦] 有美國小鬼(黃鴻升)-范海倫的八卦嗎.txt',
#  '[新聞] 遭柯文哲批「說謊」 王世堅反嗆：liar憑.txt',
#  '[問卦] 川普被隔離 會視訊跟拜登辯論嗎？.txt',
#  '[問卦] 太守丁原為何敢偷襲董卓駐守洛陽的西涼兵.txt',
#  '[問卦] 為什麼海洋生物吃魚不怕魚刺.txt',
#  'Re: [爆卦] 2020年諾貝爾化學獎.txt',
#  '[問卦] 拜登是不是也要下去了阿.txt',
#  '[問卦] 為啥墨西哥在美國旁邊還那麼窮啊？.txt',
#  '[問卦] 強生會對川普說什麼？.txt',
#  '[問卦] 為什麼日本超商很多外國店員但台灣沒有？.txt',
#  '[問卦] 部隊的食物很難吃怎麼辦？.txt',
#  '[新聞] 北市東湖國小後方變電箱爆炸 民宅停電所.txt',
#  'Re: [新聞] 機車族不是人！ 中央擬取消人行道機車格.txt',
#  '[問卦] 美國現在會跪還是脆了？.txt',
#  '[問卦] 台南的50嵐也太少了吧？？.txt',
#  '[新聞] 魔音洗腦！美獄警逼受刑人聽2小時「Baby .txt',
#  '[新聞] 吉普車撞機車後逃逸 歐吉桑騎機車勇追5公里.txt',
#  '[爆卦] 川普中標韓國反應.txt',
#  '[問卦] 人類到底有沒有登陸月球過.txt',
#  '[問卦] 被UBER EAT嗆不要送上樓怎麼辦.txt',
#  '[問卦]關於適應極端氣候的問題 醫森醫學系生請進.txt',
#  'Re: [問卦] 敢讓鄉民看到你的IG首頁嗎?.txt',
#  'Re: [新聞] 開嗆！不罰歐陽娜娜\u3000柯批政府前後矛盾.txt',
#  '[問卦] 中共侵台，台灣黑道會是潛在內奸？.txt',
#  '[新聞] 與女友吵架竟放火燒她家 警調監視器揪出.txt',
#  '[問卦] baby shark為什麼能67億點閱率？.txt',
#  '[問卦] 以後飛彈是不是改用病毒就好.txt',
#  '[問卦] 無事不登三寶殿 是哪三寶.txt',
#  '[問卦] 單身宅適合加入烏伯外送的月費方案嗎？.txt',
#  '[新聞] 俄羅斯也嚴查中國竊密 俄國科學家被捕面.txt',
#  'Re: [問卦] 拜登超穩了吧？.txt',
#  '[問卦] 徵兵如果改這樣會不會一堆人簽？.txt',
#  '[問卦] 台灣就這麼小 為什麼這麼塞?.txt',
#  'Re: [新聞] 豬農百億基金規劃出爐！ 陳吉仲︰46億升.txt',
#  '[新聞] 真．海底撈機車！安全帽、輪框「全面鏽.txt',
#  '[問卦] 有沒有蔡康永在幹嘛的八卦 ??.txt',
#  '[問卦] 現在歌頌習近平來得及嗎.txt',
#  '[新聞] 藍喊台美復交 陳柏惟：可跟中國建交.txt',
#  '[問卦] 特斯拉484很夯?.txt',
#  '[問卦] 為什麼8+9這麼愛吃薑母鴨?.txt',
#  '[問卦] 美國總統民調到底要贏多少%才算穩?.txt',
#  '[問卦] 黑人祖宗為何走到亞洲屌就變小了.txt',
#  '[問卦] 體育系學弟帶很多酒要來我這喝 該拒絕嗎?.txt',
#  '[問卦] 911事件、川普死於武肺 那個比較嚴重？.txt',
#  'Re: [問卦] 川普中鏢 支那現在很爽嗎.txt',
#  '[問卦] 南韓人均GDP今年會跌破3萬鎂？.txt',
#  '[問卦] 夜よ 僕に歌わせるなよ.txt',
#  '[新聞] 女兵好悍！ 5字經怒嗆長官遭判罰1萬元.txt',
#  '[問卦] 這次武統新聞要掩蓋什麼.txt',
#  '[問卦] 冷氣一個人吹和兩個人吹電費有差嗎？.txt',
#  '[問卦] 拜登超穩的吧.txt',
#  'Re: [新聞] 爆哭！吳宗憲現場骰子擲到這一面「小鬼真.txt',
#  '[問卦] 現在開始舔共還來的及嗎??.txt',
#  '[新聞] 股市老師line揪團報明牌\u30003天崩盤16萬賠.txt',
#  'Re: [問卦] 閩南民系漢族的特徵是什麼？.txt',
#  '[問卦] 現在是不是血洗台灣最佳時機.txt',
#  'Re: [新聞] 陳廷寵以中國人為傲 吳斯懷謢航:言論自由.txt',
#  '[問卦] 綠粽跟紫米粽哪個好?.txt',
#  'Re: [新聞] 何志偉提美豬總量管制 蔡英文不語、中常.txt',
#  '[問卦] 會討論搭捷運討厭的人是不是都南部來的?.txt',
#  '[問卦] 選前一個月超級震撼彈！！.txt',
#  '[問卦] 滯台美國人會回去投票嗎.txt',
#  '[問卦] 去日本一定要買什麼東西？.txt',
#  '[問卦] Onlyfans有什麼推薦追蹤的帳號嗎？.txt',
#  '[問卦] 小穹的生日賀卡到啦>< (小穹陣線).txt',
#  '[問卦] 十個廣告七個是手遊.txt',
#  '[問卦] 去教召查詢系統查自己資料會被紀錄嗎？.txt',
#  'Re: [問卦] 有匿蹤戰機，怎麼匿蹤飛彈還沒做出來？.txt',
#  '[新聞] 竹聯幫內訌！萬華大亂鬥砍死人\u3000賭場利.txt',
#  '[問卦] 跟愛莉莎莎同房一晚給10萬  你ok嗎？.txt',
#  '[問卦] 中國大奶妹全來台灣是不是就和平統一了？.txt',
#  '[問卦] 社會上阿薩布魯的人也太多了吧？.txt',
#  'Re: [問卦] 川普如果真的中獎了這世界會發生什麼事.txt',
#  '[問卦] 沒人關心伊凡卡嗎？.txt',
#  '[問卦] 教召14天含放假嗎？.txt',
#  'Re: [問卦] 為什麼大學要開放哲學系出來害人.txt',
#  '[問卦] 咳三個月了怎麼辦.txt',
#  '[問卦] 地獄會不會只是另一個時空？.txt',
#  '[問卦] 是誰發現 香蕉 可以吃的.txt',
#  '[問卦] 五行密碼到底是啥？.txt',
#  '[問卦] 三年級學長特製的蔬菜汁很難喝.txt',
#  '[新聞] 中芯恐遭斷頭？英媒爆川普押錯籌碼.txt',
#  '[問卦] 川普死前會公開外星人秘密嗎.txt',
#  'Re: [爆卦] 川普中標.txt',
#  '[問卦] iPhone用兩年 就開始發燙.txt',
#  '[問卦] 中共高層看到川普中標在想什麼?.txt',
#  'Re: [問卦] 隔壁女鄰居來借幾包麵？該借嗎.txt',
#  '[問卦] 日月光的保全班長很爽??.txt',
#  'Re: [新聞] 獨家》教室冷氣跳電停機一個月 高市國小.txt',
#  'Re: [問卦] 為何學法律的大多支持廢死？.txt',
#  '[問卦] 美國連香港都救不了 怎麼幫台灣？.txt',
#  'Re: [新聞] 川普確診「躺棺材」曝光！美網友貼辛普.txt',
#  '[問卦] 流氓能買的起c300？賺錢能力超強？.txt',
#  '[問卦] 這碗鮭魚親子丼要多少？.txt',
#  '[新聞] 逼少年「DIY」 嫌太慢 輔導老師伸手「幫.txt',
#  '[問卦] 台男自願加班 有加分嗎？.txt',
#  '[問卦] 為什麼開始抽煙？.txt',
#  '[新聞] 藍營推萊牛卻反萊豬「可不可恥」？ 洪孟.txt',
#  '[問卦]宮廟辦桌要怎麼進去蹭飯? .txt',
#  '[爆卦] 川普中標.txt',
#  '[問卦] 新垣結衣幾歲結婚，鄉民OK爹斯?.txt',
#  '[問卦] 愛莉莎莎包養你 多少錢可以接受.txt',
#  'Re: [問卦] 在家裡雞腿都是誰吃.txt',
#  '[新聞] 上萬噸事業廢棄物亂丟中彰投 環保掮客羈.txt',
#  'Re: [問卦] 日本章魚燒好吃嗎？.txt',
#  '[問卦] 曼都髮型是花多少錢請代言人 ?.txt',
#  '[新聞] 朱利安尼:中共刻意讓病毒破壞世界 形同戰.txt',
#  'Re: [新聞] 慕尼黑房市 泡沫風險冠全球.txt',
#  '[問卦] 應付教召有需要練身體嗎？.txt',
#  '[問卦] 有人機車騎上快速道路過嗎.txt',
#  '[問卦] 有沒有Genshin Impact 廣告做得不錯的八.txt',
#  '[問卦] 歷史上有沒有女人做了亡國之君.txt',
#  'Re: [問卦] 現在不流行清純玉女，而是前衛敢言女生嗎?.txt',
#  'Re: [新聞] 色教練慣對男童打手槍拍裸照\u3000自稱不只.txt',
#  '[問卦] 共機飛過來  不理它會怎樣嗎？.txt',
#  '[問卦] 2020爆發WW3是不是機率很高啊?.txt',
#  '[新聞] 昌鴻增強為中颱！最新路徑曝光大迴轉北上.txt',
#  'Re: [問卦] 台灣人為什麼排斥當兵上戰場呢？.txt',
#  '[問卦] 新竹高鐵站附近機車停車是不是狗幹貴?.txt',
#  '[問卦] 老闆說因為疫情不辦尾牙了？.txt',
#  'Re: [新聞] 「不管你說什麼，我反戰！」龍應台怒批.txt',
#  'Re: [問卦] 27歲 人生終於到盡頭了.txt',
#  '[問卦] 早餐吃烤肉吐司的人多嗎（在線吃.txt',
#  '[問卦] 肥宅學蕭敬騰穿打洞的牛仔褲會變潮男嗎？.txt',
#  '[新聞] 失蹤近2年\u3000議員爆：北韓前駐義國趙姓大.txt',
#  'Re: [問卦] 正妹香味從哪來的.txt',
#  'Re: [問卦] 尿尿有泡泡.txt',
#  '[新聞] 為明年台灣燈會 交通部長林佳龍參訪新竹.txt',
#  '[新聞] 學雜費凍漲15年 私大校長砲轟：干涉大學.txt',
#  'Re: [新聞] 立院初審 調戲同性最高可處6000元罰鍰  .txt',
#  '[問卦] 怎麼觸發分泌荷爾蒙.txt',
#  '[新聞] 史上首次「撲空」進入枯水期 桃竹苗台中4.txt',
#  'Re: [問卦] 中共到底紀念孫中山幹嘛？.txt',
#  '[新聞] 微軟計畫投資10億美元 雅典建3座資料中心.txt',
#  '[問卦] 一天有10分鐘該訓練何種能力的八卦?.txt',
#  '[問卦] 彭斯和賀錦麗誰最有機會當選總統.txt',
#  '[問卦] 有沒有諾貝爾獎排華的八卦？.txt',
#  '[新聞] 中山高湖口服務區驚傳隨機砍人 看惡煞一.txt',
#  '[問卦] 印度仔躺分就對了？.txt',
#  '[問卦] 川普有權力公佈51區的秘密嗎？.txt',
#  'Re: [問卦] 現實世界要怎麼拐走有錢人的未婚妻.txt',
#  '[問卦] 預購到PS2有多爽？.txt',
#  '[公告]十月份置底閒聊區      .txt',
#  '[問卦] 是先有妹妹還4先有弟弟啊?.txt',
#  '[問卦] 最後川普沒事，而梅蘭妮雅GG，會如何？.txt',
#  '[問卦] PTT十年後會像無名小站那樣關閉嗎?.txt',
#  '[新聞] 婦科名醫麻醉性侵15分鐘3次 妻揭惡行：他.txt',
#  '[問卦] 豆導會怎麼拍鬼滅真人版.txt',
#  '[問卦] 辛普森家庭想暗示什麼？.txt',
#  '[問卦] 飲料店根本不甩禁用塑膠吸管？.txt',
#  'Re: [問卦] 百度鎖臺灣ip是不是分裂國家？.txt',
#  '[新聞] 驚險！92歲老翁遭水泥車撞捲進車底 差幾.txt',
#  '[問卦] 失去雙手的退役軍人可以做什麼工作？.txt',
#  '[問卦] 要怎麼求雨？.txt',
#  '[爆卦] 花敬群:有人把我沒說過的渾話栽贓給我.txt',
#  '[問卦] 川普的十月驚奇是不是夠驚奇？.txt',
#  '[新聞] CNN:中國控制住了疫情 如今上億人開始同.txt',
#  '[問卦] 欸欸為何吃火龍果大便會是紅的.txt',
#  '[問卦] 希拉蕊已經準備好了嗎？.txt',
#  'Re: [問卦] 承認怕死是一種罪???.txt',
#  '[新聞] 桃園砸1950萬元辦萬聖節觀光活動 民代批.txt',
#  '[問卦] 現在郵局物流是不是很閒啊？.txt',
#  'Re: [新聞] 許光漢十一發文「睡一下」 遭中網出征扣.txt',
#  '[問卦] 有沒有手很小男生的八卦？.txt',
#  'Re: [問卦] 沒人想上戰場，最後應該會統一吧?.txt',
#  '[新聞] 陳廷寵辦台商學校年領6000萬政府補助.txt',
#  'Re: [問卦] 為什麼大雄的曾曾孫沒有不見？.txt',
#  '[問卦] 台灣484跟自由行星同盟越來越像惹.txt',
#  '[問卦] 我朋友打雪仗害死同事.txt',
#  '[問卦] 台灣為何沒有UberBike或GrabBike???????.txt',
#  '[問卦] 川普不是自豪美國防疫NO.1 結果自己確診?.txt',
#  '[問卦] 店家數學不好的八卦？.txt',
#  '[問卦] 湯底的四種，鄉民覺得哪個最好.txt',
#  '[問卦] 千千跟lulu怎在比賽大胃王 卦.txt',
#  '[問卦] 台女寧可老了無人照顧也不願嫁普台男?.txt',
#  '[問卦] 澎湖的街景怎麼能那麼乾淨.txt',
#  '[問卦] 到好市多有什麼必買的.txt',
#  '[新聞] 疑女友中秋夜跑去跟新歡烤肉 醋男尾隨撂.txt',
#  '[問卦] 有沒有長大就不挑食的八卦.txt',
#  '[新聞] 諾貝爾化學獎 2名女學者研究基因編輯共享殊榮.txt',
#  '[問卦] 美國鐵板紅藍州的少數選民在想什麼？.txt',
#  '[問卦] 不管我的靈魂 困在哪個肉身....txt',
#  '[問卦] 南部這樣的內容物 110合理嗎？.txt',
#  'Re: [新聞] 國民黨團提案「台美回復邦交」 立法院無.txt',
#  '[問卦] 新娘來敬酒 拉住我衣袖又放開讓我走 怎辦.txt',
#  '[爆卦] 支那垃圾賤畜集體高潮.txt',
#  'Re: [問卦] 吳剛跟嫦娥怎麼在月球上烤肉.txt',
#  'Re: [問卦] 融資是什麼意思阿.txt',
#  '[問卦] 內湖區的東湖大停電，能幹嘛    .txt',
#  '[問卦] 在台灣活得這麼爽 台灣哪可能輸出？.txt',
#  '[新聞] 違規左轉害死重機大學生情侶檔 預拌水泥.txt',
#  '[問卦] 露營初新手從哪開始起步比較好的八卦阿？.txt',
#  '[問卦] 有沒有拉姆齊Ramsay的八卦.txt',
#  '[新聞] 平林社區性平小旅行 帶動疫情後雙溪觀光.txt',
#  '[問卦] 每個診所醫生都台大主治的八卦.txt',
#  '[新聞] 「深入敵營」你儂我儂親密互動 林俊憲親.txt',
#  '[問卦] 有沒有哆啦a夢在武肺期間還破紀錄的八卦.txt',
#  '[問卦] 侯昌明的代表作是什麼?.txt',
#  '[問卦] 無人機是不是證明戰車坦克真的無用了??.txt',
#  '[問卦] 蛋黃酥是不是月餅中的經典？.txt',
#  'Re: [問卦] 台灣主權未定論的說法是不是有問題呢？.txt',
#  '[問卦] 以後要叫子孫燒獵人還是浪人劍客?.txt',
#  '[問卦] 川普死掉會怎樣.txt',
#  '[問卦] 感覺行為沉淪了怎麼辦.txt',
#  '[新聞] 又出包!實名制口罩僅2層沒有熔噴不織布.txt',
#  '[問卦] 川普第一次參加選舉就能當選美國總統？.txt',
#  '[新聞] 男拾獲疑「龍涎香」石頭 鑑定結果出爐「.txt',
#  '[問卦] 金剛:骷顱島 它:第二隻 這種片都誰在看的.txt',
#  '[問卦] 家裡跑出野生螃蟹怎麼辦.txt',
#  '[問卦] 連罵人的嘴型也要馬賽克了嗎？.txt',
#  '[問卦] 病毒戰有多可怕.txt',
#  '[新聞] 高市國小冷氣跳電停機1個月！網讚柯文哲.txt',
#  '[協尋] 瑞光路一段 民生東路 行車記錄器.txt',
#  '[問卦] 哈根達斯到底貴不貴阿??.txt',
#  '[問卦] 同事出去烤肉你自己留下來吃肯德基.txt',
#  '[問卦] 退伍超過八年到底會不會被教召？.txt',
#  '[問卦] 嘴唇乾裂怎麼辦.txt',
#  '[新聞] 「今晚我想來點....」毒蟲異想天開 竟偽.txt',
#  '[問卦] 台灣人一輩子要看幾遍食神？.txt',
#  '[問卦] 台灣484押錯邊了?.txt',
#  '[問卦] 田壘居然還是現役選手？.txt',
#  '[問卦] 開店賣薑母鴨好賺嗎?.txt',
#  'Re: [問卦] 同事出去烤肉你自己留下來吃肯德基.txt',
#  'Re: [問卦] 該挺亞美尼亞 還是亞塞拜然?.txt',
#  '[問卦] 有沒有彭恰恰個人債務問題的八卦.txt',
#  'Re: [問卦] 欸 在麥當勞丟垃圾 不分類的都什麼人.txt',
#  '[新聞] 何志偉綠中常會提美豬總量管制 莊瑞雄：.txt',
#  '[問卦] 中國現在在想什麼？.txt',
#  '[問卦] 101國慶日出生要取什麼名字.txt',
#  '[問卦] 年輕人月光族因為很愛享受?.txt',
#  '[問卦] 志玲姐姐說的雙節合一是哪雙節？.txt',
#  '[問卦] 為什麼8+9的女人都這麼瘦啊？.txt',
#  '[問卦] 可以拿新槍  大家4不4很開心?.txt',
#  '[新聞] 台南黃金海岸淪垃圾海岸\u3000中國媒體諷：這.txt',
#  '[問卦] 川普打悲情牌會有人買單嗎？.txt',
#  'Re: [問卦] 記憶體2133 2666 3200差別在哪?????掛???.txt',
#  '[新聞] 「天然木瓜牛奶」論壇約壞 一伸手下秒慘.txt',
#  '[問卦] 日本章魚燒好吃嗎？.txt',
#  '[問卦] youbike 分不同齒數可行嗎.txt',
#  '[新聞]四方安全對話 印度自信滿滿：空軍已經隨.txt',
#  '[問卦] 很多人喜歡在火車或高鐵借網路？.txt',
#  'Re: [問卦] 台灣的房子那麼醜，建築師要負一半責任吧.txt',
#  '[問卦] 要怎麼和自尊心強到不認錯的三寶溝通？.txt',
#  '[問卦] 川普挺台應該幫台灣收購 FIAT-克萊斯勒.txt',
#  '[問卦] 如果戰爭的話，你（個人）會投降嗎？.txt',
#  'Re: [爆卦] 支那垃圾賤畜集體高潮.txt',
#  'Re: [新聞] 70歲婦罹胰臟癌「沒特殊感覺」\u3000腹脹就醫.txt',
#  '[問卦] 有當兵會被學長叫去幫狗打手槍的八卦嗎?.txt',
#  '[問卦] 教主有抽到魔關羽了嗎？.txt',
#  'Re: [新聞] 為囤房稅與老議員互槓\u3000呱吉爆氣：別唧唧.txt',
#  '[問卦] 百萬車你會選哪台?.txt',
#  '[爆卦] 拜登1991年時稱2020時我極可能已死了.txt',
#  '[問卦] 可以一人一信到白宮建議我川嗎？.txt',
#  '[問卦] 在711吃飯開直播的網美.txt',
#  '[問卦] 美國大選辯論，主持人華勒斯現在在想啥.txt',
#  '[問卦] 被漆彈打到是有多痛啊.txt',
#  '[新聞] 火星真有生命存在？ 義大利科學家宣稱火.txt',
#  '[問卦] 永恆的瞬間該怎樣保存?.txt',
#  '[問卦] 月老這麼靈，各位肥宅怎麼還單身？.txt',
#  'Re: [問卦] 男女版為啥又再吵AA.txt',
#  '[問卦] 老大 口水戰真的有用耶.txt',
#  '[問卦] 為何共匪軍機擾台 我們要出動驅逐？.txt',
#  '[問卦] 美國不開戰！總統總統染疫難道吞下去.txt',
#  '[問卦] 川普中標 五毛高潮？.txt',
#  '[新聞] 川普拒絕「改變辯論形式」：我上次輕鬆.txt',
#  'Re: [新聞] 機車族不是人！ 中央擬取消人行道機車格 .txt',
#  'Re: [爆卦] 最新防疫成功國家排名 中國第一 台灣榜外 .txt',
#  '[問卦] 共機擾台 可以用雷達鎖定嗎？.txt',
#  '[問卦] 我川是不是要出招了?.txt',
#  '[問卦] 認真問 準備電機研究所大概要多久？？.txt',
#  '[爆卦] 中秋夜，我家門口有人自撞.txt',
#  '[爆卦] 台灣上華盛頓郵報…的標題.txt',
#  '[問卦] 愛莉莎莎刻在你心底的名字.txt',
#  '[問卦] 月收50萬在鄉下是什麼等級.txt',
#  '[問卦] 台女脫口秀只能靠黃色出名嗎.txt',
#  '[問卦] 憑實力發爆文是不是滿強的？.txt',
#  '[新聞] 佛心來的！全台唯一「特斯拉小黃」在新竹.txt',
#  'Re: [問卦] 台灣484押錯邊了?.txt',
#  'Re: [問卦] 現在還有人固定14天買全家人的口罩嗎.txt',
#  '[問卦] 愛莉莎莎居然還沒男友？ 怎麼解釋.txt',
#  '[問卦] 美軍 CIA 現在在幹嘛？.txt',
#  '[問卦] 沒人想上戰場，最後應該會統一吧?.txt',
#  '[問卦] 女生會愛看軍教片嗎.txt',
#  'Re: [問卦] 隨便說三個台中的美食！.txt',
#  '[問卦] 川普中標，週一台股怎麼玩？.txt',
#  '[新聞] 深夜驚魂！妙齡女遭尾隨200米\u3000急叩男友.txt',
#  '[新聞] 他說了什麼讓蔡英文一語不發?.txt',
#  '[問卦] 工程師該開什麼等級的車？.txt',
#  '[新聞] 背女友偷吃同校妹「6天做3次」！專科男.txt',
#  '[問卦] ‘’和平‘’是不是根本不可能？.txt',
#  '[問卦] 鳴人共使出多少次影分身？.txt',
#  '[問卦] 中國人：川普一死 下個就換台灣.txt',
#  '[問卦] 捷運上的國中妹偷喝飲料怎麼辦?.txt',
#  '[問卦] 大家國慶連假有出遊嗎？.txt',
#  '[問卦] 記憶體2133 2666 3200差別在哪?????掛???.txt',
#  '[新聞] 色男持刀白嫖強盜按摩女\u3000留100元給她吃.txt',
#  '[問卦] 貓貓要怎麼料理？.txt',
#  '[問卦] 台灣自行車廠為什麼比汽車強那麼多？.txt',
#  '[協尋] 高雄前金區 黑白貓小蜜(代po).txt',
#  '[問卦] 能免役要免役嗎.txt',
#  '[新聞] 川普夫婦確診 羅友志驚喊：美國版的兩顆.txt',
#  '[問卦] 絕版的書自行列印會觸法嗎？.txt',
#  '[問卦] 中國人的傳統美德都到哪兒去了？.txt',
#  '[新聞] 水情拉警報 桃竹苗台中4區域下週三起實施.txt',
#  'Re: [問卦]中國軍機靠近台灣若被打下 他們敢開戰？.txt',
#  'Re: [問卦]中國軍機靠近台灣若被打下 他們敢開戰.txt',
#  '[問卦] 台灣豬標章得獎作者：綠色代表安全.txt',
#  '[問卦] hebe的唱腔 怎麼越來越奇怪.txt',
#  'Re: [問卦] 可以開川普中標的賭盤嗎？.txt',
#  '[問卦] 現實世界要怎麼拐走有錢人的未婚妻.txt',
#  '[問卦] 裝病.txt',
#  '[問卦] 川普中標或是自導自演的fake news?.txt',
#  'Re: [問卦] 同學台大數學想休學怎麼辦?.txt',
#  '[問卦] Cyberpunk到底在紅什麼??????.txt',
#  '[新聞] 川普確診新冠肺炎 感染科醫：拜登危險了.txt',
#  'Re: [爆卦] 最新防疫成功國家排名 中國第一 台灣榜外.txt',
#  '[問卦] 習包維尼哀帝是不是要開始躲地下碉堡啦?.txt',
#  '[問卦] 每次睡醒頭髮都會亂翹怎麼辦.txt',
#  '[問卦] 中秋烤肉趴帶甚麼食材最雷？.txt',
#  '[問卦] 有沒有被清潔工發現在看成人片的八卦?.txt',
#  '[新聞] 「反覆自打臉又一直要當官」\u3000林為洲再.txt',
#  '[問卦] 如果川普康復會說什麼？.txt',
#  '[問卦] 北市新生南路是不是設計得很智障.txt',
#  '[問卦] 有無秋天真的來臨了.txt',
#  'Re: [問卦] 慟！中秋連烤4天肉，到現在還沒拉屎！.txt',
#  '[新聞]瑞郎升不停 瑞士央行擋不住.txt',
#  '[問卦] 歐陽娜娜是不是用來轉移焦點的.txt',
#  '[問卦] Buffett 只吃8分飽算財富自由嗎.txt',
#  '[問卦] 如何入門二戰歷史？.txt',
#  '[問卦] 下課想直接回家卻被我姊叫去加社團.txt',
#  'Re: [新聞] 拍妻絲襪辣腿…遭轟死變態！尪1句反擊 冉.txt',
#  '[新聞] 五星旗亂象》防中共藉言論自由統戰 綠委.txt',
#  '[公告] 數條板規修改草案於gossippicket討論.txt',
#  '[問卦] 吃螃蟹時都怎麼去殼？.txt',
#  '[問卦] 川普康復後會說什麼.txt',
#  '[問卦] 清國國慶是何時？發錢算內亂嗎.txt',
#  '[問卦] 買3杯綠豆沙牛奶只有一根吸管是什麼意思.txt',
#  '[問卦] 拜登超穩了吧？.txt',
#  '[新聞] 扁籲朝野兩岸和解 馬點頭相挺.txt',
#  '[問卦] 陸客多久沒來了台灣也沒怎樣.txt',
#  '[問卦] 中國戰狼外交成果出爐! 全世界恨死了!.txt',
#  'Re: [新聞] 美國總統川普與第一夫人梅蘭妮亞新冠肺.txt',
#  '[問卦] 華爾街不是很討厭川普嗎? 怎沒大漲?.txt',
#  '[問卦] 多賢最可愛是什麼時期？.txt',
#  '[問卦] 川普中毒 美國是不是太丟臉了啊?.txt',
#  '[新聞] 獨家｜金曲台語歌后浴室全裸重摔\u3000送急診.txt',
#  'Re: [問卦] FB上面放BMW跟放MBL哪個可以吸引到女森？.txt',
#  '[問卦] 維尼的歷史定位是不是穩了.txt',
#  '[問卦] 川普這招是奧步嗎?.txt',
#  '[問卦] 民主黨派拜登是不是看美國人沒有.txt',
#  '[問卦] 在酒店說單純做這些事，有可能嗎??.txt',
#  '[問卦] 盲眼神婆巴巴萬加預言川普罹怪病倒下.txt',
#  '[問卦] 煞車油缸維修要多少錢啊？.txt',
#  '[問卦] 張鋒現在在想蛇摸ㄋ ?? ☺ ☺ ☺ ☺ ☺.txt',
#  '[問卦] 賣炸雞的，怎麼都不見了？.txt',
#  '[問卦] 台灣能養老虎嗎.txt',
#  '[新聞] 中共「抄近道」求世衛幫推未完成試驗的疫.txt',
#  '[問卦] 有沒有平均7分鐘就一篇大紀元新唐人的八卦.txt',
#  '[問卦] 慟！愛樂電台電腦版全面收費了！！！.txt',
#  '[新聞] 宣稱保護同志導致滅亡 日本東京區議員拒.txt',
#  '[新聞] 日艦撞我漁船 謝長廷:如抗議 吃虧會是台.txt',
#  '[爆卦] 王柏融棒打日本澤村賞名投.txt',
#  '[問卦] 美國484房子都可以隨便蓋.txt',
#  '[問卦] 在北極丟冰塊就好了吧？.txt',
#  '[問卦] 現在當兵可以用智慧型手機嗎?.txt',
#  '[新聞] 酒店公關爽吃人夫...還跩嗆正宮「鬆姐黑.txt',
#  '[新聞] 美50參議員促啓動美台全面貿易協議談判.txt',
#  'Re: [問卦] 現在是進場美股的時機嗎.txt',
#  'Re: [問卦] 住在陽明山上有什麼優點？.txt',
#  '[問卦] 印加果油的卦.txt',
#  '[新聞] 3葬槍道別！孫女捧骨灰 李登輝長眠五指山.txt',
#  '[問卦] 強人為什麼都先有女兒？.txt',
#  '[新聞] 美公布年度難民接納計劃 首次納入香港人.txt',
#  '[問卦] 為何大腸麵線要加蒜泥？？.txt',
#  'Re: [問卦] 解放軍打來真的敢殺嗎？.txt',
#  '[新聞] 蘇揆指示 儘速盤整資安黑名單.txt',
#  '[問卦] 川普是不是要下去了啊.txt',
#  '[問卦] 川普推特1小時20萬留言.txt',
#  '[新聞] 「你幾歲開始長陰毛？」 丹麥兒童節目給.txt',
#  '[問卦] 銀行一直打來幹嘛.txt',
#  '[問卦] 梅花三不能保留是不是多數暴力.txt',
#  '[問卦] 共軍會不等外國人撤僑就打台灣？.txt',
#  '[問卦] Baby shark, doo, doo, doo, doo, doo, .txt',
#  '[問卦] 推薦台中不會瘋狂推銷的健身房.txt',
#  '[問卦] 房地產會崩盤嗎？.txt',
#  '[問卦] 玩什麼遊戲才不顯宅啊.txt',
#  '[問卦] 基督徒 為啥都喜歡公開把主掛在嘴上??.txt',
#  'Re: [問卦] 其實現在臺灣人的漢人血統很稀薄了吧？.txt',
#  '[問卦] 光頭櫻木來了！！.txt',
#  '[問卦] 很用力業配奮game有多辛苦？.txt',
#  '[新聞] 台鐵區間車撞到闖入機車 保安=中洲雙向.txt',
#  '[新聞] 違國際禁令偷賣北韓石油3000噸\u3000貪財船東.txt',
#  'Re: [新聞] 高雄全套店收三倍券 更自製「振興折200券.txt',
#  'Re: [問卦] 要世界大戰了嗎？.txt',
#  '[新聞] 教召不夠！陳玉珍提「金門民防自衛隊」.txt',
#  '[問卦] 有沒有全聯要開節目的八卦.txt',
#  'Re: [問卦] 正妹讀大學時  大概會吃幾根香腸?.txt',
#  '[問卦] 川普這次不死也半殘了？.txt',
#  '[問卦] 愛Z莎莎跟那兩個日本人到底有沒外流影片.txt',
#  '[新聞] 陳廷寵「國軍戰力零」論 吳斯懷：憲法言.txt',
#  'Re: [新聞] 傳柯文哲一度想出席！國慶日退將辦「反台.txt',
#  '[問卦] 我們是不是都把藝人想錯了.txt',
#  '[問卦] 白石到底有什麼資格站在西野七瀬旁邊？.txt',
#  'Re: [新聞] 萊豬文宣竟進入北市7國小 北市教育局：確.txt',
#  'Re: [問卦] 為什麼古代生物體型可以長到這麼大？.txt',
#  '[問卦]急！ 台中一中街有沒有能寄放包包的.txt',
#  '[問卦] 我破解兩岸開戰的方法了.txt',
#  '[問卦] 台股來不及逃耶.txt',
#  '[問卦] 為何東部人這麼討厭核廢料??.txt',
#  'Re: [新聞] 大象絕望嚼食垃圾!攝影師跟蹤骨瘦如柴的.txt',
#  '[新聞] Excel漏數據之亂 英國1萬6,000名COVID-19.txt',
#  '[新聞] 綠委竟爆陳其邁上任後 高雄治安不佳 懲處.txt',
#  '[問卦] 中國開始要抹臭美國了嗎.txt',
#  'Re: [爆卦] 最新防疫成功國家排名 中國第一 台灣.txt',
#  '[問卦] SONY新世代手機是不是總是缺了點什麼??.txt',
#  'Re: [新聞] 陳廷寵以中國人為傲 吳斯懷謢航:言論.txt',
#  '[新聞] 川普確診｜重大！川普證實和第一夫人確.txt',
#  '[問卦] 覺青覺得這樣好嗎?.txt',
#  '[問卦] 隨便說三個台北市景點.txt',
#  '[問卦] 拜登如果也確診美國大選會延期嗎？.txt',
#  'Re: [問卦] 川普死掉會怎樣.txt',
#  '[公告] 八卦板板規(2020.07.21).txt',
#  '[新聞] 新課本撞臉小英 蔡英文笑：以後都要選女.txt',
#  '[問卦] 白鞋為什麼這麼誘人.txt',
#  'Re: [問卦] 南韓人均GDP今年會跌破3萬鎂？.txt',
#  '[新聞] 屏東新住民媽媽搭起溝通橋樑 影像記錄移.txt',
#  '[新聞] 新澤西州垃圾箱內發現成堆郵件 包括選票.txt',
#  '[問卦] 義交都是計程車司機兼差 時薪300.txt',
#  '[新聞] 他選上高雄拋棄年輕人？李眉蓁怒：這錢.txt',
#  '[問卦] 墾丁後壁湖海底十字架的八卦.txt',
#  '[問卦] 租屋或買房?.txt',
#  '[新聞] 在野3黨明聯合提監院人事案釋憲\u3000藍白合.txt',
#  '[問卦] 怎麼沒有youtuber是新的股市明燈?.txt',
#  '[問卦] 支持英國、美國即刻進攻中國！.txt',
#  'Re: [問卦] 台灣有厲害的科普YT嗎？.txt',
#  '[新聞] 有片／人在美國不忘花蓮\u3000蕭美琴錄影捎.txt',
#  '[新聞] 操作吊車誤觸高壓電 男子遭電擊送醫.txt',
#  '[問卦] 暗槓退房小費有搞頭嗎.txt',
#  'Re: [問卦] 不想打仗幹嘛不跟中國講= =?.txt',
#  '[問卦] 手機的emoji表情符號484很嘲諷.txt',
#  '[問卦] 如果台灣出現超級英雄可以對抗中共嗎?.txt',
#  'Re: [新聞] 放寬除役年限？年齡擬提高到50歲\u3000.txt',
#  '[問卦] 萬華的廚具店484很黑牙？.txt',
#  '[問卦] 在全聯上班是什麼感覺.txt',
#  '[問卦] 優質技術奶台?.txt',
#  'Re: [新聞] 藍營提案「台美復交」 蔡英文疑問：國民.txt',
#  '[新聞] 川普確診「躺棺材」曝光！美網友貼辛普森.txt',
#  'Re: [新聞] 啃老逆子中秋返家討錢被拒\u3000「肉魯啊」砸.txt',
#  '[新聞] 川普夫婦確診陸網嗨爆！直衝微博熱搜第一.txt',
#  '[問卦] 命理老師會怎麼評論這波染疫？.txt',
#  '[新聞] 立院初審 調戲同性最高可處6000元罰鍰  .txt',
#  'Re: [爆卦] 馬來西亞 武漢肺炎死亡病例再增加 (今天無死亡).txt',
#  '[新聞] 海邊漂來「怪香黑石」！送檢報告出爐「就.txt',
#  '[問卦] homelander跟超人PK誰會贏?.txt',
#  '[問卦] 欸欸 川普甘我屁事？洗一堆標題.txt',
#  '[問卦] 有沒有胸罩L75是什麼概念的八卦.txt',
#  '[問卦] 當時屯酒精的現在在想什麼.txt',
#  '[新聞] 川普染疫！新冠病毒檢測呈陽性 道瓊期指4.txt',
#  'Re: [新聞] 礦業63歲老闆再婚娶38歲妻 新娘：嫁給愛.txt',
#  '[問卦] 川普辯論會狂插話噴口水，是計畫通？.txt',
#  '[問卦]台妹:大陸健保比台灣健保公平太多啦！.txt',
#  '[問卦] 大家會仔細算找回來的錢嗎.txt',
#  '[新聞] 中共不是祖國？蔡正元歷史分析 「中國確.txt',
#  '[問卦] 同學會是不是有錢人才會出席?.txt',
#  '[新聞] 2北市長熱門人選同現身 陳時中讚不簡單林右.txt',
#  'Re: [問卦] Gogoro為什麼賣不動了？.txt',
#  '[新聞] 國防部：教召14天最高加薪1.5倍\u30001年1訓2.txt',
#  'Re: [爆卦] 學甲爐渣案 林易瑩:一直有耳聞市府壓新聞.txt',
#  ...]

# %%
# 先準備好 column
columns = ['推數', '噓數', '文章分數', '文章作者', '文章名稱','發表時間']

# %%
# 讀取每一篇文章，並將需要的部分取出，轉成我們需要個格式
article_info_row_data = []
for each_article in file_list:
    article_path = source_file_path + '/' + each_article
    with open(article_path, 'r', encoding = 'utf-8') as f:
        tmp_article_string = f.read()
    tmp_row_data = tmp_article_string.split('---split---')[1].split('\n')[1:-1]
    article_info_row_data.append(tmp_row_data)
article_info_row_data
# Out:
# [['推: 25',
#   '噓: 4',
#   '分數: 21',
#   '作者: Rusnake5566 (魯蛇+56 PTT最強帳號)',
#   '標題: [問卦] 兩個候選人選前一個月同時陣亡的可能性',
#   '時間: Fri Oct  2 13:56:39 2020'],
#  ['推: 11',
#   '噓: 11',
#   '分數: 0',
#   '作者: LoveMakeLove (ボケ)',
#   '標題: [新聞]江啟臣：兩岸是不對稱的戰爭 從募兵改徵兵',
#   '時間: Wed Oct  7 18:53:08 2020'],
#  ['推: 1',
#   '噓: 1',
#   '分數: 0',
#   '作者: Asce (Excalibur)',
#   '標題: Re: [新聞] 高加索血戰破百死：亞美尼亞禁止役齡男',
#   '時間: Fri Oct  2 13:07:43 2020'],
#  ['推: 20',
#   '噓: 0',
#   '分數: 20',
#   '作者: MintSu (Simon)',
#   '標題: [問卦] 如果川普老婆死於武漢肺炎會怎麼樣？',
#   '時間: Fri Oct  2 13:30:55 2020'],
#  ['推: 31',
#   '噓: 2',
#   '分數: 29',
#   '作者: seiya2000 (風見)',
#   '標題: [問卦] 為什麼古代生物體型可以長到這麼大？',
#   '時間: Fri Oct  2 12:35:18 2020'],
#  ['推: 106',
#   '噓: 6',
#   '分數: 100',
#   '作者: kasumi5566 (霞)',
#   '標題: [問卦] 支那女生是不是都沒錢修補衣服',
#   '時間: Fri Oct  2 13:43:25 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: aasawfish ()',
#   '標題: Re: [問卦] 今天為什麼要降半旗',
#   '時間: Wed Oct  7 17:34:21 2020'],
#  ['推: 3',
#   '噓: 3',
#   '分數: 0',
#   '作者: douCai (D能統粉)',
#   '標題: [問卦] 八卦板的問卦484都毫無意義?',
#   '時間: Fri Oct  2 12:46:14 2020'],
#  ['推: 11',
#   '噓: 27',
#   '分數: -16',
#   '作者: starport (輕鬆看)',
#   '標題: [新聞] 川普夫婦確診了！網友卻認為「案情不單',
#   '時間: Fri Oct  2 14:30:34 2020'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: trolleybus99 (不要問)',
#   '標題: [問卦] 習大大現在在想什麼',
#   '時間: Fri Oct  2 14:07:53 2020'],
#  ['推: 4',
#   '噓: 7',
#   '分數: -3',
#   '作者: HTC92 (中国台湾人的驕傲-92共識)',
#   '標題: [問卦] 正妹讀大學時  大概會吃幾根香腸?',
#   '時間: Wed Oct  7 18:41:32 2020'],
#  ['推: 2',
#   '噓: 4',
#   '分數: -2',
#   '作者: Huffman (David)',
#   '標題: [問卦] 美帝統領中瘟疫了 現在是解放台灣時候?',
#   '時間: Fri Oct  2 13:20:56 2020'],
#  ['推: 3',
#   '噓: 0',
#   '分數: 3',
#   '作者: smallpig02 (小豬二號)',
#   '標題: [問卦] 美軍、參聯會現在想什麼?',
#   '時間: Fri Oct  2 14:30:49 2020'],
#  ['推: 2',
#   '噓: 4',
#   '分數: -2',
#   '作者: hk410050 (A柏)',
#   '標題: [新聞] 國際藝文人士來台可申請專案縮短隔離 國',
#   '時間: Wed Oct  7 16:53:31 2020'],
#  ['推: 36',
#   '噓: 4',
#   '分數: 32',
#   '作者: tennoji2003 ()',
#   '標題: [問卦] 隨便說三個你會的做愛技巧！',
#   '時間: Wed Oct  7 17:55:20 2020'],
#  ['推: 4',
#   '噓: 0',
#   '分數: 4',
#   '作者: XDDDpupu5566 (XDpu56家族)',
#   '標題: [問卦] 亡國之君在想什麼？',
#   '時間: Fri Oct  2 14:13:42 2020'],
#  ['推: 4',
#   '噓: 3',
#   '分數: 1',
#   '作者: E24056823 (RAINFAULT)',
#   '標題: [問卦] 現在新聞都喜歡用什麼字眼啊',
#   '時間: Fri Oct  2 13:25:47 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: postit (擁有秘密是快樂的事)',
#   '標題: Re: [新聞] 酒店公關爽吃人夫...還跩嗆正宮「鬆姐黑',
#   '時間: Fri Oct  2 14:57:51 2020'],
#  ['推: 7',
#   '噓: 2',
#   '分數: 5',
#   '作者: hhuuu (hhhh)',
#   '標題: [問卦] 你第一眼直覺這個能防螞蟻嗎',
#   '時間: Wed Oct  7 17:30:27 2020'],
#  ['推: 149',
#   '噓: 14',
#   '分數: 135',
#   '作者: gogopacer (gogopacer)',
#   '標題: [問卦] 大安區的便當這樣多少？',
#   '時間: Wed Oct  7 18:07:59 2020'],
#  ['推: 2',
#   '噓: 2',
#   '分數: 0',
#   '作者: WaWa3 (寂寞的麻糬)',
#   '標題: [問卦] 泌尿科找女醫師，最後向台女露鳥的機會？',
#   '時間: Fri Oct  2 11:32:58 2020'],
#  ['推: 10',
#   '噓: 0',
#   '分數: 10',
#   '作者: ccf52881 (ccf52881)',
#   '標題: [新聞] 新莊、樹林周邊電桿全面地下化 耗資9億54',
#   '時間: Wed Oct  7 16:42:00 2020'],
#  ['推: 3',
#   '噓: 0',
#   '分數: 3',
#   '作者: freeunixer (離自相空她相)',
#   '標題: Re: [問卦] 憂鬱症不吃藥的治療方法',
#   '時間: Wed Oct  7 18:19:19 2020'],
#  ['推: 4',
#   '噓: 0',
#   '分數: 4',
#   '作者: zalora (lara)',
#   '標題: [新聞] 印度邊境布防巡航導彈目標鎖解放軍西藏',
#   '時間: Fri Oct  2 12:59:39 2020'],
#  ['推: 94',
#   '噓: 29',
#   '分數: 65',
#   '作者: www90173 (明鏡)',
#   '標題: [問卦] 華堡是不是屌打大麥克',
#   '時間: Wed Oct  7 16:26:18 2020'],
#  ['推: 8',
#   '噓: 6',
#   '分數: 2',
#   '作者: cimo764 (蘋果西打)',
#   '標題: [新聞] 扯！台中發獎狀竟印中國民國\u3000師：原來',
#   '時間: Wed Oct  7 19:37:02 2020'],
#  ['推: 4',
#   '噓: 0',
#   '分數: 4',
#   '作者: a12345x (到不了終點)',
#   '標題: [問卦] 台灣的印度人多嗎',
#   '時間: Fri Oct  2 12:49:40 2020'],
#  ['推: 4',
#   '噓: 1',
#   '分數: 3',
#   '作者: blue999 (民國詩人-Blue居易)',
#   '標題: Re: [問卦] 喂 為什麼教召要改成一年一訓而不徵兵啦',
#   '時間: Wed Oct  7 17:38:51 2020'],
#  ['推: 56',
#   '噓: 2',
#   '分數: 54',
#   '作者: Conan5566 (連續殺人)',
#   '標題: [問卦] 川普遺書會寫什麼？',
#   '時間: Fri Oct  2 15:01:05 2020'],
#  ['推: 2',
#   '噓: 6',
#   '分數: -4',
#   '作者: posen2012 (posen)',
#   '標題: [問卦] 阿福一字馬484很香啊？',
#   '時間: Wed Oct  7 17:20:27 2020'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: ostracize (bucolic)',
#   '標題: Re: [問卦] 有沒有『洪蘭式煩惱』的八卦？',
#   '時間: Fri Oct  2 14:44:54 2020'],
#  ['推: 8',
#   '噓: 2',
#   '分數: 6',
#   '作者: ericf129 (☆小艾克★)',
#   '標題: [問卦] 有沒有國慶煙火超屌的八卦？',
#   '時間: Wed Oct  7 16:13:15 2020'],
#  ['推: 8',
#   '噓: 10',
#   '分數: -2',
#   '作者: keane9112 (拎北逮頑郎 拎北反支那啦)',
#   '標題: [問卦] 那些質疑魏如萱的是否沒看到這段才質疑',
#   '時間: Wed Oct  7 16:47:45 2020'],
#  ['推: 4',
#   '噓: 0',
#   '分數: 4',
#   '作者: aure0914 (tunik)',
#   '標題: [問卦] 如果川普在選前掛掉會怎樣？',
#   '時間: Fri Oct  2 14:46:55 2020'],
#  ['推: 1',
#   '噓: 3',
#   '分數: -2',
#   '作者: gs1 (2007/1/4)',
#   '標題: [問卦] 為什麼中國不保留皇室傳統 ??',
#   '時間: Fri Oct  2 13:13:48 2020'],
#  ['推: 10',
#   '噓: 0',
#   '分數: 10',
#   '作者: cklovework (ckcck休。)',
#   '標題: [問卦] 65歲老人可以湊到一個輕裝師嗎？',
#   '時間: Wed Oct  7 19:56:55 2020'],
#  ['推: 5',
#   '噓: 0',
#   '分數: 5',
#   '作者: sookie (宣醬)',
#   '標題: [新聞] 最新Chromecast搭載Google TV與遙控器\u3000',
#   '時間: Wed Oct  7 19:05:05 2020'],
#  ['推: 9',
#   '噓: 1',
#   '分數: 8',
#   '作者: faceloser (臉輸哥)',
#   '標題: [問卦] 如果川普跟拜登都在選前病逝？',
#   '時間: Fri Oct  2 13:29:51 2020'],
#  ['推: 2',
#   '噓: 2',
#   '分數: 0',
#   '作者: jiouje (JioUje)',
#   '標題: [問卦] 洗頭妹 幫我洗頭帶手套？？？？',
#   '時間: Wed Oct  7 21:20:19 2020'],
#  ['推: 1',
#   '噓: 0',
#   '分數: 1',
#   '作者: Qorqios (☁銀長直傲嬌JK☁)',
#   '標題: Re: [問卦] 夜よ 僕に歌わせるなよ',
#   '時間: Wed Oct  7 20:56:44 2020'],
#  ['推: 12',
#   '噓: 2',
#   '分數: 10',
#   '作者: andy90498 (發錢喇幹)',
#   '標題: [問卦] 知道招式機01~08的都是什麼樣的人啊?',
#   '時間: Wed Oct  7 20:07:39 2020'],
#  ['推: 11',
#   '噓: 3',
#   '分數: 8',
#   '作者: jerrysuper (super)',
#   '標題: [問卦] 機車吵爸媽出錢買的在想什麼？',
#   '時間: Fri Oct  2 12:45:31 2020'],
#  ['推: 26',
#   '噓: 3',
#   '分數: 23',
#   '作者: jasonlin2100 (jasonlin)',
#   '標題: [問卦] 湖口一堆流氓8+9？',
#   '時間: Wed Oct  7 18:39:50 2020'],
#  ['推: 1',
#   '噓: 5',
#   '分數: -4',
#   '作者: realtw (realtw)',
#   '標題: Re: [問卦] 核彈投中國哪，台灣才不會被波及？',
#   '時間: Fri Oct  2 15:19:58 2020'],
#  ['推: 4',
#   '噓: 0',
#   '分數: 4',
#   '作者: Warheart ( ︶    八    ︶ )',
#   '標題: Re: [問卦] 被UBER EAT嗆不要送上樓怎麼辦',
#   '時間: Fri Oct  2 12:13:46 2020'],
#  ['推: 11',
#   '噓: 3',
#   '分數: 8',
#   '作者: abcde010710 (跟著風向走的肥宅)',
#   '標題: [問卦] 林俊傑音樂功力怎麼樣',
#   '時間: Wed Oct  7 17:16:44 2020'],
#  ['推: 4',
#   '噓: 0',
#   '分數: 4',
#   '作者: hmt17 (Popo:(bﾟ▽ﾟ)b)',
#   '標題: [新聞]《惡靈古堡》電影再啟卡司曝光！Netfix影 ',
#   '時間: Wed Oct  7 21:20:51 2020'],
#  ['推: 3',
#   '噓: 2',
#   '分數: 1',
#   '作者: ICBM ()',
#   '標題: Re: [新聞] 國民黨提案台美復交「促美協防抵抗中共',
#   '時間: Wed Oct  7 20:14:40 2020'],
#  ['推: 1',
#   '噓: 0',
#   '分數: 1',
#   '作者: touurtn (vv)',
#   '標題: [問卦] 質疑口罩防疫效果的人是不是都遭到報應?',
#   '時間: Fri Oct  2 13:26:18 2020'],
#  ['推: 30',
#   '噓: 1',
#   '分數: 29',
#   '作者: wizardfizban (瘋法師)',
#   '標題: [新聞] 萊豬文宣竟進入北市7國小 北市教育局：確',
#   '時間: Wed Oct  7 20:41:42 2020'],
#  ['推: 12',
#   '噓: 0',
#   '分數: 12',
#   '作者: ibox5566 (I盒子5566)',
#   '標題: [問卦] 今天美股會熔斷嗎？',
#   '時間: Fri Oct  2 13:09:18 2020'],
#  ['推: 3',
#   '噓: 0',
#   '分數: 3',
#   '作者: gemini2010 (本人在PTT所有發言為反串)',
#   '標題: [問卦] 靠觀光旅遊賺錢的歐豬現在經濟如何?',
#   '時間: Fri Oct  2 14:42:42 2020'],
#  ['推: 12',
#   '噓: 4',
#   '分數: 8',
#   '作者: ron19971997 (安安)',
#   '標題: [問卦] 台北車站真的算迷宮嗎？',
#   '時間: Wed Oct  7 16:47:55 2020'],
#  ['推: 1',
#   '噓: 3',
#   '分數: -2',
#   '作者: powyo (光子郎)',
#   '標題: [問卦] 排骨酥湯+湯圓 這樣吃會很客家嗎',
#   '時間: Fri Oct  2 13:12:15 2020'],
#  ['推: 32',
#   '噓: 7',
#   '分數: 25',
#   '作者: tw689 (台灣689)',
#   '標題: [問卦] 住在陽明山上有什麼優點？',
#   '時間: Wed Oct  7 20:16:57 2020'],
#  ['推: 6',
#   '噓: 2',
#   '分數: 4',
#   '作者: stock5566 (股神56)',
#   '標題: [問卦] 活過2020年484能嘴一輩子？',
#   '時間: Fri Oct  2 13:33:39 2020'],
#  ['推: 1',
#   '噓: 0',
#   '分數: 1',
#   '作者: showlive0214 (凡艾草)',
#   '標題: [問卦] 川普確診是不是八奇的思考力領域',
#   '時間: Fri Oct  2 14:17:26 2020'],
#  ['推: 9',
#   '噓: 1',
#   '分數: 8',
#   '作者: underwood (安德伍德)',
#   '標題: [問卦] 有人只能靠年終存錢的ㄇ',
#   '時間: Fri Oct  2 12:11:08 2020'],
#  ['推: 1',
#   '噓: 0',
#   '分數: 1',
#   '作者: aabbcc520 (U質文)',
#   '標題: [問卦] 請問女同事問我要不要去同事婚禮的八卦',
#   '時間: Fri Oct  2 14:57:45 2020'],
#  ['推: 6',
#   '噓: 3',
#   '分數: 3',
#   '作者: nissan168 (pingGO)',
#   '標題: [問卦] 坑殺四十萬趙國降卒？',
#   '時間: Fri Oct  2 12:47:02 2020'],
#  ['推: 4',
#   '噓: 2',
#   '分數: 2',
#   '作者: APUDOOR (APUDOOR)',
#   '標題: [問卦] 4不4該把川普爸爸接來台灣的時候到了??',
#   '時間: Fri Oct  2 14:37:44 2020'],
#  ['推: 9',
#   '噓: 2',
#   '分數: 7',
#   '作者: lotudi (憶苦方知思甜)',
#   '標題: [問卦]低碳飲食的狀態下有辦法不容易肚子餓？',
#   '時間: Wed Oct  7 17:54:03 2020'],
#  ['推: 10',
#   '噓: 0',
#   '分數: 10',
#   '作者: LeonardoChen (LeonardoChen)',
#   '標題: [問卦] 亂倫的黑數484很高？',
#   '時間: Wed Oct  7 16:35:19 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: zzyyxx77 (討噓大師77)',
#   '標題: [問卦] 騎到新竹宇老 再來要幹嗎？',
#   '時間: Fri Oct  2 15:37:17 2020'],
#  ['推: 117',
#   '噓: 15',
#   '分數: 102',
#   '作者: Quiff (in the Shell)',
#   '標題: [爆卦] 拜登領先擴大至21%！',
#   '時間: Wed Oct  7 17:52:26 2020'],
#  ['推: 1',
#   '噓: 0',
#   '分數: 1',
#   '作者: tangqingcai (燙青菜)',
#   '標題: [問卦] 武漢病毒現在在想什麼？',
#   '時間: Fri Oct  2 13:21:56 2020'],
#  ['推: 25',
#   '噓: 6',
#   '分數: 19',
#   '作者: Allen1096 (慾望越大，硬碟越大)',
#   '標題: [問卦] 有沒有新竹火車站的八卦',
#   '時間: Wed Oct  7 18:30:59 2020'],
#  ['推: 12',
#   '噓: 14',
#   '分數: -2',
#   '作者: Mayinggo (甲甲跟柯糞一起下去)',
#   '標題: [新聞] 變態直排輪教練！帶7男童拍裸照打飛機 \u3000',
#   '時間: Fri Oct  2 12:29:23 2020'],
#  ['推: 5',
#   '噓: 13',
#   '分數: -8',
#   '作者: nk11208z (小魯)',
#   '標題: [新聞] 戰爭時誰收屍？PTT鄉民揭神秘內幕：大賺',
#   '時間: Fri Oct  2 12:02:20 2020'],
#  ['推: 3',
#   '噓: 4',
#   '分數: -1',
#   '作者: Holmes7 (El Mundo)',
#   '標題: [問卦] 我哥也是勞工為何不嫌退休金少？',
#   '時間: Wed Oct  7 19:18:30 2020'],
#  ['推: 5',
#   '噓: 2',
#   '分數: 3',
#   '作者: saisai9230 (小為)',
#   '標題: [新聞] 延攬柯文哲人馬 林右昌證實前北市府發言人林昆鋒接綜合發展處長',
#   '時間: Wed Oct  7 20:14:42 2020'],
#  ['推: 30',
#   '噓: 5',
#   '分數: 25',
#   '作者: Usayhiisayha (【〖《〔（{`}）〕》〗】)',
#   '標題: [問卦] 海陸全餐加蔥蛋林志玲吃的完嗎？',
#   '時間: Fri Oct  2 11:53:04 2020'],
#  ['推: 5',
#   '噓: 0',
#   '分數: 5',
#   '作者: sam197665 (東哥)',
#   '標題: [問卦] 川普對上羅禮士，誰會贏？',
#   '時間: Wed Oct  7 20:39:58 2020'],
#  ['推: 27',
#   '噓: 3',
#   '分數: 24',
#   '作者: badjye911 (阿三)',
#   '標題: [問卦] 基隆以後適合長住嗎？',
#   '時間: Fri Oct  2 11:50:33 2020'],
#  ['推: 8',
#   '噓: 2',
#   '分數: 6',
#   '作者: perfidia (Schlafmütze)',
#   '標題: [問卦] FB上面放BMW跟放MBL哪個可以吸引到女森？',
#   '時間: Wed Oct  7 17:40:13 2020'],
#  ['推: 5',
#   '噓: 2',
#   '分數: 3',
#   '作者: mesubutaMYS (YBUTACHAN)',
#   '標題: [問卦] 上帝連我的隊友都救不了，如何救世人',
#   '時間: Fri Oct  2 13:55:12 2020'],
#  ['推: 1',
#   '噓: 0',
#   '分數: 1',
#   '作者: win8719 (win8719)',
#   '標題: Re: [問卦]台妹:大陸健保比台灣健保公平太多啦！',
#   '時間: Wed Oct  7 20:49:42 2020'],
#  ['推: 5',
#   '噓: 6',
#   '分數: -1',
#   '作者: kashima228 (承)',
#   '標題: [問卦] 機車上高速到底有沒有合法？',
#   '時間: Wed Oct  7 18:51:23 2020'],
#  ['推: 72',
#   '噓: 7',
#   '分數: 65',
#   '作者: faosxh (灰狐狸)',
#   '標題: [問卦] 有沒有像「北榮」這種簡稱的簡稱',
#   '時間: Fri Oct  2 14:25:18 2020'],
#  ['推: 0',
#   '噓: 2',
#   '分數: -2',
#   '作者: d995511 (flcl)',
#   '標題: [問卦] 買惹many發現路上妹子都在看我怎麼辦？',
#   '時間: Wed Oct  7 21:23:36 2020'],
#  ['推: 6',
#   '噓: 10',
#   '分數: -4',
#   '作者: silentknight (清純男)',
#   '標題: [問卦] 學妹穿女僕裝說 主人 晚餐要吃什麼?(有圖)',
#   '時間: Wed Oct  7 17:26:24 2020'],
#  ['推: 141',
#   '噓: 2',
#   '分數: 139',
#   '作者: alinalovers (凜冬將至企鵝在天涯)',
#   '標題: Fw: [新聞] 獄警強迫囚犯連聽Baby Shark兩小時遭起訴',
#   '時間: Wed Oct  7 17:48:55 2020'],
#  ['推: 1',
#   '噓: 1',
#   '分數: 0',
#   '作者: BelaTarr (森)',
#   '標題: [問卦] 怎麼勸告阿北不要吃(美)牛肉麵?!',
#   '時間: Fri Oct  2 11:56:27 2020'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: HyperPoro (TomorrowIsInYourHands)',
#   '標題: [問卦] 川普如果癒後颯爽復出會發生什麼事？',
#   '時間: Fri Oct  2 14:44:17 2020'],
#  ['推: 5',
#   '噓: 0',
#   '分數: 5',
#   '作者: opfish (coco)',
#   '標題: [問卦] 爐渣市要辦國慶煙火有推薦好玩好吃的嗎',
#   '時間: Fri Oct  2 12:58:01 2020'],
#  ['推: 129',
#   '噓: 21',
#   '分數: 108',
#   '作者: facebookig (魯蛇臉書)',
#   '標題: [爆卦] 恭喜警察被記申誡喔！',
#   '時間: Wed Oct  7 19:41:08 2020'],
#  ['推: 40',
#   '噓: 5',
#   '分數: 35',
#   '作者: lockgolden (鎖金)',
#   '標題: [問卦] 有匿蹤戰機，怎麼匿蹤飛彈還沒做出來？',
#   '時間: Wed Oct  7 17:10:45 2020'],
#  ['推: 6',
#   '噓: 3',
#   '分數: 3',
#   '作者: Francise (少喝飲料多喝水)',
#   '標題: [問卦] 雙北的8＋9都藏在哪？',
#   '時間: Wed Oct  7 18:46:36 2020'],
#  ['推: 4',
#   '噓: 1',
#   '分數: 3',
#   '作者: s110269 ()',
#   '標題: [問卦] 放假前進十張2330是不是躺著數錢？',
#   '時間: Fri Oct  2 13:41:38 2020'],
#  ['推: 2',
#   '噓: 1',
#   '分數: 1',
#   '作者: gowang19 (不認)',
#   '標題: Re: [新聞] 防疫獎章頒獎 陳時中：台灣人氣質好可以',
#   '時間: Fri Oct  2 14:08:39 2020'],
#  ['推: 3',
#   '噓: 0',
#   '分數: 3',
#   '作者: sheep531531 (只是一隻羊 @("o_o")@)',
#   '標題: [問卦] 甘草粉是不是屌打梅粉？',
#   '時間: Wed Oct  7 18:49:36 2020'],
#  ['推: 7',
#   '噓: 1',
#   '分數: 6',
#   '作者: syearth (sysearth)',
#   '標題: [問卦] 灑狗血 打悲情牌 這招在美國選舉有用嗎?',
#   '時間: Fri Oct  2 13:49:02 2020'],
#  ['推: 30',
#   '噓: 2',
#   '分數: 28',
#   '作者: amoebaba719 (阿米巴(按z進精華區))',
#   '標題: [新聞] Subway潛艇堡的麵包不是麵包？愛爾蘭法院',
#   '時間: Wed Oct  7 18:20:29 2020'],
#  ['推: 7',
#   '噓: 0',
#   '分數: 7',
#   '作者: LaAc (深淵戰士)',
#   '標題: [問卦] 有沒有hspice的八卦',
#   '時間: Wed Oct  7 20:08:51 2020'],
#  ['推: 8',
#   '噓: 4',
#   '分數: 4',
#   '作者: r1i545we (種田賣菜郎)',
#   '標題: [問卦] 看到教召要加薪教召仔有多爽？？',
#   '時間: Wed Oct  7 20:13:57 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: PrinceKanto (生田絵梨花は俺の嫁)',
#   '標題: [問卦] 乃木坂"夏のFree&Easy"ＭＶ的觀看重點?',
#   '時間: Wed Oct  7 21:34:09 2020'],
#  ['推: 23',
#   '噓: 2',
#   '分數: 21',
#   '作者: Stella289 (Stella)',
#   '標題: [新聞] 放寬除役年限？年齡擬提高到50歲\u3000',
#   '時間: Wed Oct  7 20:49:37 2020'],
#  ['推: 62',
#   '噓: 74',
#   '分數: -12',
#   '作者: googolplex (googolplex)',
#   '標題: [爆卦] 最新防疫成功國家排名 中國第一 台灣榜外',
#   '時間: Wed Oct  7 17:40:29 2020'],
#  ['推: 8',
#   '噓: 0',
#   '分數: 8',
#   '作者: IslamicState (伊斯蘭國-不亂砍頭)',
#   '標題: [問卦] 川普中標會讓美國選舉產生變數嗎',
#   '時間: Fri Oct  2 13:08:07 2020'],
#  ['推: 1',
#   '噓: 1',
#   '分數: 0',
#   '作者: bluebagel (果果:))',
#   '標題: [問卦] 大家幾天沒洗頭會變條碼頭？',
#   '時間: Fri Oct  2 13:28:29 2020'],
#  ['推: 13',
#   '噓: 7',
#   '分數: 6',
#   '作者: Sandra777 (珊朵拉)',
#   '標題: [問卦] 年薪40萬  可以買台北哪裡？',
#   '時間: Wed Oct  7 18:00:37 2020'],
#  ['推: 19',
#   '噓: 1',
#   '分數: 18',
#   '作者: theskyofblue (天空藍)',
#   '標題: [問卦] 蘋果的safari為啥這麼多人愛用',
#   '時間: Fri Oct  2 15:18:20 2020'],
#  ['推: 5',
#   '噓: 0',
#   '分數: 5',
#   '作者: matatabi (matatabi)',
#   '標題: [問卦] 台中火車站那麼多家太陽餅都誰在買的？',
#   '時間: Wed Oct  7 18:29:46 2020'],
#  ['推: 3',
#   '噓: 1',
#   '分數: 2',
#   '作者: Giddcns (狠、插、勁！！！)',
#   '標題: [問卦] 有沒有蓋牌的八卦？',
#   '時間: Wed Oct  7 16:30:55 2020'],
#  ['推: 6',
#   '噓: 3',
#   '分數: 3',
#   '作者: DavidGuetta (大衛 庫塔)',
#   '標題: [問卦] 台灣跟中國一樣虛坪制不丟臉嗎？',
#   '時間: Wed Oct  7 16:58:55 2020'],
#  ['推: 0',
#   '噓: 1',
#   '分數: -1',
#   '作者: jayyen7 (小傑)',
#   '標題: Re: [問卦] 演化後為什麼要一公一母才可以繁衍',
#   '時間: Wed Oct  7 17:39:12 2020'],
#  ['推: 4',
#   '噓: 1',
#   '分數: 3',
#   '作者: kusowan (你感受一下)',
#   '標題: Re: [新聞] 台灣豬標章標示不實「吹哨者條款」出爐',
#   '時間: Wed Oct  7 16:25:21 2020'],
#  ['推: 10',
#   '噓: 5',
#   '分數: 5',
#   '作者: stockeye (stockeye)',
#   '標題: [新聞] 救豬農「百億基金」首曝光 陳吉仲：4年共',
#   '時間: Wed Oct  7 21:00:08 2020'],
#  ['推: 2',
#   '噓: 0',
#   '分數: 2',
#   '作者: abc12812 ()',
#   '標題: [問卦] 如果普丁生在台灣 有辦法成功台獨嗎?',
#   '時間: Fri Oct  2 12:08:48 2020'],
#  ['推: 23',
#   '噓: 3',
#   '分數: 20',
#   '作者: mucorn (MU)',
#   '標題: [問卦] 美國總統中毒，最爽的是誰？',
#   '時間: Fri Oct  2 13:17:51 2020'],
#  ['推: 8',
#   '噓: 5',
#   '分數: 3',
#   '作者: soulboy330 (stay the course)',
#   '標題: [問卦] 咖啡因洗髮精真的有用嗎？',
#   '時間: Wed Oct  7 19:36:34 2020'],
#  ['推: 1',
#   '噓: 0',
#   '分數: 1',
#   '作者: ASKR (ASKR)',
#   '標題: [問卦] 阿薩斯會淨化白宮嗎',
#   '時間: Fri Oct  2 13:27:28 2020'],
#  ['推: 4',
#   '噓: 1',
#   '分數: 3',
#   '作者: tigotigo5566 (鐵劍5566)',
#   '標題: [問卦] 有沒有黃安又要拍戲的八卦？',
#   '時間: Fri Oct  2 14:35:56 2020'],
#  ['推: 4',
#   '噓: 0',
#   '分數: 4',
#   '作者: Win7 (孕妻)',
#   '標題: Re: [爆卦] 中國新的實驗性疫苗證實安全有效',
#   '時間: Wed Oct  7 20:54:06 2020'],
#  ['推: 33',
#   '噓: 3',
#   '分數: 30',
#   '作者: fenway18 (天然本草)',
#   '標題: [新聞] 慕尼黑房市 泡沫風險冠全球',
#   '時間: Wed Oct  7 19:45:27 2020'],
#  ['推: 4',
#   '噓: 1',
#   '分數: 3',
#   '作者: d995511 (flcl)',
#   '標題: [問卦] 明天要挑戰一人頂三工好緊張？',
#   '時間: Wed Oct  7 20:53:21 2020'],
#  ['推: 5',
#   '噓: 0',
#   '分數: 5',
#   '作者: christiano (喀稱)',
#   '標題: [問卦] 外國人中文歌的例子多嗎？',
#   '時間: Wed Oct  7 16:35:27 2020'],
#  ['推: 1',
#   '噓: 2',
#   '分數: -1',
#   '作者: hydroer (水人)',
#   '標題: [問卦] 汪建民和丸子的Junior要怎麼分？',
#   '時間: Wed Oct  7 20:10:35 2020'],
#  ['推: 3',
#   '噓: 0',
#   '分數: 3',
#   '作者: jun059 (好想睡覺)',
#   '標題: [問卦] 想見你為啥沒入圍金曲獎？',
#   '時間: Wed Oct  7 21:15:44 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: a111111 ( )',
#   '標題: Re: [問卦] 流氓能買的起c300？賺錢能力超強？',
#   '時間: Wed Oct  7 21:33:29 2020'],
#  ['推: 136',
#   '噓: 23',
#   '分數: 113',
#   '作者: AirJordan (MJ23)',
#   '標題: [爆卦] 學甲爐渣案 林易瑩:一直有耳聞市府壓新聞',
#   '時間: Wed Oct  7 20:57:42 2020'],
#  ['推: 40',
#   '噓: 0',
#   '分數: 40',
#   '作者: jackliao1990 (jack)',
#   '標題: [爆卦] 2020年諾貝爾化學獎',
#   '時間: Wed Oct  7 17:48:42 2020'],
#  ['推: 6',
#   '噓: 1',
#   '分數: 5',
#   '作者: stuj9019 (肥宅好吃 ^Q^)',
#   '標題: [問卦] 該怎麼用北京話求饒',
#   '時間: Fri Oct  2 13:18:06 2020'],
#  ['推: 94',
#   '噓: 13',
#   '分數: 81',
#   '作者: chee77724 (打工小天后)',
#   '標題: [新聞] 大安警衛伴李登輝36年今解散歸建 \u3000李坤',
#   '時間: Wed Oct  7 17:16:21 2020'],
#  ['推: 26',
#   '噓: 7',
#   '分數: 19',
#   '作者: milkBK (blitzkrieg比較低)',
#   '標題: [問卦] 台灣有厲害的科普YT嗎？',
#   '時間: Fri Oct  2 12:09:51 2020'],
#  ['推: 2',
#   '噓: 1',
#   '分數: 1',
#   '作者: ht91008 (色情狂)',
#   '標題: [問卦] 在美國生病只能自身自滅嗎？',
#   '時間: Fri Oct  2 14:49:39 2020'],
#  ['推: 5',
#   '噓: 22',
#   '分數: -17',
#   "作者: GOD5566GOD (o'_'o)",
#   '標題: [問卦] 覺青是不是嚇得屁滾尿流了wwwwwww',
#   '時間: Fri Oct  2 14:06:27 2020'],
#  ['推: 4',
#   '噓: 2',
#   '分數: 2',
#   '作者: Dodoroiscute (再想想)',
#   '標題: [問卦] 美豬進口台灣，誰會去代理經銷啊？',
#   '時間: Wed Oct  7 18:44:33 2020'],
#  ['推: 3',
#   '噓: 0',
#   '分數: 3',
#   '作者: cwh0105 (Ex咖哩棒)',
#   '標題: [問卦] 萬一美國總統選到一半候選人死了會怎樣?',
#   '時間: Fri Oct  2 14:33:00 2020'],
#  ['推: 16',
#   '噓: 2',
#   '分數: 14',
#   '作者: goldenhill (我的人權時代)',
#   '標題: [新聞]「退黨證書」可線上辦 中國人紛退黨自保',
#   '時間: Wed Oct  7 20:13:46 2020'],
#  ['推: 25',
#   '噓: 7',
#   '分數: 18',
#   '作者: sec5566 (sec)',
#   '標題: [問卦] 象棋是不是不懂戰爭的人發明的',
#   '時間: Wed Oct  7 19:33:26 2020'],
#  ['推: 13',
#   '噓: 5',
#   '分數: 8',
#   '作者: qk56 (休息56)',
#   '標題: 欸! 教召爭議其實是因為不公平吧!',
#   '時間: Wed Oct  7 18:00:15 2020'],
#  ['推: 17',
#   '噓: 2',
#   '分數: 15',
#   '作者: Rusnake5566 (魯蛇+56 PTT最強帳號)',
#   '標題: [問卦] 2020的高潮要來了嗎?',
#   '時間: Fri Oct  2 14:28:10 2020'],
#  ['推: 4',
#   '噓: 1',
#   '分數: 3',
#   '作者: tigotigo (鐵劍-中立理性選民)',
#   '標題: Re: [問卦] 退伍超過八年到底會不會被教召？',
#   '時間: Wed Oct  7 19:39:25 2020'],
#  ['推: 7',
#   '噓: 2',
#   '分數: 5',
#   '作者: shoga (歡迎 來自星星的Elohim)',
#   '標題: [爆卦] 日本藝人結婚對東京股市的衝擊',
#   '時間: Fri Oct  2 14:50:45 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: upen (PENPEN)',
#   '標題: Re: [問卦] 為何共匪軍機擾台 我們要出動驅逐？',
#   '時間: Wed Oct  7 18:49:08 2020'],
#  ['推: 8',
#   '噓: 0',
#   '分數: 8',
#   '作者: sodistrues (true)',
#   '標題: [問卦] 為什麼日本AKB會突然力捧大盛真步？',
#   '時間: Fri Oct  2 12:21:16 2020'],
#  ['推: 131',
#   '噓: 14',
#   '分數: 117',
#   '作者: scum5566 (你好宅)',
#   '標題: [新聞] 礦業63歲老闆再婚娶38歲妻 新娘：嫁給愛',
#   '時間: Wed Oct  7 17:06:14 2020'],
#  ['推: 30',
#   '噓: 5',
#   '分數: 25',
#   '作者: zxc2331189 (阿拉花瓜)',
#   '標題: [新聞] 獨／國道又見機車趴趴走…連過2交流道不',
#   '時間: Wed Oct  7 16:38:34 2020'],
#  ['推: 25',
#   '噓: 6',
#   '分數: 19',
#   '作者: fnm525 (22/7博士後研究員)',
#   '標題: [問卦] 大學私立前段是哪幾間阿？',
#   '時間: Wed Oct  7 18:34:51 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: q347 (我家隔壁北川景子)',
#   '標題: [問卦] 當兵最幹的是甚麼??',
#   '時間: Fri Oct  2 15:39:58 2020'],
#  ['推: 7',
#   '噓: 2',
#   '分數: 5',
#   '作者: edwardsyo (愛德華)',
#   '標題: [問卦] 中秋節大家會做愛吧',
#   '時間: Fri Oct  2 14:06:43 2020'],
#  ['推: 14',
#   '噓: 1',
#   '分數: 13',
#   '作者: arrenwu (拉姆真可愛)',
#   '標題: [問卦] 為什麼兔田佩可拉一直在用小畫家？',
#   '時間: Wed Oct  7 19:59:29 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: hayate232 (CY)',
#   '標題: Re: [問卦] 以後下基地會全部都是教召老兵嗎?',
#   '時間: Wed Oct  7 21:11:00 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: feelar (蟹Seafood)',
#   '標題: Re: [問卦] 家裡跑出野生螃蟹怎麼辦',
#   '時間: Wed Oct  7 21:26:54 2020'],
#  ['推: 11',
#   '噓: 88',
#   '分數: -77',
#   '作者: nerudaliu (Chairborne Ranger)',
#   '標題: [新聞] 「不管你說什麼，我反戰！」龍應台怒批',
#   '時間: Wed Oct  7 17:53:46 2020'],
#  ['推: 16',
#   '噓: 1',
#   '分數: 15',
#   '作者: Masahiro ()',
#   '標題: [新聞] 超愛吃肉乾！28歲女罹大腸癌\u3000醫曝研究',
#   '時間: Fri Oct  2 12:29:44 2020'],
#  ['推: 2',
#   '噓: 0',
#   '分數: 2',
#   '作者: isagoo (古先生)',
#   '標題: Re: [問卦] 一天到晚嗆買房是傻子的都哪種人？',
#   '時間: Wed Oct  7 16:26:05 2020'],
#  ['推: 4',
#   '噓: 5',
#   '分數: -1',
#   '作者: Taiwanese (臺灣人)',
#   '標題: [問卦] 年收50萬在鄉下地方是什麼等級',
#   '時間: Fri Oct  2 13:43:02 2020'],
#  ['推: 11',
#   '噓: 3',
#   '分數: 8',
#   '作者: yoyodio (8卦鹹蝦哥)',
#   '標題: [問卦] 台女滯留愛爾蘭在做啥阿??U沒U卦??',
#   '時間: Wed Oct  7 17:56:30 2020'],
#  ['推: 5',
#   '噓: 2',
#   '分數: 3',
#   '作者: edrpj (非賣品)',
#   '標題: [新聞] 網購3盒壯陽藥 男子差點被關10年',
#   '時間: Wed Oct  7 18:52:23 2020'],
#  ['推: 18',
#   '噓: 2',
#   '分數: 16',
#   '作者: thomasyu (你要戰，便來戰)',
#   '標題: [新聞] 19歲男大生多次與15歲女孩上床\u3000品行優良',
#   '時間: Wed Oct  7 16:45:50 2020'],
#  ['推: 9',
#   '噓: 4',
#   '分數: 5',
#   '作者: mickeykiller (黑色曼陀羅)',
#   '標題: [問卦] 市容差距',
#   '時間: Wed Oct  7 16:15:35 2020'],
#  ['推: 1',
#   '噓: 1',
#   '分數: 0',
#   '作者: bota (llll)',
#   '標題: [問卦] 承認怕死是一種罪???',
#   '時間: Fri Oct  2 12:05:13 2020'],
#  ['推: 9',
#   '噓: 1',
#   '分數: 8',
#   '作者: lichuer (Z揪兒)',
#   '標題: [問卦] 隔壁住吸毒犯怎麼辦?',
#   '時間: Fri Oct  2 11:54:30 2020'],
#  ['推: 17',
#   '噓: 8',
#   '分數: 9',
#   '作者: dzwei (Args&&... args)',
#   '標題: [問卦] 李永樂老師屌打台灣多數的Youtuber吧?',
#   '時間: Wed Oct  7 21:03:52 2020'],
#  ['推: 7',
#   '噓: 7',
#   '分數: 0',
#   '作者: kukulee ()',
#   '標題: [新聞] 辦好市多會員卡值得？過來人曝「真實經驗',
#   '時間: Fri Oct  2 11:31:35 2020'],
#  ['推: 8',
#   '噓: 2',
#   '分數: 6',
#   '作者: cosmite (焼き団子)',
#   '標題: [問卦] 娶到銀行員是什麼感覺？',
#   '時間: Wed Oct  7 19:31:51 2020'],
#  ['推: 7',
#   '噓: 1',
#   '分數: 6',
#   '作者: tLuesuGi (不識庵謙信)',
#   '標題: [問卦] 所以推背圖有推到川普陽性嗎',
#   '時間: Fri Oct  2 14:18:11 2020'],
#  ['推: 13',
#   '噓: 0',
#   '分數: 13',
#   '作者: laptic (靜夜聖林彼岸花)',
#   '標題: [新聞] 夫妻冷戰10年互罵畜生、惡毒的嘴 法院認2人已恩斷義絕',
#   '時間: Fri Oct  2 14:45:01 2020'],
#  ['推: 17',
#   '噓: 7',
#   '分數: 10',
#   '作者: wuyiulin (機掰客家人)',
#   '標題: [問卦] 撿到鴿子怎麼辦？',
#   '時間: Wed Oct  7 19:04:47 2020'],
#  ['推: 7',
#   '噓: 3',
#   '分數: 4',
#   '作者: ClownT (克朗)',
#   '標題: [問卦] 愛莉莎莎算是PTT反串的巔峰嗎？',
#   '時間: Fri Oct  2 12:45:48 2020'],
#  ['推: 65',
#   '噓: 3',
#   '分數: 62',
#   '作者: despairF (オタクペンギン)',
#   '標題: [問卦] 有沒有四級地震的卦？',
#   '時間: Wed Oct  7 19:20:23 2020'],
#  ['推: 2',
#   '噓: 0',
#   '分數: 2',
#   '作者: pkmu8426 (巴426)',
#   '標題: [新聞] 開放美豬｜農委會疑濫用政策行銷費用\u3000',
#   '時間: Wed Oct  7 17:45:25 2020'],
#  ['推: 6',
#   '噓: 2',
#   '分數: 4',
#   '作者: jt1801 (白白的)',
#   '標題: [問卦] 閩南民系漢族的特徵是什麼？',
#   '時間: Fri Oct  2 14:38:28 2020'],
#  ['推: 2',
#   '噓: 0',
#   '分數: 2',
#   '作者: tigotigo (鐵劍-中立理性選民)',
#   '標題: Re: [問卦] 如果戰爭的話，你（個人）會投降嗎？',
#   '時間: Wed Oct  7 20:43:57 2020'],
#  ['推: 21',
#   '噓: 5',
#   '分數: 16',
#   '作者: tn00270144 (正義)',
#   '標題: [問卦] 為什麼我還沒被教召過？？？',
#   '時間: Wed Oct  7 20:38:18 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: qazwsx0128 (*****)',
#   '標題: [問卦] 美國之子捨身對抗邪惡這劇本怎麼樣',
#   '時間: Fri Oct  2 13:54:04 2020'],
#  ['推: 5',
#   '噓: 0',
#   '分數: 5',
#   '作者: Curry16 (小咖哩)',
#   '標題: Re: [新聞] 妻打麻將輸了沒錢還…竟趴桌讓3牌友蹂躪',
#   '時間: Wed Oct  7 16:46:44 2020'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: lauwei (lauwei)',
#   '標題: [問卦] 拜登如果輸了會提起選舉無效之訴嗎',
#   '時間: Fri Oct  2 13:27:14 2020'],
#  ['推: 4',
#   '噓: 0',
#   '分數: 4',
#   '作者: ShenVen5566 (三代自耕農)',
#   '標題: Re: [爆卦] 花敬群:有人把我沒說過的渾話栽贓給我',
#   '時間: Wed Oct  7 20:49:06 2020'],
#  ['推: 37',
#   '噓: 19',
#   '分數: 18',
#   '作者: Stella289 (Stella)',
#   '標題: [問卦] 除役年齡 可能要延長14年了',
#   '時間: Wed Oct  7 19:01:53 2020'],
#  ['推: 2',
#   '噓: 0',
#   '分數: 2',
#   '作者: Flitz (費爾)',
#   '標題: [問卦] 台灣以外的中秋節 有人在烤肉嗎',
#   '時間: Fri Oct  2 13:46:54 2020'],
#  ['推: 26',
#   '噓: 1',
#   '分數: 25',
#   '作者: dream0821 (早餐很重要)',
#   '標題: [問卦] 習近平怎摸都沒事啊',
#   '時間: Fri Oct  2 14:14:19 2020'],
#  ['推: 41',
#   '噓: 18',
#   '分數: 23',
#   '作者: shiwenli (別哭)',
#   '標題: [新聞] 機車族不是人！ 中央擬取消人行道機車格 ',
#   '時間: Fri Oct  2 15:23:54 2020'],
#  ['推: 14',
#   '噓: 3',
#   '分數: 11',
#   '作者: OhwadaAkira (大和田常務)',
#   '標題: [新聞] 駁陳廷寵 嚴德發：國軍現在最有戰力',
#   '時間: Wed Oct  7 17:19:57 2020'],
#  ['推: 11',
#   '噓: 1',
#   '分數: 10',
#   '作者: jack3254 (cozoro)',
#   '標題: [問卦] 簡廷芮男友是不是很有錢？',
#   '時間: Fri Oct  2 13:58:11 2020'],
#  ['推: 18',
#   '噓: 1',
#   '分數: 17',
#   '作者: zft777 (誰贊成?誰反對?)',
#   '標題: [問卦] 百度鎖臺灣ip是不是分裂國家？',
#   '時間: Wed Oct  7 18:10:09 2020'],
#  ['推: 2',
#   '噓: 7',
#   '分數: -5',
#   '作者: organize222 (GOGO99)',
#   '標題: Re: [問卦] 簡體字為了掃盲是不是智障的作法?',
#   '時間: Wed Oct  7 18:56:02 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: Killhugh ()',
#   '標題: [問卦]  A date which will live in infamy',
#   '時間: Fri Oct  2 13:42:20 2020'],
#  ['推: 2',
#   '噓: 0',
#   '分數: 2',
#   '作者: DONNY (Donny)',
#   '標題: [問卦] 有沒有給我tempo ready go 的掛',
#   '時間: Fri Oct  2 12:13:38 2020'],
#  ['推: 10',
#   '噓: 4',
#   '分數: 6',
#   '作者: bamama56 (bamama)',
#   '標題: [新聞] 3000違建工廠僅300納管\u3000桃園祭違建剋星',
#   '時間: Fri Oct  2 12:23:05 2020'],
#  ['推: 1',
#   '噓: 0',
#   '分數: 1',
#   '作者: Phoenix723 (操場旁的含羞草)',
#   '標題: [問卦] 辛普森家庭的製作人？',
#   '時間: Fri Oct  2 15:17:05 2020'],
#  ['推: 3',
#   '噓: 1',
#   '分數: 2',
#   '作者: kone33221 (阿揪)',
#   '標題: [問卦] 有沒有智力測驗的八卦？',
#   '時間: Wed Oct  7 16:25:00 2020'],
#  ['推: 4',
#   '噓: 0',
#   '分數: 4',
#   '作者: YU0121 (愛玉冰™)',
#   '標題: [問卦] 朋友去買豪宅',
#   '時間: Fri Oct  2 11:54:47 2020'],
#  ['推: 19',
#   '噓: 2',
#   '分數: 17',
#   '作者: royroy666 (老鼠)',
#   '標題: [問卦] 要世界大戰了嗎？',
#   '時間: Fri Oct  2 13:12:52 2020'],
#  ['推: 7',
#   '噓: 0',
#   '分數: 7',
#   '作者: lupin2401 (信長肛森蘭)',
#   '標題: [問卦] 川普確診的時間點',
#   '時間: Fri Oct  2 15:13:34 2020'],
#  ['推: 2',
#   '噓: 0',
#   '分數: 2',
#   '作者: shala (沙羅是轉換後的文字檔打m)',
#   '標題: [問卦] 開戰後要打多久才能讓共匪喪失戰意？',
#   '時間: Wed Oct  7 21:03:18 2020'],
#  ['推: 5',
#   '噓: 15',
#   '分數: -10',
#   '作者: chadmu (查德姆)',
#   '標題: [新聞] 爆哭！吳宗憲現場骰子擲到這一面「小鬼真',
#   '時間: Wed Oct  7 20:04:13 2020'],
#  ['推: 2',
#   '噓: 1',
#   '分數: 1',
#   '作者: baobeising (㊣Ptt㊣最強a思想家-肚臍)',
#   '標題: Re: [新聞] 婚姻和姓氏：妻隨夫姓為何在西方社會更為普遍',
#   '時間: Fri Oct  2 11:28:36 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: HIDEI524 (shuchan)',
#   '標題: [問卦] 辯論會的辯論人位置是社交距離嗎？',
#   '時間: Fri Oct  2 14:34:11 2020'],
#  ['推: 1',
#   '噓: 0',
#   '分數: 1',
#   '作者: iwannashot (奶油會飛)',
#   '標題: [問卦] 翻墮羅拳接班人',
#   '時間: Fri Oct  2 13:47:33 2020'],
#  ['推: 52',
#   '噓: 4',
#   '分數: 48',
#   "作者: peterlin495 (專業果粉O'_'O)",
#   '標題: [新聞] 習近平思想 納入中國重點大學必修課  ',
#   '時間: Wed Oct  7 20:54:10 2020'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: iamshiba ((  ・ω・`)',
#   '標題: [問卦] 有湯瑪士小火車真人版的卦ㄇ',
#   '時間: Wed Oct  7 18:21:58 2020'],
#  ['推: 2',
#   '噓: 0',
#   '分數: 2',
#   '作者: nocturne ( )',
#   '標題: Re: [問卦] 認真問 好市多卡值得辦嗎？',
#   '時間: Fri Oct  2 12:00:26 2020'],
#  ['推: 2',
#   '噓: 0',
#   '分數: 2',
#   '作者: APUDOOR (APUDOOR)',
#   '標題: [問卦] 怎樣才可以叫中國或北韓趕快打阿??',
#   '時間: Fri Oct  2 15:22:35 2020'],
#  ['推: 8',
#   '噓: 0',
#   '分數: 8',
#   '作者: ich2 (北川石原都是我老婆)',
#   '標題: [問卦] 台北人連假會去哪裡玩的八卦',
#   '時間: Fri Oct  2 14:09:00 2020'],
#  ['推: 7',
#   '噓: 6',
#   '分數: 1',
#   '作者: nk1110 (s)',
#   '標題: [問卦] 台灣空軍升空驅離共機有必要嗎??',
#   '時間: Wed Oct  7 16:42:25 2020'],
#  ['推: 11',
#   '噓: 0',
#   '分數: 11',
#   '作者: fawangching (陽光宅叔)',
#   '標題: [問卦] 中國484完了',
#   '時間: Fri Oct  2 13:37:19 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: jerrylin (金錢就是力量)',
#   '標題: Re: [問卦] 台女寧可老了無人照顧也不願嫁普台男?',
#   '時間: Wed Oct  7 17:40:02 2020'],
#  ['推: 168',
#   '噓: 1',
#   '分數: 167',
#   '作者: zxc8899546 (183帥哥)',
#   '標題: [協尋] 桃園交通事故，請大家幫幫忙',
#   '時間: Mon Oct  5 18:38:57 2020'],
#  ['推: 1',
#   '噓: 1',
#   '分數: 0',
#   '作者: W12 (= BMI30 肥宅 =)',
#   '標題: Re: [問卦] 台南的50嵐也太少了吧？？',
#   '時間: Fri Oct  2 13:18:02 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: markban (馬克白)',
#   '標題: Re: [問卦] 瘋狂十月開始了嗎？',
#   '時間: Fri Oct  2 13:53:31 2020'],
#  ['推: 1',
#   '噓: 5',
#   '分數: -4',
#   '作者: astring (AString)',
#   '標題: [問卦] 大蛇丸是不是也得肺炎？',
#   '時間: Fri Oct  2 14:36:16 2020'],
#  ['推: 216',
#   '噓: 33',
#   '分數: 183',
#   '作者: richjf (richArt)',
#   '標題: [新聞] 何志偉提美豬總量管制 蔡英文不語、中常',
#   '時間: Wed Oct  7 17:53:49 2020'],
#  ['推: 1',
#   '噓: 2',
#   '分數: -1',
#   '作者: s910211 (我愛PTT)',
#   '標題: [問卦] 發現自己對別人的悲慘無感，怎麼釋懷？',
#   '時間: Wed Oct  7 18:22:07 2020'],
#  ['推: 11',
#   '噓: 2',
#   '分數: 9',
#   '作者: e22103 (RRRRRRRRRRRRRRRRRRRR)',
#   '標題: [新聞] 林智堅表態不選新北市長 侯友宜：好人才',
#   '時間: Fri Oct  2 15:08:18 2020'],
#  ['推: 6',
#   '噓: 2',
#   '分數: 4',
#   '作者: Matz (イラマチオ研究員)',
#   '標題: [問卦] 廢大學改科大會重返農藥嗎?',
#   '時間: Fri Oct  2 12:42:43 2020'],
#  ['推: 1',
#   '噓: 0',
#   '分數: 1',
#   '作者: algebraic (algebraic)',
#   '標題: [問卦] 周一上午要怎麼搶7?',
#   '時間: Wed Oct  7 20:36:33 2020'],
#  ['推: 6',
#   '噓: 2',
#   '分數: 4',
#   '作者: relax911 (Lmerro)',
#   '標題: [新聞] 營養午餐文宣遭疑宣揚瘦肉精 教育部要求',
#   '時間: Wed Oct  7 17:48:48 2020'],
#  ['推: 6',
#   '噓: 1',
#   '分數: 5',
#   '作者: deurpye (WORRY)',
#   '標題: [問卦] 潘瑋柏 瘦子Ozi',
#   '時間: Wed Oct  7 20:46:52 2020'],
#  ['推: 12',
#   '噓: 1',
#   '分數: 11',
#   '作者: ibox5566 (I盒子5566)',
#   '標題: [問卦] 禮拜一台股開盤要馬上把股票賣掉嗎？',
#   '時間: Fri Oct  2 13:28:28 2020'],
#  ['推: 6',
#   '噓: 4',
#   '分數: 2',
#   '作者: kuro (垃圾不分藍綠)',
#   '標題: [新聞] 台灣大道違停昨害死18歲女大生\u3000扯！貨車',
#   '時間: Wed Oct  7 21:10:17 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: nanami56 (I 佛 U)',
#   '標題: [問卦] 欸幾年沒放過颱風假了？',
#   '時間: Wed Oct  7 20:21:01 2020'],
#  ['推: 13',
#   '噓: 19',
#   '分數: -6',
#   '作者: liuyihui (臺北然也)',
#   '標題: [爆卦] 解放軍:台灣地區不要干擾我正常行動！',
#   '時間: Wed Oct  7 19:56:30 2020'],
#  ['推: 317',
#   '噓: 26',
#   '分數: 291',
#   '作者: rpg1510 (八分之三)',
#   '標題: [新聞] 國民黨推台美復交…國台辦崩潰了 江啟臣',
#   '時間: Wed Oct  7 17:58:48 2020'],
#  ['推: 2',
#   '噓: 1',
#   '分數: 1',
#   '作者: chenweichih (走路常跌倒)',
#   '標題: Re: [新聞] ATM領2萬少8千...求助遭疑「妳動手腳」',
#   '時間: Wed Oct  7 19:08:40 2020'],
#  ['推: 1',
#   '噓: 0',
#   '分數: 1',
#   '作者: colorless (colorless)',
#   '標題: [新聞] 美50名參議員致函川普政府 敦促展開台美BTA談判',
#   '時間: Fri Oct  2 14:31:15 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: longtimens (阿捲)',
#   '標題: [問卦] 是不是有重大事件就是ptt的價值發揮的時',
#   '時間: Fri Oct  2 13:35:39 2020'],
#  ['推: 5',
#   '噓: 1',
#   '分數: 4',
#   '作者: edrj1122 (帥氣男森)',
#   '標題: [問卦] 怎麼做選擇啊 ?',
#   '時間: Wed Oct  7 17:08:04 2020'],
#  ['推: 3',
#   '噓: 2',
#   '分數: 1',
#   '作者: ai770116 (東方的神秘力量)',
#   '標題: [問卦] 有沒有川普都不戴口罩很沒水準的八卦',
#   '時間: Fri Oct  2 13:23:28 2020'],
#  ['推: 4',
#   '噓: 1',
#   '分數: 3',
#   '作者: JKGOOD (Dont QQ)',
#   '標題: [問卦] 為什麼有錢人愛打高爾夫',
#   '時間: Fri Oct  2 11:54:27 2020'],
#  ['推: 11',
#   '噓: 1',
#   '分數: 10',
#   '作者: Caress (愛撫)',
#   '標題: [問卦] 台灣怎麼不全民當兵?',
#   '時間: Wed Oct  7 17:48:46 2020'],
#  ['推: 4',
#   '噓: 18',
#   '分數: -14',
#   '作者: duncan8522 (小B)',
#   '標題: [新聞] 內衣女模遭硬塞\u3000胸部驚見「異物」！闆娘',
#   '時間: Wed Oct  7 18:14:20 2020'],
#  ['推: 3',
#   '噓: 9',
#   '分數: -6',
#   '作者: johnny9667 (大八)',
#   '標題: Re: [問卦] 宮廟8+9會上ptt嗎？',
#   '時間: Fri Oct  2 15:11:23 2020'],
#  ['推: 3',
#   '噓: 0',
#   '分數: 3',
#   '作者: Venter (dream weaver)',
#   '標題: Re: [新聞] 康軒傳開除「吹哨者」未付66萬資遣費\u3000新北下午登總部勞',
#   '時間: Wed Oct  7 17:15:40 2020'],
#  ['推: 8',
#   '噓: 2',
#   '分數: 6',
#   '作者: wangyc (粒咲杏子的老公)',
#   '標題: [問卦] 有沒有一姆三分咪的八卦？',
#   '時間: Fri Oct  2 13:53:12 2020'],
#  ['推: 12',
#   '噓: 8',
#   '分數: 4',
#   '作者: samgreco (55)',
#   '標題: [問卦] 台灣人為什麼排斥當兵上戰場呢？',
#   '時間: Fri Oct  2 14:00:25 2020'],
#  ['推: 1',
#   '噓: 0',
#   '分數: 1',
#   '作者: ilw4e (可以吃嗎？)',
#   '標題: Re: [問卦] 川普第一次參加選舉就能當選美國總統？',
#   '時間: Fri Oct  2 11:52:00 2020'],
#  ['推: 6',
#   '噓: 1',
#   '分數: 5',
#   '作者: n74042300 (BACKLIFE)',
#   '標題: [問卦] 台灣真的很多積非成是的事嗎?',
#   '時間: Fri Oct  2 12:02:13 2020'],
#  ['推: 4',
#   '噓: 1',
#   '分數: 3',
#   '作者: YU0121 (愛玉冰™)',
#   '標題: [問卦] 商圈一堆女性品牌服飾到底誰在買的？',
#   '時間: Wed Oct  7 16:46:47 2020'],
#  ['推: 25',
#   '噓: 4',
#   '分數: 21',
#   '作者: owo0204 (owo0204)',
#   '標題: [問卦] 美國總統死於武漢肺炎的話這仇多大',
#   '時間: Fri Oct  2 15:28:46 2020'],
#  ['推: 6',
#   '噓: 1',
#   '分數: 5',
#   '作者: silentknight (清純男)',
#   '標題: [問卦] 為什麼白石麻衣的影片出現的是白石茉莉奈',
#   '時間: Wed Oct  7 18:55:21 2020'],
#  ['推: 5',
#   '噓: 0',
#   '分數: 5',
#   '作者: alaza (無恥美國)',
#   '標題: [問卦] 拜登現在宣布自己確診還有救嗎?',
#   '時間: Fri Oct  2 13:37:45 2020'],
#  ['推: 453',
#   '噓: 34',
#   '分數: 419',
#   '作者: rabbit83035 (遠野妖怪前綫)',
#   '標題: [新聞] 獨家》教室冷氣跳電停機一個月 高市國小',
#   '時間: Wed Oct  7 18:24:04 2020'],
#  ['推: 52',
#   '噓: 12',
#   '分數: 40',
#   '作者: Ryo5566 ()',
#   '標題: [新聞] 國小菜單驚見瘦肉精文宣挨轟\u3000北市教育',
#   '時間: Wed Oct  7 19:11:57 2020'],
#  ['推: 7',
#   '噓: 3',
#   '分數: 4',
#   '作者: Jyery (文弟)',
#   '標題: [問卦] 慟！Fighter 6停產了',
#   '時間: Wed Oct  7 16:45:50 2020'],
#  ['推: 7',
#   '噓: 3',
#   '分數: 4',
#   '作者: pulagu (遠離中共，遠離瘟疫！)',
#   '標題: [新聞] 確診者在身邊？ 新APP將發出警告',
#   '時間: Fri Oct  2 14:12:07 2020'],
#  ['推: 9',
#   '噓: 1',
#   '分數: 8',
#   '作者: rfvujm (Rfvujm)',
#   '標題: [問卦] 現在沒人在說很台了嗎',
#   '時間: Wed Oct  7 20:23:40 2020'],
#  ['推: 20',
#   '噓: 6',
#   '分數: 14',
#   '作者: HTC92 (中国台湾人的驕傲-92共識)',
#   '標題: [新聞] 高雄全套店收三倍券 更自製「振興折200券',
#   '時間: Wed Oct  7 18:47:54 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: Kakehiko (用localizer晾衣服)',
#   '標題: Re: [問卦] 健身房教練好賺嗎？',
#   '時間: Fri Oct  2 15:26:29 2020'],
#  ['推: 20',
#   '噓: 2',
#   '分數: 18',
#   '作者: PrinceKanto (生田絵梨花は俺の嫁)',
#   '標題: [新聞] 川普夫婦確診新冠肺炎 副總統潘斯：為他',
#   '時間: Fri Oct  2 15:21:02 2020'],
#  ['推: 5',
#   '噓: 15',
#   '分數: -10',
#   '作者: XXXXCOW (xxxxcow)',
#   '標題: [新聞] 拍妻絲襪辣腿…遭轟死變態！尪1句反擊 冉',
#   '時間: Wed Oct  7 19:03:46 2020'],
#  ['推: 32',
#   '噓: 2',
#   '分數: 30',
#   '作者: oz5566 (威廉。霍恩索倫)',
#   '標題: [問卦] 拜登應該嚇死了吧',
#   '時間: Fri Oct  2 14:08:09 2020'],
#  ['推: 5',
#   '噓: 0',
#   '分數: 5',
#   '作者: reppoc (稍會)',
#   '標題: [問卦] 川普推特宣布中標前會先操作股票嗎？',
#   '時間: Fri Oct  2 14:31:43 2020'],
#  ['推: 20',
#   '噓: 7',
#   '分數: 13',
#   '作者: ubcs (覺★青年超冒險蓋)',
#   '標題: [公告] 多篇無關推噓文 水桶',
#   '時間: Wed Oct  7 17:49:04 2020'],
#  ['推: 4',
#   '噓: 5',
#   '分數: -1',
#   '作者: sleeeve (赴美留學的日子...)',
#   '標題: [問卦] 有多少女生主動跟你說中秋節快了啊?',
#   '時間: Fri Oct  2 11:52:32 2020'],
#  ['推: 11',
#   '噓: 1',
#   '分數: 10',
#   '作者: EvilisGood (Hustler)',
#   '標題: [問卦] 有沒有Reddit都在慶祝川普確診的八卦',
#   '時間: Fri Oct  2 13:41:01 2020'],
#  ['推: 9',
#   '噓: 3',
#   '分數: 6',
#   '作者: Sandra777 (珊朵拉)',
#   '標題: [問卦] 欸 在麥當勞丟垃圾 不分類的都什麼人',
#   '時間: Wed Oct  7 18:09:17 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: cccccc0125 (小陳)',
#   '標題: Re: [問卦] 認真問被比特犬攻擊如何自保或反擊',
#   '時間: Fri Oct  2 15:38:03 2020'],
#  ['推: 0',
#   '噓: 13',
#   '分數: -13',
#   '作者: bensonwood (班木)',
#   '標題: [爆卦] 台彩刮刮樂的設計者的都不讀書嗎？',
#   '時間: Fri Oct  2 14:47:49 2020'],
#  ['推: 9',
#   '噓: 1',
#   '分數: 8',
#   '作者: LeeAnAn (就值得了愛，就值得了等)',
#   '標題: [問卦] 碩士念什麼所最慘？',
#   '時間: Wed Oct  7 16:55:56 2020'],
#  ['推: 7',
#   '噓: 1',
#   '分數: 6',
#   '作者: orfan (當個快樂的邊緣人~)',
#   '標題: [問卦] 為什麼冰淇淋紅茶是給粗吸管啊',
#   '時間: Wed Oct  7 17:07:34 2020'],
#  ['推: 990',
#   '噓: 66',
#   '分數: 924',
#   '作者: ubcs (覺★青年超冒險蓋)',
#   '標題: [公告] 中秋連假線上烤肉兼置底聯誼閒聊區',
#   '時間: Wed Sep 30 23:45:49 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: a111111 ( )',
#   '標題: Re: [問卦] 台灣就這麼小 為什麼這麼塞?',
#   '時間: Fri Oct  2 15:39:08 2020'],
#  ['推: 3',
#   '噓: 2',
#   '分數: 1',
#   '作者: xzcb2008 (嘿嘿我很變態歐)',
#   '標題: [問卦] =.= 有沒有賣塊公務員油土伯阿神的八卦',
#   '時間: Wed Oct  7 19:30:01 2020'],
#  ['推: 1',
#   '噓: 0',
#   '分數: 1',
#   '作者: bluebluelan (高砂國一之宮歐今津大神)',
#   '標題: Re: [問卦] 民主黨派拜登是不是看美國人沒有',
#   '時間: Fri Oct  2 12:59:34 2020'],
#  ['推: 3',
#   '噓: 0',
#   '分數: 3',
#   '作者: ToHsiang (誤上賊船)',
#   '標題: Re: [新聞] 何博文95％得票當選新北黨部主委 叫陣2022綠',
#   '時間: Wed Oct  7 18:38:39 2020'],
#  ['推: 7',
#   '噓: 1',
#   '分數: 6',
#   '作者: ccyaztfe (best_troll_tw)',
#   '標題: [問卦] 看到俯衝轟炸機衝過來的士兵在想啥？',
#   '時間: Wed Oct  7 16:28:03 2020'],
#  ['推: 3',
#   '噓: 0',
#   '分數: 3',
#   '作者: jason851124 (YeeeEX)',
#   '標題: [問卦] 台灣情趣用品店怎麼那麼多？',
#   '時間: Wed Oct  7 21:25:53 2020'],
#  ['推: 3',
#   '噓: 4',
#   '分數: -1',
#   '作者: algebraic (algebraic)',
#   '標題: [問卦] 學弟想面交',
#   '時間: Fri Oct  2 11:56:49 2020'],
#  ['推: 8',
#   '噓: 21',
#   '分數: -13',
#   '作者: jt910203 (aa)',
#   '標題: [問卦] 唐綺陽預言很準的八卦',
#   '時間: Fri Oct  2 13:35:12 2020'],
#  ['推: 9',
#   '噓: 1',
#   '分數: 8',
#   '作者: Qoo302 (Qoo~)',
#   '標題: [問卦] 有沒有什麼歌是台灣國慶應該必唱的？',
#   '時間: Fri Oct  2 13:08:50 2020'],
#  ['推: 33',
#   '噓: 3',
#   '分數: 30',
#   '作者: k90209 (k90209)',
#   '標題: [問卦] 中共到底紀念孫中山幹嘛？',
#   '時間: Fri Oct  2 12:13:01 2020'],
#  ['推: 13',
#   '噓: 5',
#   '分數: 8',
#   '作者: BlueANSI (藍色)',
#   '標題: [問卦] 私立大學分前後段是不是假議題？',
#   '時間: Wed Oct  7 18:53:59 2020'],
#  ['推: 4',
#   '噓: 1',
#   '分數: 3',
#   '作者: ryusenming ( )',
#   '標題: [問卦] 拿熟女穿一天的絲襪來尻槍是什麼感覺',
#   '時間: Wed Oct  7 20:49:08 2020'],
#  ['推: 9',
#   '噓: 0',
#   '分數: 9',
#   '作者: cimo764 (蘋果西打)',
#   '標題: [問卦] 如果是普丁中標的話?',
#   '時間: Fri Oct  2 13:37:24 2020'],
#  ['推: 4',
#   '噓: 0',
#   '分數: 4',
#   '作者: NagahamaNeru (睡睡的老公)',
#   '標題: [新聞] 35隻猴子打群架\u3000踩塌樓房壓死屋主和工人',
#   '時間: Wed Oct  7 20:36:41 2020'],
#  ['推: 35',
#   '噓: 7',
#   '分數: 28',
#   '作者: CHL98 (CHL)',
#   '標題: [新聞] 吃完牛肉麵稱「老闆送錯了」奧客只付陽春',
#   '時間: Wed Oct  7 19:16:54 2020'],
#  ['推: 2',
#   '噓: 0',
#   '分數: 2',
#   '作者: bota (llll)',
#   '標題: Re: [問卦] 有沒有健美是否真的很美的八卦',
#   '時間: Fri Oct  2 11:42:53 2020'],
#  ['推: 3',
#   '噓: 2',
#   '分數: 1',
#   '作者: you495 (哭哭)',
#   '標題: [問卦] 老闆怎麼還不放蝦',
#   '時間: Fri Oct  2 14:02:33 2020'],
#  ['推: 85',
#   '噓: 6',
#   '分數: 79',
#   '作者: Scathach (紫色BBA)',
#   '標題: [問卦] 27歲 人生終於到盡頭了',
#   '時間: Wed Oct  7 17:42:34 2020'],
#  ['推: 2',
#   '噓: 1',
#   '分數: 1',
#   '作者: yabia (*~亞比醬~*)',
#   '標題: Re: [新聞] 陳廷寵「國軍戰力零」論 吳斯懷：憲法言',
#   '時間: Wed Oct  7 17:45:19 2020'],
#  ['推: 8',
#   '噓: 4',
#   '分數: 4',
#   '作者: Flitz (費爾)',
#   '標題: [問卦] 一般人可以把hangten穿得很潮嗎',
#   '時間: Fri Oct  2 11:36:43 2020'],
#  ['推: 28',
#   '噓: 78',
#   '分數: -50',
#   '作者: vntlu ()',
#   '標題: [新聞] 傳柯文哲一度想出席！國慶日退將辦「反台',
#   '時間: Wed Oct  7 17:45:40 2020'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: Gazooli (窩4肥宅)',
#   '標題: [問卦] 烤懶較怎麼烤才好吃',
#   '時間: Fri Oct  2 13:29:39 2020'],
#  ['推: 1',
#   '噓: 10',
#   '分數: -9',
#   '作者: ilovebunnies (bunny)',
#   '標題: [問卦] 鄉民會眼皮跳嗎',
#   '時間: Wed Oct  7 16:38:34 2020'],
#  ['推: 5',
#   '噓: 0',
#   '分數: 5',
#   '作者: layu19920414 (Guan-Jie Huang)',
#   '標題: [問卦] 翻車魚484海裏的渡渡鳥牙?',
#   '時間: Fri Oct  2 14:54:06 2020'],
#  ['推: 2',
#   '噓: 4',
#   '分數: -2',
#   '作者: Wardyal (pekomiko)',
#   '標題: [問卦] 甚麼是快樂？',
#   '時間: Wed Oct  7 18:11:55 2020'],
#  ['推: 6',
#   '噓: 24',
#   '分數: -18',
#   '作者: nba887215 (方塊馬)',
#   '標題: [新聞] 反駁賣台\u3000周錫瑋：國民黨什麼時候對大',
#   '時間: Fri Oct  2 11:58:54 2020'],
#  ['推: 24',
#   '噓: 0',
#   '分數: 24',
#   '作者: a828203 ()',
#   '標題: [問卦] 「藝FUN券」算是免洗APP嗎?',
#   '時間: Fri Oct  2 11:59:09 2020'],
#  ['推: 15',
#   '噓: 2',
#   '分數: 13',
#   '作者: silbermond (...)',
#   '標題: [新聞] 大象絕望嚼食垃圾!攝影師跟蹤骨瘦如柴的',
#   '時間: Wed Oct  7 17:27:30 2020'],
#  ['推: 6',
#   '噓: 2',
#   '分數: 4',
#   '作者: Gazooli (窩4肥宅)',
#   '標題: [問卦] 中秋禮金只有200怎辦',
#   '時間: Fri Oct  2 14:11:25 2020'],
#  ['推: 3',
#   '噓: 1',
#   '分數: 2',
#   '作者: asdfg012345 (Vicious circle)',
#   '標題: Re: [問卦] 台灣空軍升空驅離共機有必要嗎??',
#   '時間: Wed Oct  7 17:36:56 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: el790124 (噓噓)',
#   '標題: [問卦] 城市尋寶是個什麼樣的活動',
#   '時間: Fri Oct  2 14:37:31 2020'],
#  ['推: 4',
#   '噓: 15',
#   '分數: -11',
#   '作者: ronharper (不要再造謠了)',
#   '標題: Re: [新聞] 預告十月還有「震撼死亡」事件！唐綺陽',
#   '時間: Fri Oct  2 13:23:41 2020'],
#  ['推: 28',
#   '噓: 3',
#   '分數: 25',
#   '作者: godiegroup (mvp)',
#   '標題: [問卦] 川普武漢肺炎確診對他美國總統連任有利?',
#   '時間: Fri Oct  2 13:45:26 2020'],
#  ['推: 2',
#   '噓: 15',
#   '分數: -13',
#   '作者: jasd1786 (假橡膠樹)',
#   '標題: [問卦] 中秋連假第二天應該沒人會噓了吧？',
#   '時間: Fri Oct  2 14:11:32 2020'],
#  ['推: 7',
#   '噓: 0',
#   '分數: 7',
#   '作者: XC40 (XC40)',
#   '標題: Re: [問卦] 台灣怎麼不全民當兵?',
#   '時間: Wed Oct  7 17:54:19 2020'],
#  ['推: 8',
#   '噓: 0',
#   '分數: 8',
#   '作者: sulanpa (...)',
#   '標題: [新聞] 揚言殺孩子、打斷親生女兒腿 法官准惡爸',
#   '時間: Wed Oct  7 19:35:31 2020'],
#  ['推: 6',
#   '噓: 5',
#   '分數: 1',
#   '作者: FuyumiIrisu (入須冬実)',
#   '標題: [新聞] 每月捐薪水1%\u3000永達保經8年捐64輛長照專車',
#   '時間: Wed Oct  7 19:10:28 2020'],
#  ['推: 5',
#   '噓: 0',
#   '分數: 5',
#   '作者: koushimei (平安順心)',
#   '標題: Re: [問卦] 台灣可以做出IC 卻做不出汽車？',
#   '時間: Fri Oct  2 11:36:06 2020'],
#  ['推: 2',
#   '噓: 0',
#   '分數: 2',
#   '作者: aquaair (aquaair)',
#   '標題: [問卦] 沒塞車是不是大家改雙十才出遊啊？',
#   '時間: Fri Oct  2 11:35:29 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: serenitymice (肥肥超越者)',
#   '標題: [問卦] 你說自由就像一陣風',
#   '時間: Wed Oct  7 20:56:10 2020'],
#  ['推: 4',
#   '噓: 0',
#   '分數: 4',
#   '作者: r5e97nk63 (DoUNo)',
#   '標題: [問卦] 拜登中標的機率？',
#   '時間: Fri Oct  2 13:35:31 2020'],
#  ['推: 11',
#   '噓: 0',
#   '分數: 11',
#   '作者: Pamplona (￣︶￣)',
#   '標題: [問卦] 川普是高危險族群吧！',
#   '時間: Fri Oct  2 13:54:23 2020'],
#  ['推: 2',
#   '噓: 2',
#   '分數: 0',
#   '作者: tigotigo5566 (鐵劍5566)',
#   '標題: [問卦] 羅志祥在微博慶賀雙節的八卦？',
#   '時間: Fri Oct  2 13:11:22 2020'],
#  ['推: 11',
#   '噓: 0',
#   '分數: 11',
#   '作者: koreawargod (高麗戰神金正恩)',
#   '標題: [問卦] 簡體字為了掃盲是不是智障的作法?',
#   '時間: Wed Oct  7 18:43:59 2020'],
#  ['推: 1',
#   '噓: 1',
#   '分數: 0',
#   '作者: dasuininder (硬派大叔)',
#   '標題: [問卦] 肥宅的嘔吐物能賣多少？',
#   '時間: Wed Oct  7 19:16:06 2020'],
#  ['推: 6',
#   '噓: 5',
#   '分數: 1',
#   '作者: thejackys (肥波)',
#   '標題: [問卦] 約克羊會看綿羊料理嗎',
#   '時間: Wed Oct  7 17:44:44 2020'],
#  ['推: 7',
#   '噓: 1',
#   '分數: 6',
#   '作者: akanishiking (arnold jackson)',
#   '標題: [問卦] 有沒有芭樂特的八卦？',
#   '時間: Fri Oct  2 12:07:53 2020'],
#  ['推: 16',
#   '噓: 0',
#   '分數: 16',
#   '作者: LEEWY (芸兒)',
#   '標題: [問卦] 現在還有人固定14天買全家人的口罩嗎',
#   '時間: Fri Oct  2 15:10:55 2020'],
#  ['推: 5',
#   '噓: 1',
#   '分數: 4',
#   '作者: abianfuck (Anonymous)',
#   '標題: Re: [問卦] 哪個智障設計環狀線新埔彎板橋的?',
#   '時間: Fri Oct  2 12:33:19 2020'],
#  ['推: 7',
#   '噓: 0',
#   '分數: 7',
#   '作者: bluebluelan (高砂國一之宮歐今津大神)',
#   '標題: [問卦] 誰能接下川普的黃金精神?',
#   '時間: Fri Oct  2 13:13:34 2020'],
#  ['推: 3',
#   '噓: 0',
#   '分數: 3',
#   '作者: qskingq (勾勾)',
#   '標題: [問卦] 現在換成彭斯的話，中國會有多慘呢？',
#   '時間: Fri Oct  2 13:31:58 2020'],
#  ['推: 7',
#   '噓: 4',
#   '分數: 3',
#   '作者: F16V (んなあああああああああ)',
#   '標題: [新聞] 局長遭爆料！軍情局駁斥醜聞不排除提告 ',
#   '時間: Wed Oct  7 19:42:41 2020'],
#  ['推: 7',
#   '噓: 1',
#   '分數: 6',
#   '作者: Qoo2222 (Qoo2222上來說是 但是缺3)',
#   '標題: [問卦] 為何雪隧昨天一路暢通？？',
#   '時間: Fri Oct  2 13:40:28 2020'],
#  ['推: 7',
#   '噓: 2',
#   '分數: 5',
#   '作者: bob120400 (花滿樓)',
#   '標題: [問卦] 小心「港版國安法」地雷',
#   '時間: Wed Oct  7 17:12:32 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: Lumial020 (廢貓文專用帳號)',
#   '標題: Re: [問卦] ‘’和平‘’是不是根本不可能？',
#   '時間: Fri Oct  2 12:57:57 2020'],
#  ['推: 1',
#   '噓: 1',
#   '分數: 0',
#   '作者: as1885 (甲文44)',
#   '標題: [問卦] 為什麼禿頭會有大鬍子？',
#   '時間: Wed Oct  7 18:28:17 2020'],
#  ['推: 6',
#   '噓: 1',
#   '分數: 5',
#   '作者: Starcraft3 (小藥丸)',
#   '標題: [問卦] 肖戰為什麼沒有出現在中秋晚會上？',
#   '時間: Fri Oct  2 12:56:07 2020'],
#  ['推: 5',
#   '噓: 0',
#   '分數: 5',
#   '作者: nogood (nogood)',
#   '標題: [問卦] 川普選舉花招是不是一直學台灣？',
#   '時間: Fri Oct  2 12:28:30 2020'],
#  ['推: 6',
#   '噓: 1',
#   '分數: 5',
#   '作者: eugene31431 (eugene31431)',
#   '標題: [問卦] 該請美國爸爸來臺灣治療了吧？',
#   '時間: Fri Oct  2 14:04:28 2020'],
#  ['推: 7',
#   '噓: 3',
#   '分數: 4',
#   '作者: LineageM (天堂M)',
#   '標題: [問卦] 隔壁女鄰居來借幾包麵？該借嗎',
#   '時間: Wed Oct  7 21:09:56 2020'],
#  ['推: 7',
#   '噓: 0',
#   '分數: 7',
#   '作者: Silent (夢想)',
#   '標題: Re: [問卦] 哈根達斯到底貴不貴阿??',
#   '時間: Wed Oct  7 18:17:56 2020'],
#  ['推: 13',
#   '噓: 4',
#   '分數: 9',
#   '作者: YU0121 (愛玉冰™)',
#   '標題: [問卦] 女生要的很簡單 到底多簡單？',
#   '時間: Wed Oct  7 17:51:03 2020'],
#  ['推: 7',
#   '噓: 1',
#   '分數: 6',
#   '作者: lianpig5566 (家庭教師殺手里包恩)',
#   '標題: [新聞] 老翁開賓士撞上16輛汽機車 自稱「閃車才',
#   '時間: Wed Oct  7 20:50:51 2020'],
#  ['推: 10',
#   '噓: 1',
#   '分數: 9',
#   '作者: soulboy330 (stay the course)',
#   '標題: [問卦] 古代真的有可能把城門撞開嗎？',
#   '時間: Wed Oct  7 19:11:54 2020'],
#  ['推: 13',
#   '噓: 4',
#   '分數: 9',
#   '作者: onepunchgg (onepunchgg)',
#   '標題: [問卦] 第一次坐捷運要注意什麼',
#   '時間: Wed Oct  7 18:15:49 2020'],
#  ['推: 3',
#   '噓: 0',
#   '分數: 3',
#   '作者: ElizabethXIV (應許)',
#   '標題: Re: [問卦] 愛莉莎莎算是PTT反串的巔峰嗎？',
#   '時間: Fri Oct  2 12:57:31 2020'],
#  ['推: 21',
#   '噓: 5',
#   '分數: 16',
#   '作者: skygift (SkY)',
#   '標題: Re: [爆卦] 央行副行長：房地產不是台灣經濟火車頭！',
#   '時間: Wed Oct  7 16:43:00 2020'],
#  ['推: 5',
#   '噓: 0',
#   '分數: 5',
#   '作者: markban (馬克白)',
#   '標題: [問卦] 美國的華萊士有倒在地上哭嗎？',
#   '時間: Fri Oct  2 13:15:45 2020'],
#  ['推: 1',
#   '噓: 0',
#   '分數: 1',
#   '作者: dgc (逍遙遊)',
#   '標題: Re: [新聞] 川普確診「躺棺材」曝光！美網友貼辛普森',
#   '時間: Fri Oct  2 14:50:46 2020'],
#  ['推: 54',
#   '噓: 15',
#   '分數: 39',
#   '作者: Rrrxddd (有噴蛤蜊 RR)',
#   '標題: [新聞] 藍營提案「台美復交」 蔡英文疑問：國民',
#   '時間: Wed Oct  7 18:17:42 2020'],
#  ['推: 3',
#   '噓: 1',
#   '分數: 2',
#   '作者: mlb99551155 (mlb995511)',
#   '標題: [問卦] 川普體內病毒在想什麼？',
#   '時間: Fri Oct  2 13:24:46 2020'],
#  ['推: 26',
#   '噓: 5',
#   '分數: 21',
#   '作者: nchum102 ()',
#   '標題: [問卦] 臺灣如果有顆核彈是不是中國就閉嘴了',
#   '時間: Fri Oct  2 12:58:20 2020'],
#  ['推: 31',
#   '噓: 10',
#   '分數: 21',
#   '作者: brokenback3 (3)',
#   '標題: [問卦]中國軍機靠近台灣若被打下 他們敢開戰？',
#   '時間: Wed Oct  7 16:13:07 2020'],
#  ['推: 9',
#   '噓: 1',
#   '分數: 8',
#   '作者: yangzy (亞瑟)',
#   '標題: [問卦] 美國總統有病被隔離時可射核彈嗎？',
#   '時間: Fri Oct  2 14:22:49 2020'],
#  ['推: 4',
#   '噓: 3',
#   '分數: 1',
#   '作者: lx2x3 ()',
#   '標題: Re: [新聞] 川普夫婦確診陸網嗨爆！直衝微博熱搜第一',
#   '時間: Fri Oct  2 15:18:12 2020'],
#  ['推: 8',
#   '噓: 0',
#   '分數: 8',
#   '作者: happyjames1 (快樂詹姆士1號)',
#   '標題: [問卦] 川普推特為什麼一堆阿姆哈拉文推文？',
#   '時間: Fri Oct  2 13:26:56 2020'],
#  ['推: 25',
#   '噓: 7',
#   '分數: 18',
#   '作者: ffreakk ()',
#   '標題: [問卦] 隨便說三個玩過三年的遊戲',
#   '時間: Wed Oct  7 17:47:19 2020'],
#  ['推: 43',
#   '噓: 0',
#   '分數: 43',
#   '作者: EvilisGood (Hustler)',
#   '標題: [爆卦] 幕僚確診後 川普跑去參加餐會',
#   '時間: Fri Oct  2 14:45:14 2020'],
#  ['推: 2',
#   '噓: 12',
#   '分數: -10',
#   '作者: ht91008 (色情狂)',
#   '標題: Re: [問卦] 台灣即將被中國統一',
#   '時間: Fri Oct  2 15:18:46 2020'],
#  ['推: 0',
#   '噓: 3',
#   '分數: -3',
#   '作者: ptt987654321 ()',
#   '標題: Re: [問卦] 原來台灣仇女的這麼多，我好震驚',
#   '時間: Fri Oct  2 12:12:28 2020'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: togs (雙標達人)',
#   '標題: Re: [新聞] 海邊漂來「怪香黑石」！送檢報告出爐「就',
#   '時間: Wed Oct  7 18:13:31 2020'],
#  ['推: 3',
#   '噓: 1',
#   '分數: 2',
#   '作者: linhu8883324 (SirLinhu)',
#   '標題: [新聞] 勤洗手防疫台北市每人每日家庭用水量創10',
#   '時間: Wed Oct  7 19:41:19 2020'],
#  ['推: 1',
#   '噓: 2',
#   '分數: -1',
#   '作者: Nemowei (fsn9665)',
#   '標題: [問卦] 還有什麼新聞可看啊',
#   '時間: Fri Oct  2 14:14:06 2020'],
#  ['推: 12',
#   '噓: 0',
#   '分數: 12',
#   '作者: cmelo1515 (瓜農)',
#   '標題: [問卦] 滿手台積電的還吃得下烤肉嗎？',
#   '時間: Fri Oct  2 13:12:51 2020'],
#  ['推: 8',
#   '噓: 1',
#   '分數: 7',
#   '作者: pl132 (pl132)',
#   '標題: [新聞]解放軍何時會攻打台灣沈富雄預測：起碼還要30年',
#   '時間: Fri Oct  2 15:01:07 2020'],
#  ['推: 4',
#   '噓: 5',
#   '分數: -1',
#   '作者: Pamplona (￣︶￣)',
#   '標題: [問卦] 美國人會怎麼跟中國算帳？',
#   '時間: Fri Oct  2 13:41:17 2020'],
#  ['推: 14',
#   '噓: 6',
#   '分數: 8',
#   '作者: AsllaPiscu (阿斯拉)',
#   '標題: [問卦] 今天為什麼要降半旗',
#   '時間: Wed Oct  7 17:19:12 2020'],
#  ['推: 0',
#   '噓: 2',
#   '分數: -2',
#   '作者: words2012 (づ′・ω・)',
#   '標題: Re: [問卦] 現在舔共最成功的是誰',
#   '時間: Fri Oct  2 15:07:44 2020'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: Audien (Audien)',
#   '標題: [問卦] 為啥川普確診一堆人po限時動態？',
#   '時間: Fri Oct  2 15:35:18 2020'],
#  ['推: 6',
#   '噓: 5',
#   '分數: 1',
#   '作者: purine5566 (漂亮56)',
#   '標題: [問卦] 以後下基地會全部都是教召老兵嗎?',
#   '時間: Wed Oct  7 19:46:28 2020'],
#  ['推: 4',
#   '噓: 0',
#   '分數: 4',
#   '作者: LoveMakeLove (ボケ)',
#   '標題: [問卦] 五星旗現在哪裡可以買？',
#   '時間: Fri Oct  2 15:30:36 2020'],
#  ['推: 5',
#   '噓: 1',
#   '分數: 4',
#   '作者: aivxg (家裡窮西索XD)',
#   '標題: [問卦] 有沒有後XX的八卦？',
#   '時間: Wed Oct  7 20:00:14 2020'],
#  ['推: 12',
#   '噓: 5',
#   '分數: 7',
#   '作者: gay7788 (卡稱之神=卡神)',
#   '標題: [問卦] 慟！中秋連烤4天肉，到現在還沒拉屎！',
#   '時間: Wed Oct  7 16:57:31 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: CenaC (王葛格加油!!)',
#   '標題: Re: [問卦] 可以一人一信到白宮建議我川嗎？',
#   '時間: Fri Oct  2 14:16:31 2020'],
#  ['推: 1',
#   '噓: 0',
#   '分數: 1',
#   '作者: Sharonchens (澈水明心)',
#   '標題: Re: [新聞] 中共不是祖國？蔡正元歷史分析 「中國確',
#   '時間: Fri Oct  2 15:35:17 2020'],
#  ['推: 8',
#   '噓: 2',
#   '分數: 6',
#   '作者: HANAXALICE (青春電幻物語)',
#   '標題: Re: [新聞] 五星旗亂象》防中共藉言論自由統戰 綠委',
#   '時間: Fri Oct  2 12:49:51 2020'],
#  ['推: 2',
#   '噓: 5',
#   '分數: -3',
#   '作者: spartaucs896 (夢醒十分)',
#   '標題: [問卦] 亞美尼亞女現在願意嫁給台男嗎',
#   '時間: Fri Oct  2 15:33:06 2020'],
#  ['推: 27',
#   '噓: 2',
#   '分數: 25',
#   '作者: jiouje (JioUje)',
#   '標題: [問卦] 中共小粉紅很想跟美國打戰啊？',
#   '時間: Fri Oct  2 13:59:14 2020'],
#  ['推: 3',
#   '噓: 0',
#   '分數: 3',
#   '作者: humbler (獸人H)',
#   '標題: [問卦] 胡天蘭吃到美豬會說什麼？',
#   '時間: Wed Oct  7 17:58:11 2020'],
#  ['推: 3',
#   '噓: 2',
#   '分數: 1',
#   '作者: coga4712 (海森堡)',
#   '標題: [問卦] 為什麼勁舞團當年會很多人玩',
#   '時間: Fri Oct  2 11:40:37 2020'],
#  ['推: 359',
#   '噓: 11',
#   '分數: 348',
#   '作者: polanco (polanco)',
#   '標題: [新聞] 美國總統川普與第一夫人梅蘭妮亞新冠肺',
#   '時間: Fri Oct  2 13:11:38 2020'],
#  ['推: 4',
#   '噓: 2',
#   '分數: 2',
#   '作者: sdtgfsrt (カヴァスⅡ世)',
#   '標題: [問卦] 地錯好看嗎?',
#   '時間: Wed Oct  7 18:06:28 2020'],
#  ['推: 24',
#   '噓: 18',
#   '分數: 6',
#   '作者: ots625 (歐踢Sk蓴    ,噤>鐝ud  巽r)',
#   '標題: [問卦] 咱們817覺青不怕打仗',
#   '時間: Wed Oct  7 17:11:00 2020'],
#  ['推: 11',
#   '噓: 0',
#   '分數: 11',
#   '作者: missingkid ()',
#   '標題: [問卦] 30歲前年收300萬的人生活是什麼樣子',
#   '時間: Wed Oct  7 18:20:12 2020'],
#  ['推: 4',
#   '噓: 1',
#   '分數: 3',
#   '作者: ambitious (Andrew)',
#   '標題: [問卦] 等下班的垃圾時間可以幹嘛',
#   '時間: Wed Oct  7 17:01:07 2020'],
#  ['推: 3',
#   '噓: 2',
#   '分數: 1',
#   '作者: saobox (刀劍神域盒盒)',
#   '標題: [問卦] 假設中共潛艦來投誠 要收嗎?',
#   '時間: Fri Oct  2 15:23:43 2020'],
#  ['推: 1',
#   '噓: 1',
#   '分數: 0',
#   '作者: en5151 (asenen)',
#   '標題: [問卦] 如果立法院拍youtobe開頻道有搞頭嗎？',
#   '時間: Wed Oct  7 21:07:32 2020'],
#  ['推: 13',
#   '噓: 4',
#   '分數: 9',
#   '作者: Yolosnow (生活很無聊)',
#   '標題: [問卦] 有大腸鏡跟胃鏡都做過的鄉民嗎？',
#   '時間: Fri Oct  2 12:35:55 2020'],
#  ['推: 2',
#   '噓: 0',
#   '分數: 2',
#   '作者: sushi11 (偶像可以亂摸嗎peko)',
#   '標題: [問卦] 為什麼不讓機車在內車道',
#   '時間: Wed Oct  7 20:56:35 2020'],
#  ['推: 2',
#   '噓: 1',
#   '分數: 1',
#   '作者: Rrrxddd (有噴蛤蜊 RR)',
#   '標題: Re: [問卦] 有沒有手很小男生的八卦？',
#   '時間: Fri Oct  2 12:30:43 2020'],
#  ['推: 5',
#   '噓: 1',
#   '分數: 4',
#   '作者: markban (馬克白)',
#   '標題: [問卦] 川普跟拜登可能進入四人賭命賽？',
#   '時間: Fri Oct  2 11:52:59 2020'],
#  ['推: 6',
#   '噓: 16',
#   '分數: -10',
#   '作者: ssss0960193 (愛莉莎莎後援會楓谷部長)',
#   '標題: [問卦] 愛莉莎莎仙氣側臉，網驚呼：臺灣IU',
#   '時間: Wed Oct  7 20:06:12 2020'],
#  ['推: 62',
#   '噓: 2',
#   '分數: 60',
#   '作者: chucky (衛藤x白石x橋本)',
#   '標題: [新聞] 快訊／川普夫婦確診新冠肺炎 即刻開始隔',
#   '時間: Fri Oct  2 13:24:11 2020'],
#  ['推: 1',
#   '噓: 2',
#   '分數: -1',
#   '作者: ryhma (hmä)',
#   '標題: Re: [問卦] 真的有人幹過羊嗎',
#   '時間: Wed Oct  7 20:01:55 2020'],
#  ['推: 7',
#   '噓: 5',
#   '分數: 2',
#   '作者: AlphaPTT (阿爾法+PTT)',
#   '標題: [問卦] iPhone的記憶體會不會少得可憐啊',
#   '時間: Wed Oct  7 20:23:27 2020'],
#  ['推: 1',
#   '噓: 1',
#   '分數: 0',
#   '作者: ryhma (hmä)',
#   '標題: [問卦] 妳的網誌成了我秘密基地',
#   '時間: Fri Oct  2 13:36:13 2020'],
#  ['推: 10',
#   '噓: 3',
#   '分數: 7',
#   '作者: liuyihui (臺北然也)',
#   '標題: [問卦] 我的經歷是中國社會的縮影嗎？',
#   '時間: Wed Oct  7 18:54:54 2020'],
#  ['推: 1',
#   '噓: 0',
#   '分數: 1',
#   '作者: cookie1125 (curry)',
#   '標題: Re: [問卦] 認真問 人一天可以走幾公里呀？',
#   '時間: Fri Oct  2 14:30:58 2020'],
#  ['推: 19',
#   '噓: 4',
#   '分數: 15',
#   '作者: silentknight (清純男)',
#   '標題: [新聞] 熱戀ing衝公廁纏綿！男大生慘挨告\u300012歲',
#   '時間: Wed Oct  7 18:02:36 2020'],
#  ['推: 10',
#   '噓: 1',
#   '分數: 9',
#   '作者: barucher (芭樂)',
#   '標題: [問卦] 請問有沒有防貓貓搶飯的方法',
#   '時間: Fri Oct  2 13:09:20 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: tml7415 (國民黨不倒 台灣不會好)',
#   '標題: Re: [問卦] 美豬進口台灣，誰會去代理經銷啊？',
#   '時間: Wed Oct  7 18:51:00 2020'],
#  ['推: 1',
#   '噓: 1',
#   '分數: 0',
#   '作者: edge112233 (忍者龜頭痛)',
#   '標題: [問卦] 美式豬肋排要用美豬還是台豬啊？',
#   '時間: Fri Oct  2 12:16:37 2020'],
#  ['推: 2',
#   '噓: 1',
#   '分數: 1',
#   '作者: EricTCartman (阿ㄆㄧㄚˇ)',
#   '標題: [問卦] 哪個地區的麻將最智障？哪個最講技術？',
#   '時間: Fri Oct  2 11:57:21 2020'],
#  ['推: 3',
#   '噓: 4',
#   '分數: -1',
#   '作者: elec1141 (木村拓哉)',
#   '標題: Re: [問卦] 台灣牛為什麼大多不做牛排用？',
#   '時間: Wed Oct  7 16:42:04 2020'],
#  ['推: 2',
#   '噓: 1',
#   '分數: 1',
#   '作者: gk1329 ()',
#   '標題: Re: [問卦] 陸客多久沒來了台灣也沒怎樣',
#   '時間: Wed Oct  7 19:05:49 2020'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: Lumial020 (廢貓文專用帳號)',
#   '標題: Re: [問卦] 基隆以後適合長住嗎？',
#   '時間: Fri Oct  2 12:29:56 2020'],
#  ['推: 8',
#   '噓: 0',
#   '分數: 8',
#   '作者: kawhidurantt (kawhi durant)',
#   '標題: [問卦] 為什麼川普中標推特下 一堆奇怪圖片?',
#   '時間: Fri Oct  2 13:38:56 2020'],
#  ['推: 11',
#   '噓: 7',
#   '分數: 4',
#   '作者: qazxsw123 (小新)',
#   '標題: [問卦] 融資是什麼意思阿',
#   '時間: Wed Oct  7 20:19:17 2020'],
#  ['推: 9',
#   '噓: 11',
#   '分數: -2',
#   '作者: googolplex (googolplex)',
#   '標題: [爆卦] 最新美國6大搖擺州民調 川普選情持續穩定',
#   '時間: Wed Oct  7 16:57:38 2020'],
#  ['推: 8',
#   '噓: 0',
#   '分數: 8',
#   '作者: sysop5566 (馬丁路德)',
#   '標題: [問卦] 四大科缺人 是哪四大？',
#   '時間: Fri Oct  2 11:47:03 2020'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: Tsuzichen (Zoo)',
#   '標題: [問卦] 孤單的朋友看到烤肉動態要來參加 怎辦',
#   '時間: Fri Oct  2 12:17:04 2020'],
#  ['推: 10',
#   '噓: 3',
# ...
#  ['推: 5',
#   '噓: 0',
#   '分數: 5',
#   '作者: lovekyoko ()',
#   '標題: Re: [新聞] 美國總統川普與第一夫人梅蘭妮亞新冠肺',
#   '時間: Fri Oct  2 13:20:05 2020'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: jerrysuper (super)',
#   '標題: [問卦] 華爾街不是很討厭川普嗎? 怎沒大漲?',
#   '時間: Fri Oct  2 14:57:00 2020'],
#  ['推: 11',
#   '噓: 4',
#   '分數: 7',
#   '作者: taipei5566 (臺北56)',
#   '標題: [問卦] 多賢最可愛是什麼時期？',
#   '時間: Fri Oct  2 14:20:04 2020'],
#  ['推: 1',
#   '噓: 3',
#   '分數: -2',
#   '作者: dWoWb (dWoWb)',
#   '標題: [問卦] 川普中毒 美國是不是太丟臉了啊?',
#   '時間: Fri Oct  2 13:24:59 2020'],
#  ['推: 18',
#   '噓: 4',
#   '分數: 14',
#   '作者: HisVol (他的體積)',
#   '標題: [新聞] 獨家｜金曲台語歌后浴室全裸重摔\u3000送急診',
#   '時間: Wed Oct  7 16:30:37 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: elite9q ()',
#   '標題: Re: [問卦] FB上面放BMW跟放MBL哪個可以吸引到女森？',
#   '時間: Wed Oct  7 18:21:07 2020'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: Scathach (紫色BBA)',
#   '標題: [問卦] 維尼的歷史定位是不是穩了',
#   '時間: Fri Oct  2 13:10:10 2020'],
#  ['推: 55',
#   '噓: 2',
#   '分數: 53',
#   '作者: leon80148 (leon)',
#   '標題: [問卦] 川普這招是奧步嗎?',
#   '時間: Fri Oct  2 13:22:04 2020'],
#  ['推: 8',
#   '噓: 1',
#   '分數: 7',
#   '作者: marsalien (mars)',
#   '標題: [問卦] 民主黨派拜登是不是看美國人沒有',
#   '時間: Fri Oct  2 12:50:03 2020'],
#  ['推: 6',
#   '噓: 1',
#   '分數: 5',
#   '作者: k44754 (9527)',
#   '標題: [問卦] 在酒店說單純做這些事，有可能嗎??',
#   '時間: Wed Oct  7 18:50:04 2020'],
#  ['推: 13',
#   '噓: 7',
#   '分數: 6',
#   '作者: joliha (一輪明月)',
#   '標題: [問卦] 盲眼神婆巴巴萬加預言川普罹怪病倒下',
#   '時間: Fri Oct  2 15:09:38 2020'],
#  ['推: 4',
#   '噓: 1',
#   '分數: 3',
#   '作者: jeremytsai (鬆)',
#   '標題: [問卦] 煞車油缸維修要多少錢啊？',
#   '時間: Wed Oct  7 17:28:34 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   "作者: Assisi (Francesco d'Assisi)",
#   '標題: [問卦] 張鋒現在在想蛇摸ㄋ ?? ☺ ☺ ☺ ☺ ☺',
#   '時間: Wed Oct  7 21:28:32 2020'],
#  ['推: 1',
#   '噓: 2',
#   '分數: -1',
#   '作者: neil136 (BianYuanFeiJhai)',
#   '標題: [問卦] 賣炸雞的，怎麼都不見了？',
#   '時間: Fri Oct  2 15:19:24 2020'],
#  ['推: 6',
#   '噓: 1',
#   '分數: 5',
#   '作者: WuDunE (GLAUCUS)',
#   '標題: [問卦] 台灣能養老虎嗎',
#   '時間: Wed Oct  7 18:26:11 2020'],
#  ['推: 5',
#   '噓: 1',
#   '分數: 4',
#   '作者: createlight (創輝)',
#   '標題: [新聞] 中共「抄近道」求世衛幫推未完成試驗的疫',
#   '時間: Wed Oct  7 20:59:47 2020'],
#  ['推: 5',
#   '噓: 2',
#   '分數: 3',
#   '作者: americ (americ)',
#   '標題: [問卦] 有沒有7分鐘就一篇大紀元新唐人的八卦',
#   '時間: Wed Oct  7 20:49:23 2020'],
#  ['推: 6',
#   '噓: 3',
#   '分數: 3',
#   '作者: smileboy2016 (Sand Tree Pad)',
#   '標題: [問卦] 慟！愛樂電台電腦版全面收費了！！！',
#   '時間: Wed Oct  7 17:36:03 2020'],
#  ['推: 16',
#   '噓: 0',
#   '分數: 16',
#   '作者: girl55665566 (同志友善ID)',
#   '標題: [新聞] 宣稱保護同志導致滅亡 日本東京區議員拒',
#   '時間: Wed Oct  7 20:04:28 2020'],
#  ['推: 97',
#   '噓: 81',
#   '分數: 16',
#   '作者: rathunter (老鼠殺手)',
#   '標題: [新聞] 日艦撞我漁船 謝長廷:如抗議 吃虧會是台',
#   '時間: Fri Oct  2 12:37:35 2020'],
#  ['推: 33',
#   '噓: 4',
#   '分數: 29',
#   '作者: nobel777 ()',
#   '標題: [爆卦] 王柏融棒打日本澤村賞名投',
#   '時間: Wed Oct  7 19:19:13 2020'],
#  ['推: 2',
#   '噓: 2',
#   '分數: 0',
#   '作者: fly820822 (大飛哥啦)',
#   '標題: [問卦] 美國484房子都可以隨便蓋',
#   '時間: Fri Oct  2 14:26:46 2020'],
#  ['推: 10',
#   '噓: 4',
#   '分數: 6',
#   '作者: toolmaster (工具人大師)',
#   '標題: [問卦] 在北極丟冰塊就好了吧？',
#   '時間: Fri Oct  2 11:49:37 2020'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: Beanoodle (津崎似超人平匡先生)',
#   '標題: [問卦] 現在當兵可以用智慧型手機嗎?',
#   '時間: Wed Oct  7 17:46:29 2020'],
#  ['推: 34',
#   '噓: 1',
#   '分數: 33',
#   '作者: Ryo5566 ()',
#   '標題: [新聞] 酒店公關爽吃人夫...還跩嗆正宮「鬆姐黑',
#   '時間: Fri Oct  2 14:47:34 2020'],
#  ['推: 4',
#   '噓: 1',
#   '分數: 3',
#   '作者: createlight (創輝)',
#   '標題: [新聞] 美50參議員促啓動美台全面貿易協議談判',
#   '時間: Fri Oct  2 12:55:21 2020'],
#  ['推: 1',
#   '噓: 1',
#   '分數: 0',
#   '作者: e741000 (複利葉。腹便。幫浦拉絲)',
#   '標題: Re: [問卦] 現在是進場美股的時機嗎',
#   '時間: Fri Oct  2 14:05:52 2020'],
#  ['推: 1',
#   '噓: 0',
#   '分數: 1',
#   '作者: cosmite (焼き団子)',
#   '標題: Re: [問卦] 住在陽明山上有什麼優點？',
#   '時間: Wed Oct  7 20:31:13 2020'],
#  ['推: 6',
#   '噓: 1',
#   '分數: 5',
#   '作者: kbt2720 (master)',
#   '標題: [問卦] 印加果油的卦',
#   '時間: Wed Oct  7 16:44:08 2020'],
#  ['推: 24',
#   '噓: 2',
#   '分數: 22',
#   '作者: wei0204 (喂~色情電話)',
#   '標題: [新聞] 3葬槍道別！孫女捧骨灰 李登輝長眠五指山',
#   '時間: Wed Oct  7 20:31:24 2020'],
#  ['推: 3',
#   '噓: 1',
#   '分數: 2',
#   '作者: LeeAnAn (就值得了愛，就值得了等)',
#   '標題: [問卦] 強人為什麼都先有女兒？',
#   '時間: Wed Oct  7 17:41:56 2020'],
#  ['推: 1',
#   '噓: 0',
#   '分數: 1',
#   '作者: Yirgacheffe (守住善良)',
#   '標題: [新聞] 美公布年度難民接納計劃 首次納入香港人',
#   '時間: Fri Oct  2 13:26:58 2020'],
#  ['推: 12',
#   '噓: 2',
#   '分數: 10',
#   '作者: Elsie1999 (艾兒)',
#   '標題: [問卦] 為何大腸麵線要加蒜泥？？',
#   '時間: Wed Oct  7 18:33:43 2020'],
#  ['推: 6',
#   '噓: 3',
#   '分數: 3',
#   '作者: sanae0307 (防空棲姬人柱力)',
#   '標題: Re: [問卦] 解放軍打來真的敢殺嗎？',
#   '時間: Fri Oct  2 15:33:38 2020'],
#  ['推: 5',
#   '噓: 10',
#   '分數: -5',
#   '作者: t77133562003 (我是一隻山羊)',
#   '標題: [新聞] 蘇揆指示 儘速盤整資安黑名單',
#   '時間: Wed Oct  7 17:02:51 2020'],
#  ['推: 1',
#   '噓: 1',
#   '分數: 0',
#   '作者: ann141414 (海底撈火鍋)',
#   '標題: [問卦] 川普是不是要下去了啊',
#   '時間: Fri Oct  2 13:24:34 2020'],
#  ['推: 8',
#   '噓: 1',
#   '分數: 7',
#   '作者: nail5566 (寶寶不說)',
#   '標題: [問卦] 川普推特1小時20萬留言',
#   '時間: Fri Oct  2 14:32:40 2020'],
#  ['推: 12',
#   '噓: 1',
#   '分數: 11',
#   '作者: saiulbb (#KEEP MLB GREAT!)',
#   '標題: [新聞] 「你幾歲開始長陰毛？」 丹麥兒童節目給',
#   '時間: Wed Oct  7 21:21:10 2020'],
#  ['推: 2',
#   '噓: 0',
#   '分數: 2',
#   '作者: yogurt0313 (愛草莓)',
#   '標題: [問卦] 銀行一直打來幹嘛',
#   '時間: Wed Oct  7 18:43:14 2020'],
#  ['推: 10',
#   '噓: 3',
#   '分數: 7',
#   '作者: ginsengwolf ( )',
#   '標題: [問卦] 梅花三不能保留是不是多數暴力',
#   '時間: Wed Oct  7 16:13:59 2020'],
#  ['推: 3',
#   '噓: 2',
#   '分數: 1',
#   '作者: zakijudelo (Zack)',
#   '標題: [問卦] 共軍會不等外國人撤僑就打台灣？',
#   '時間: Wed Oct  7 17:54:26 2020'],
#  ['推: 4',
#   '噓: 10',
#   '分數: -6',
#   '作者: alinalovers (凜冬將至企鵝在天涯)',
#   '標題: [問卦] Baby shark, doo, doo, doo, doo, doo, ',
#   '時間: Wed Oct  7 20:00:41 2020'],
#  ['推: 11',
#   '噓: 0',
#   '分數: 11',
#   '作者: utdsml (阿邊肥)',
#   '標題: [問卦] 推薦台中不會瘋狂推銷的健身房',
#   '時間: Fri Oct  2 12:01:30 2020'],
#  ['推: 4',
#   '噓: 0',
#   '分數: 4',
#   '作者: farmer (^_^)',
#   '標題: [問卦] 房地產會崩盤嗎？',
#   '時間: Fri Oct  2 14:59:42 2020'],
#  ['推: 12',
#   '噓: 1',
#   '分數: 11',
#   '作者: yoyo2008yoyo (Jgosu?)',
#   '標題: [問卦] 玩什麼遊戲才不顯宅啊',
#   '時間: Fri Oct  2 12:30:29 2020'],
#  ['推: 43',
#   '噓: 10',
#   '分數: 33',
#   '作者: hebeshaman (Hebe)',
#   '標題: [問卦] 基督徒 為啥都喜歡把主掛在嘴上??',
#   '時間: Fri Oct  2 11:33:03 2020'],
#  ['推: 3',
#   '噓: 0',
#   '分數: 3',
#   '作者: Sharonchens (澈水明心)',
#   '標題: Re: [問卦] 其實現在臺灣人的漢人血統很稀薄了吧？',
#   '時間: Fri Oct  2 12:05:38 2020'],
#  ['推: 4',
#   '噓: 4',
#   '分數: 0',
#   '作者: juyhnmki (juyhnmki)',
#   '標題: [問卦] 光頭櫻木來了！！',
#   '時間: Fri Oct  2 13:19:10 2020'],
#  ['推: 2',
#   '噓: 1',
#   '分數: 1',
#   '作者: h50212263 (奈威)',
#   '標題: [問卦] 很用力業配奮game有多辛苦？',
#   '時間: Fri Oct  2 15:13:00 2020'],
#  ['推: 4',
#   '噓: 0',
#   '分數: 4',
#   '作者: iamshana (CANINE力集中在一些重要S)',
#   '標題: [新聞] 台鐵區間車撞到闖入機車 保安=中洲雙向',
#   '時間: Wed Oct  7 21:17:49 2020'],
#  ['推: 2',
#   '噓: 2',
#   '分數: 0',
#   '作者: Comebuy (三分鐘熱度)',
#   '標題: [新聞] 違國際禁令偷賣北韓石油3000噸\u3000貪財船東',
#   '時間: Wed Oct  7 21:16:21 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: destiny1895 (1895的命運)',
#   '標題: Re: [新聞] 高雄全套店收三倍券 更自製「振興折200券',
#   '時間: Wed Oct  7 19:01:42 2020'],
#  ['推: 3',
#   '噓: 0',
#   '分數: 3',
#   '作者: Scathach (紫色BBA)',
#   '標題: Re: [問卦] 要世界大戰了嗎？',
#   '時間: Fri Oct  2 13:16:47 2020'],
#  ['推: 47',
#   '噓: 12',
#   '分數: 35',
#   '作者: Anddyliu (安滴滴)',
#   '標題: [新聞] 教召不夠！陳玉珍提「金門民防自衛隊」',
#   '時間: Wed Oct  7 16:57:21 2020'],
#  ['推: 3',
#   '噓: 2',
#   '分數: 1',
#   '作者: coon182 (微笑小空空♥)',
#   '標題: [問卦] 有沒有全聯要開節目的八卦',
#   '時間: Wed Oct  7 20:26:42 2020'],
#  ['推: 3',
#   '噓: 2',
#   '分數: 1',
#   '作者: limoncool (中国共产党杀光台独贱畜)',
#   '標題: Re: [問卦] 正妹讀大學時  大概會吃幾根香腸?',
#   '時間: Wed Oct  7 18:51:06 2020'],
#  ['推: 8',
#   '噓: 0',
#   '分數: 8',
#   '作者: ben28 (ben)',
#   '標題: [問卦] 川普這次不死也半殘了？',
#   '時間: Fri Oct  2 13:25:46 2020'],
#  ['推: 3',
#   '噓: 2',
#   '分數: 1',
#   '作者: wsp0323 (wsp0323)',
#   '標題: [問卦] 愛Z莎莎跟那兩個日本人到底有沒外流影片',
#   '時間: Fri Oct  2 11:55:51 2020'],
#  ['推: 20',
#   '噓: 18',
#   '分數: 2',
#   '作者: hbk20491 (〥夢中情一場夢〥)',
#   '標題: [新聞] 陳廷寵「國軍戰力零」論 吳斯懷：憲法言',
#   '時間: Wed Oct  7 16:37:51 2020'],
#  ['推: 6',
#   '噓: 13',
#   '分數: -7',
#   '作者: cutbear123 (皇帝熊)',
#   '標題: Re: [新聞] 傳柯文哲一度想出席！國慶日退將辦「反台',
#   '時間: Wed Oct  7 17:59:46 2020'],
#  ['推: 1',
#   '噓: 0',
#   '分數: 1',
#   '作者: nicolaskage (棋聖)',
#   '標題: [問卦] 我們是不是都把藝人想錯了',
#   '時間: Fri Oct  2 12:55:31 2020'],
#  ['推: 10',
#   '噓: 1',
#   '分數: 9',
#   '作者: AllMight (澤近愛理我老婆)',
#   '標題: [問卦] 白石到底有什麼資格站在西野七瀬旁邊？',
#   '時間: Wed Oct  7 21:07:42 2020'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: rote (ROTE)',
#   '標題: Re: [新聞] 萊豬文宣竟進入北市7國小 北市教育局：確',
#   '時間: Wed Oct  7 20:45:32 2020'],
#  ['推: 4',
#   '噓: 0',
#   '分數: 4',
#   '作者: hayate232 (CY)',
#   '標題: Re: [問卦] 為什麼古代生物體型可以長到這麼大？',
#   '時間: Fri Oct  2 12:48:46 2020'],
#  ['推: 8',
#   '噓: 2',
#   '分數: 6',
#   '作者: ans781020 (5566)',
#   '標題: [問卦]急！ 台中一中街有沒有能寄放包包的',
#   '時間: Fri Oct  2 12:23:36 2020'],
#  ['推: 6',
#   '噓: 3',
#   '分數: 3',
#   '作者: toto3527 (toto)',
#   '標題: [問卦] 我破解兩岸開戰的方法了',
#   '時間: Wed Oct  7 21:03:07 2020'],
#  ['推: 4',
#   '噓: 2',
#   '分數: 2',
#   '作者: a09651238 (可口美味好滋味)',
#   '標題: [問卦] 台股來不及逃耶',
#   '時間: Fri Oct  2 13:27:12 2020'],
#  ['推: 2',
#   '噓: 5',
#   '分數: -3',
#   '作者: w510048 (黨的恩情比山高)',
#   '標題: [問卦] 為何東部人這麼討厭核廢料??',
#   '時間: Wed Oct  7 19:52:48 2020'],
#  ['推: 2',
#   '噓: 1',
#   '分數: 1',
#   '作者: end56 (終結56)',
#   '標題: Re: [新聞] 大象絕望嚼食垃圾!攝影師跟蹤骨瘦如柴的',
#   '時間: Wed Oct  7 17:35:17 2020'],
#  ['推: 48',
#   '噓: 3',
#   '分數: 45',
#   '作者: kailayxiudo (肉毒桿菌)',
#   '標題: [新聞] Excel漏數據之亂 英國1萬6,000名COVID-19',
#   '時間: Wed Oct  7 19:23:10 2020'],
#  ['推: 48',
#   '噓: 6',
#   '分數: 42',
#   '作者: LinuxKernel (Linus Torvalds)',
#   '標題: [新聞] 綠委竟爆陳其邁上任後 高雄治安不佳 懲處',
#   '時間: Wed Oct  7 19:59:05 2020'],
#  ['推: 2',
#   '噓: 0',
#   '分數: 2',
#   '作者: johanLarson (Rent)',
#   '標題: [問卦] 中國開始要抹臭美國了嗎',
#   '時間: Fri Oct  2 13:39:04 2020'],
#  ['推: 5',
#   '噓: 12',
#   '分數: -7',
#   '作者: destiny1895 (1895的命運)',
#   '標題: Re: [爆卦] 最新防疫成功國家排名 中國第一 台灣榜外',
#   '時間: Wed Oct  7 17:52:27 2020'],
#  ['推: 1',
#   '噓: 0',
#   '分數: 1',
#   '作者: a15661263 (誠實豆沙包)',
#   '標題: [問卦] SONY新世代手機是不是總是缺了點什麼??',
#   '時間: Wed Oct  7 21:14:54 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: muse87131 ()',
#   '標題: Re: [新聞] 陳廷寵以中國人為傲 吳斯懷謢航:言論自由',
#   '時間: Wed Oct  7 21:31:58 2020'],
#  ['推: 15',
#   '噓: 1',
#   '分數: 14',
#   '作者: rosefan (Rocket Queen)',
#   '標題: [新聞] 川普確診｜重大！川普證實和第一夫人確',
#   '時間: Fri Oct  2 13:42:57 2020'],
#  ['推: 1',
#   '噓: 2',
#   '分數: -1',
#   '作者: elite9q ()',
#   '標題: [問卦] 覺青覺得這樣好嗎?',
#   '時間: Wed Oct  7 20:29:40 2020'],
#  ['推: 10',
#   '噓: 3',
#   '分數: 7',
#   '作者: gn01914712 (台大人類系之光柏豪哥)',
#   '標題: [問卦] 隨便說三個台北市景點',
#   '時間: Wed Oct  7 16:48:47 2020'],
#  ['推: 8',
#   '噓: 2',
#   '分數: 6',
#   '作者: bornwinner (tripleandyliu)',
#   '標題: [問卦] 拜登如果也確診美國大選會延期嗎？',
#   '時間: Fri Oct  2 15:15:59 2020'],
#  ['推: 5',
#   '噓: 1',
#   '分數: 4',
#   '作者: Scathach (紫色BBA)',
#   '標題: Re: [問卦] 川普死掉會怎樣',
#   '時間: Fri Oct  2 13:26:08 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: seabox (盒盒)',
#   '標題: [公告] 八卦板板規(2020.07.21)',
#   '時間: Tue Jul 21 00:00:04 2020'],
#  ['推: 22',
#   '噓: 35',
#   '分數: -13',
#   '作者: armorblocks (package)',
#   '標題: [新聞] 新課本撞臉小英 蔡英文笑：以後都要選女',
#   '時間: Wed Oct  7 19:03:27 2020'],
#  ['推: 1',
#   '噓: 3',
#   '分數: -2',
#   '作者: kopuck (派翠克星星)',
#   '標題: [問卦] 白鞋為什麼這麼誘人',
#   '時間: Fri Oct  2 11:57:31 2020'],
#  ['推: 13',
#   '噓: 2',
#   '分數: 11',
#   '作者: a810086 (眼睛業障重)',
#   '標題: Re: [問卦] 南韓人均GDP今年會跌破3萬鎂？',
#   '時間: Wed Oct  7 20:46:58 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: JimOBrien (family man)',
#   '標題: [新聞] 屏東新住民媽媽搭起溝通橋樑 影像記錄移',
#   '時間: Fri Oct  2 12:55:10 2020'],
#  ['推: 4',
#   '噓: 1',
#   '分數: 3',
#   '作者: eeth (韓國綜藝社)',
#   '標題: [新聞] 新澤西州垃圾箱內發現成堆郵件 包括選票',
#   '時間: Wed Oct  7 20:28:58 2020'],
#  ['推: 42',
#   '噓: 4',
#   '分數: 38',
#   '作者: v26457681 ()',
#   '標題: [問卦] 義交都是計程車司機兼差 時薪300',
#   '時間: Wed Oct  7 17:21:35 2020'],
#  ['推: 13',
#   '噓: 12',
#   '分數: 1',
#   '作者: blueskymaple (你是不是在發球)',
#   '標題: [新聞] 他選上高雄拋棄年輕人？李眉蓁怒：這錢',
#   '時間: Wed Oct  7 19:25:11 2020'],
#  ['推: 2',
#   '噓: 5',
#   '分數: -3',
#   '作者: Fortran (Fortran)',
#   '標題: [問卦] 墾丁後壁湖海底十字架的八卦',
#   '時間: Wed Oct  7 21:23:52 2020'],
#  ['推: 5',
#   '噓: 3',
#   '分數: 2',
#   '作者: LoveNPeace (689T陳宗傑)',
#   '標題: [問卦] 租屋或買房?',
#   '時間: Wed Oct  7 19:22:29 2020'],
#  ['推: 2',
#   '噓: 0',
#   '分數: 2',
#   '作者: cycling (一直暴雷一直爽)',
#   '標題: [新聞] 在野3黨明聯合提監院人事案釋憲\u3000藍白合',
#   '時間: Wed Oct  7 20:53:11 2020'],
#  ['推: 3',
#   '噓: 0',
#   '分數: 3',
#   '作者: pizzafan (隔多天的約定容易忘)',
#   '標題: [問卦] 怎麼沒有youtuber是新的股市明燈?',
#   '時間: Fri Oct  2 12:03:59 2020'],
#  ['推: 2',
#   '噓: 4',
#   '分數: -2',
#   '作者: AllBlack (All Black)',
#   '標題: [問卦] 支持英國、美國即刻進攻中國！',
#   '時間: Fri Oct  2 13:32:10 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: shala (沙羅是轉換後的文字檔打m)',
#   '標題: Re: [問卦] 台灣有厲害的科普YT嗎？',
#   '時間: Fri Oct  2 14:08:31 2020'],
#  ['推: 12',
#   '噓: 4',
#   '分數: 8',
#   '作者: lescafe ()',
#   '標題: [新聞] 有片／人在美國不忘花蓮\u3000蕭美琴錄影捎',
#   '時間: Fri Oct  2 12:34:35 2020'],
#  ['推: 19',
#   '噓: 0',
#   '分數: 19',
#   '作者: seibu (難過)',
#   '標題: [新聞] 操作吊車誤觸高壓電 男子遭電擊送醫',
#   '時間: Wed Oct  7 16:32:10 2020'],
#  ['推: 1',
#   '噓: 1',
#   '分數: 0',
#   '作者: JasperChang (PeterChou)',
#   '標題: [問卦] 暗槓退房小費有搞頭嗎',
#   '時間: Wed Oct  7 20:57:34 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: ianlin1216 (伊恩可可)',
#   '標題: Re: [問卦] 不想打仗幹嘛不跟中國講= =?',
#   '時間: Wed Oct  7 20:13:40 2020'],
#  ['推: 5',
#   '噓: 1',
#   '分數: 4',
#   '作者: paulabxz123 (優文大師)',
#   '標題: [問卦] 手機的emoji表情符號484很嘲諷',
#   '時間: Fri Oct  2 12:55:06 2020'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: k91011022 (徬徨)',
#   '標題: [問卦] 如果台灣出現超級英雄可以對抗中共嗎?',
#   '時間: Wed Oct  7 16:36:05 2020'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: americ (americ)',
#   '標題: Re: [新聞] 放寬除役年限？年齡擬提高到50歲\u3000',
#   '時間: Wed Oct  7 21:03:22 2020'],
#  ['推: 3',
#   '噓: 1',
#   '分數: 2',
#   '作者: layu19920414 (Guan-Jie Huang)',
#   '標題: [問卦] 萬華的廚具店484很黑牙？',
#   '時間: Wed Oct  7 20:06:20 2020'],
#  ['推: 7',
#   '噓: 2',
#   '分數: 5',
#   '作者: chadmu (查德姆)',
#   '標題: [問卦] 在全聯上班是什麼感覺',
#   '時間: Wed Oct  7 21:21:50 2020'],
#  ['推: 3',
#   '噓: 2',
#   '分數: 1',
#   '作者: Lailungsheng (狼不會入眠)',
#   '標題: [問卦] 優質技術奶台?',
#   '時間: Fri Oct  2 13:11:10 2020'],
#  ['推: 4',
#   '噓: 4',
#   '分數: 0',
#   '作者: ilw4e (可以吃嗎？)',
#   '標題: Re: [新聞] 藍營提案「台美復交」 蔡英文疑問：國民',
#   '時間: Wed Oct  7 18:47:36 2020'],
#  ['推: 60',
#   '噓: 2',
#   '分數: 58',
#   '作者: pitalvlu (pital)',
#   '標題: [新聞] 川普確診「躺棺材」曝光！美網友貼辛普',
#   '時間: Fri Oct  2 14:18:21 2020'],
#  ['推: 4',
#   '噓: 0',
#   '分數: 4',
#   '作者: nonpolar (Nonpolar)',
#   '標題: Re: [新聞] 啃老逆子中秋返家討錢被拒\u3000「肉魯啊」砸',
#   '時間: Fri Oct  2 12:04:18 2020'],
#  ['推: 29',
#   '噓: 6',
#   '分數: 23',
#   '作者: whj0530 (億載金城武)',
#   '標題: [新聞] 川普夫婦確診陸網嗨爆！直衝微博熱搜第一',
#   '時間: Fri Oct  2 14:59:13 2020'],
#  ['推: 3',
#   '噓: 0',
#   '分數: 3',
#   '作者: Giddcns (狠、插、勁！！！)',
#   '標題: [問卦] 命理老師會怎麼評論這波染疫？',
#   '時間: Fri Oct  2 13:47:19 2020'],
#  ['推: 28',
#   '噓: 2',
#   '分數: 26',
#   '作者: hoyumi (正版型男...無誤!!!)',
#   '標題: [新聞] 立院初審 調戲同性最高可處6000元罰鍰  ',
#   '時間: Wed Oct  7 17:29:05 2020'],
#  ['推: 4',
#   '噓: 0',
#   '分數: 4',
#   '作者: laptic (靜夜聖林彼岸花)',
#   '標題: Re: [爆卦] 馬來西亞 武漢肺炎死亡病例再增加 (今天無死亡)',
#   '時間: Wed Oct  7 20:53:17 2020'],
#  ['推: 167',
#   '噓: 8',
#   '分數: 159',
#   '作者: CharleneTsai (給他200塊去吃麥當勞啦)',
#   '標題: [新聞] 海邊漂來「怪香黑石」！送檢報告出爐「就',
#   '時間: Wed Oct  7 16:48:39 2020'],
#  ['推: 3',
#   '噓: 2',
#   '分數: 1',
#   '作者: awhat (La Mer)',
#   '標題: [問卦] homelander跟超人PK誰會贏?',
#   '時間: Fri Oct  2 12:22:15 2020'],
#  ['推: 2',
#   '噓: 4',
#   '分數: -2',
#   '作者: Dinenger (低能兒)',
#   '標題: [問卦] 欸欸 川普甘我屁事？洗一堆標題',
#   '時間: Fri Oct  2 13:36:11 2020'],
#  ['推: 3',
#   '噓: 2',
#   '分數: 1',
#   '作者: pewdiefish (PewDieFish)',
#   '標題: [問卦] 有沒有胸罩L75是什麼概念的八卦',
#   '時間: Wed Oct  7 18:25:38 2020'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: tatty5566 ( )',
#   '標題: [問卦] 當時屯酒精的現在在想什麼',
#   '時間: Fri Oct  2 13:33:29 2020'],
#  ['推: 7',
#   '噓: 1',
#   '分數: 6',
#   '作者: wavespirit (鄉民進化論)',
#   '標題: [新聞] 川普染疫！新冠病毒檢測呈陽性 道瓊期指4',
#   '時間: Fri Oct  2 13:41:55 2020'],
#  ['推: 20',
#   '噓: 1',
#   '分數: 19',
#   '作者: nonpolar (Nonpolar)',
#   '標題: Re: [新聞] 礦業63歲老闆再婚娶38歲妻 新娘：嫁給愛',
#   '時間: Wed Oct  7 17:23:38 2020'],
#  ['推: 1',
#   '噓: 1',
#   '分數: 0',
#   '作者: zakijudelo (Zack)',
#   '標題: [問卦] 川普辯論會狂插話噴口水，是計畫通？',
#   '時間: Fri Oct  2 13:30:08 2020'],
#  ['推: 15',
#   '噓: 22',
#   '分數: -7',
#   '作者: liuyihui (臺北然也)',
#   '標題: [問卦]台妹:大陸健保比台灣健保公平太多啦！',
#   '時間: Wed Oct  7 20:21:26 2020'],
#  ['推: 1',
#   '噓: 0',
#   '分數: 1',
#   '作者: seth5421 (正版廢文王)',
#   '標題: [問卦] 大家會仔細算找回來的錢嗎',
#   '時間: Wed Oct  7 20:52:07 2020'],
#  ['推: 22',
#   '噓: 29',
#   '分數: -7',
#   '作者: Israfil (贖罪聖音)',
#   '標題: [新聞] 中共不是祖國？蔡正元歷史分析 「中國確',
#   '時間: Fri Oct  2 15:10:13 2020'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: zxc2331189 (阿拉花瓜)',
#   '標題: [問卦] 同學會是不是有錢人才會出席?',
#   '時間: Wed Oct  7 18:21:19 2020'],
#  ['推: 6',
#   '噓: 3',
#   '分數: 3',
#   '作者: ToHsiang (誤上賊船)',
#   '標題: [新聞] 2北市長熱門人選同現身 陳時中讚不簡單林右',
#   '時間: Fri Oct  2 15:24:08 2020'],
#  ['推: 6',
#   '噓: 4',
#   '分數: 2',
#   '作者: taker627 (你馬英九嗎?)',
#   '標題: Re: [問卦] Gogoro為什麼賣不動了？',
#   '時間: Wed Oct  7 16:27:02 2020'],
#  ['推: 63',
#   '噓: 21',
#   '分數: 42',
#   '作者: joug (好東西不簽嗎)',
#   '標題: [新聞] 國防部：教召14天最高加薪1.5倍\u30001年1訓2',
#   '時間: Wed Oct  7 16:31:29 2020'],
#  ['推: 4',
#   '噓: 2',
#   '分數: 2',
#   '作者: hugh509 ((0_ 0))',
#   '標題: Re: [爆卦] 學甲爐渣案 林易瑩:一直有耳聞市府壓新聞',
#   '時間: Wed Oct  7 21:15:18 2020'],
#  ...]

# %%
# 製作 DataFrame
df = pd.DataFrame(data=article_info_row_data, columns=columns)
df
# Out:
#          推數     噓數    文章分數                             文章作者  \
# 0     推: 25   噓: 4  分數: 21  作者: Rusnake5566 (魯蛇+56 PTT最強帳號)
# 1     推: 11  噓: 11   分數: 0            作者: LoveMakeLove (ボケ)
# 2      推: 1   噓: 1   分數: 0             作者: Asce (Excalibur)
# 3     推: 20   噓: 0  分數: 20               作者: MintSu (Simon)
# 4     推: 31   噓: 2  分數: 29               作者: seiya2000 (風見)
# ...     ...    ...     ...                              ...
# 1012   推: 0   噓: 0   分數: 0      作者: wa778895 (oilsunbright)
# 1013  推: 15   噓: 4  分數: 11              作者: stan0720 (Kimo)
# 1014  推: 10   噓: 7   分數: 3                 作者: alaza (無恥美國)
# 1015   推: 5   噓: 0   分數: 5           作者: bigtreelife (Tree)
# 1016   推: 1   噓: 0   分數: 1        作者: join183club (183club)
#
#                                   文章名稱                          發表時間
# 0          標題: [問卦] 兩個候選人選前一個月同時陣亡的可能性  時間: Fri Oct  2 13:56:39 2020
# 1         標題: [新聞]江啟臣：兩岸是不對稱的戰爭 從募兵改徵兵  時間: Wed Oct  7 18:53:08 2020
# 2      標題: Re: [新聞] 高加索血戰破百死：亞美尼亞禁止役齡男  時間: Fri Oct  2 13:07:43 2020
# 3           標題: [問卦] 如果川普老婆死於武漢肺炎會怎麼樣？  時間: Fri Oct  2 13:30:55 2020
# 4           標題: [問卦] 為什麼古代生物體型可以長到這麼大？  時間: Fri Oct  2 12:35:18 2020
# ...                                ...                           ...
# 1012                 標題: [問卦] 我是被下套了嗎？  時間: Wed Oct  7 21:27:26 2020
# 1013          標題: [問卦] 認真問 人一天可以走幾公里呀？  時間: Fri Oct  2 14:00:50 2020
# 1014            標題: [問卦] 川普確診 會不會延後選舉?  時間: Fri Oct  2 13:15:27 2020
# 1015             標題: [問卦] 叫外送的年輕人都是什麼人  時間: Fri Oct  2 15:29:44 2020
# 1016  標題: Re: [新聞] 快訊／川普夫婦確診新冠肺炎 即刻開始隔  時間: Fri Oct  2 13:37:56 2020
#
# [1017 rows x 6 columns]

# %% [markdown]
# # 過濾器操作

# %%
# 先將原資料進行備份
df2 = df.copy()

# %%
'''
使用一般函數製作過濾器
'''

# 製作過濾器
def column_filter(s):
    return s.split(': ')[-1].strip()

# %%
df['推數'].apply(column_filter)
# Out:
# 0       25
# 1       11
# 2        1
# 3       20
# 4       31
#         ..
# 1012     0
# 1013    15
# 1014    10
# 1015     5
# 1016     1
# Name: 推數, Length: 1017, dtype: object

# %%
for c in df:
    df[c] = df[c].apply(column_filter)
df
# Out:
#       推數  噓數 文章分數                         文章作者                      文章名稱  \
# 0     25   4   21  Rusnake5566 (魯蛇+56 PTT最強帳號)   [問卦] 兩個候選人選前一個月同時陣亡的可能性
# 1     11  11    0            LoveMakeLove (ボケ)  [新聞]江啟臣：兩岸是不對稱的戰爭 從募兵改徵兵
# 2      1   1    0             Asce (Excalibur)   [新聞] 高加索血戰破百死：亞美尼亞禁止役齡男
# 3     20   0   20               MintSu (Simon)    [問卦] 如果川普老婆死於武漢肺炎會怎麼樣？
# 4     31   2   29               seiya2000 (風見)    [問卦] 為什麼古代生物體型可以長到這麼大？
# ...   ..  ..  ...                          ...                       ...
# 1012   0   0    0      wa778895 (oilsunbright)             [問卦] 我是被下套了嗎？
# 1013  15   4   11              stan0720 (Kimo)      [問卦] 認真問 人一天可以走幾公里呀？
# 1014  10   7    3                 alaza (無恥美國)        [問卦] 川普確診 會不會延後選舉?
# 1015   5   0    5           bigtreelife (Tree)         [問卦] 叫外送的年輕人都是什麼人
# 1016   1   0    1        join183club (183club)  [新聞] 快訊／川普夫婦確診新冠肺炎 即刻開始隔
#
#                           發表時間
# 0     Fri Oct  2 13:56:39 2020
# 1     Wed Oct  7 18:53:08 2020
# 2     Fri Oct  2 13:07:43 2020
# 3     Fri Oct  2 13:30:55 2020
# 4     Fri Oct  2 12:35:18 2020
# ...                        ...
# 1012  Wed Oct  7 21:27:26 2020
# 1013  Fri Oct  2 14:00:50 2020
# 1014  Fri Oct  2 13:15:27 2020
# 1015  Fri Oct  2 15:29:44 2020
# 1016  Fri Oct  2 13:37:56 2020
#
# [1017 rows x 6 columns]

# %%
'''
使用 lambda 作為過濾器
'''

df2['推數'].apply(lambda x: x.split(':')[-1].strip())
# Out:
# 0       25
# 1       11
# 2        1
# 3       20
# 4       31
#         ..
# 1012     0
# 1013    15
# 1014    10
# 1015     5
# 1016     1
# Name: 推數, Length: 1017, dtype: object

# %%
for c in df2:
    df2[c] = df2[c].apply(lambda x: x.split(': ')[-1].strip())
df2
# Out:
#       推數  噓數 文章分數                         文章作者                      文章名稱  \
# 0     25   4   21  Rusnake5566 (魯蛇+56 PTT最強帳號)   [問卦] 兩個候選人選前一個月同時陣亡的可能性
# 1     11  11    0            LoveMakeLove (ボケ)  [新聞]江啟臣：兩岸是不對稱的戰爭 從募兵改徵兵
# 2      1   1    0             Asce (Excalibur)   [新聞] 高加索血戰破百死：亞美尼亞禁止役齡男
# 3     20   0   20               MintSu (Simon)    [問卦] 如果川普老婆死於武漢肺炎會怎麼樣？
# 4     31   2   29               seiya2000 (風見)    [問卦] 為什麼古代生物體型可以長到這麼大？
# ...   ..  ..  ...                          ...                       ...
# 1012   0   0    0      wa778895 (oilsunbright)             [問卦] 我是被下套了嗎？
# 1013  15   4   11              stan0720 (Kimo)      [問卦] 認真問 人一天可以走幾公里呀？
# 1014  10   7    3                 alaza (無恥美國)        [問卦] 川普確診 會不會延後選舉?
# 1015   5   0    5           bigtreelife (Tree)         [問卦] 叫外送的年輕人都是什麼人
# 1016   1   0    1        join183club (183club)  [新聞] 快訊／川普夫婦確診新冠肺炎 即刻開始隔
#
#                           發表時間
# 0     Fri Oct  2 13:56:39 2020
# 1     Wed Oct  7 18:53:08 2020
# 2     Fri Oct  2 13:07:43 2020
# 3     Fri Oct  2 13:30:55 2020
# 4     Fri Oct  2 12:35:18 2020
# ...                        ...
# 1012  Wed Oct  7 21:27:26 2020
# 1013  Fri Oct  2 14:00:50 2020
# 1014  Fri Oct  2 13:15:27 2020
# 1015  Fri Oct  2 15:29:44 2020
# 1016  Fri Oct  2 13:37:56 2020
#
# [1017 rows x 6 columns]

# %% [markdown]
# # 儲存及讀取 CSV

# %%
# 儲存成csv檔

df.to_csv(r'./pttGossiping.csv', index=0, encoding = 'utf-8-sig')

# %%
df_load = pd.read_csv(r'./pttGossiping.csv')
df_load
# Out:
#       推數  噓數  文章分數                         文章作者                      文章名稱  \
# 0     25   4    21  Rusnake5566 (魯蛇+56 PTT最強帳號)   [問卦] 兩個候選人選前一個月同時陣亡的可能性
# 1     11  11     0            LoveMakeLove (ボケ)  [新聞]江啟臣：兩岸是不對稱的戰爭 從募兵改徵兵
# 2      1   1     0             Asce (Excalibur)   [新聞] 高加索血戰破百死：亞美尼亞禁止役齡男
# 3     20   0    20               MintSu (Simon)    [問卦] 如果川普老婆死於武漢肺炎會怎麼樣？
# 4     31   2    29               seiya2000 (風見)    [問卦] 為什麼古代生物體型可以長到這麼大？
# ...   ..  ..   ...                          ...                       ...
# 1012   0   0     0      wa778895 (oilsunbright)             [問卦] 我是被下套了嗎？
# 1013  15   4    11              stan0720 (Kimo)      [問卦] 認真問 人一天可以走幾公里呀？
# 1014  10   7     3                 alaza (無恥美國)        [問卦] 川普確診 會不會延後選舉?
# 1015   5   0     5           bigtreelife (Tree)         [問卦] 叫外送的年輕人都是什麼人
# 1016   1   0     1        join183club (183club)  [新聞] 快訊／川普夫婦確診新冠肺炎 即刻開始隔
#
#                           發表時間
# 0     Fri Oct  2 13:56:39 2020
# 1     Wed Oct  7 18:53:08 2020
# 2     Fri Oct  2 13:07:43 2020
# 3     Fri Oct  2 13:30:55 2020
# 4     Fri Oct  2 12:35:18 2020
# ...                        ...
# 1012  Wed Oct  7 21:27:26 2020
# 1013  Fri Oct  2 14:00:50 2020
# 1014  Fri Oct  2 13:15:27 2020
# 1015  Fri Oct  2 15:29:44 2020
# 1016  Fri Oct  2 13:37:56 2020
#
# [1017 rows x 6 columns]
