# %%
'''

Pandas 基本操作

'''
import pandas as pd

# 宣告一個DataFrame
df = pd.DataFrame(columns = ['a', 'b', 'c'])
df
# Out:
# Empty DataFrame
# Columns: [a, b, c]
# Index: []

# %%
# 插入一個row
df.loc[0] = [1,2,3]
df.loc[1] = [2,3,4]
df.loc[3] = [5,6,5]
df
# Out:
#    a  b  c
# 0  1  2  3
# 1  2  3  4
# 3  5  6  5

# %%
df['d'] = [2,2,3]
df
# Out:
#    a  b  c  d
# 0  1  2  3  2
# 1  2  3  4  2
# 3  5  6  5  3

# %%
df['e'] = [1,2,3,4]
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-2dfbdc2b3503> in <module>()
# ----> 1 df['e'] = [1,2,3,4]
#       2 df
#
# /Users/uuboy.scy/PycharmProjects/tibame-pyetl/venv/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3470         else:
#    3471             # set column
# -> 3472             self._set_item(key, value)
#    3473
#    3474     def _setitem_slice(self, key, value):
#
# /Users/uuboy.scy/PycharmProjects/tibame-pyetl/venv/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3547
#    3548         self._ensure_valid_index(value)
# -> 3549         value = self._sanitize_column(key, value)
#    3550         NDFrame._set_item(self, key, value)
#    3551
#
# /Users/uuboy.scy/PycharmProjects/tibame-pyetl/venv/lib/python3.7/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3732
#    3733             # turn me into an ndarray
# -> 3734             value = sanitize_index(value, self.index, copy=False)
#    3735             if not isinstance(value, (np.ndarray, Index)):
#    3736                 if isinstance(value, list) and len(value) > 0:
#
# /Users/uuboy.scy/PycharmProjects/tibame-pyetl/venv/lib/python3.7/site-packages/pandas/core/internals/construction.py in sanitize_index(data, index, copy)
#     610
#     611     if len(data) != len(index):
# --> 612         raise ValueError("Length of values does not match length of index")
#     613
#     614     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %%
df.drop(['d'], axis=1)
# Out:
#    a  b  c
# 0  1  2  3
# 1  2  3  4
# 3  5  6  5

# %%
df
# Out:
#    a  b  c  d
# 0  1  2  3  2
# 1  2  3  4  2
# 3  5  6  5  3

# %%
df = df.drop(['d'], axis=1)
df
# Out:
#    a  b  c
# 0  1  2  3
# 1  2  3  4
# 3  5  6  5

# %%
df.drop(3)
# Out:
#    a  b  c
# 0  1  2  3
# 1  2  3  4

# %%
df
# Out:
#    a  b  c
# 0  1  2  3
# 1  2  3  4
# 3  5  6  5

# %%
df = df.drop(3)
df
# Out:
#    a  b  c
# 0  1  2  3
# 1  2  3  4

# %%
df['b'][1] = 100
df
# Out:
#    a    b  c
# 0  1    2  3
# 1  2  100  4

# %%
df.loc[0] = 200
df
# Out:
#      a    b    c
# 0  200  200  200
# 1    2  100    4

# %%
df['b'] = 100
df
# Out:
#      a    b    c
# 0  200  100  200
# 1    2  100    4

# %%
df.to_csv(r'./test_pandas.csv', index=0, encoding='utf-8')

# %%
df2 = pd.read_csv(r'./test_pandas.csv')
df2
# Out:
#      a    b    c
# 0  200  100  200
# 1    2  100    4

# %%
new_df = pd.DataFrame(data = [[66,66,66],[77,77,77]], columns = ['a', 'b', 'c'])
df.append(new_df)
# Out:
#      a    b    c
# 0  200  100  200
# 1    2  100    4
# 0   66   66   66
# 1   77   77   77
